# %%
# !pip install pyspark
# !pip install langdetect
# Out:
# Requirement already satisfied: pyspark in /usr/local/lib/python3.7/dist-packages (3.2.1)
# Requirement already satisfied: py4j==0.10.9.3 in /usr/local/lib/python3.7/dist-packages (from pyspark) (0.10.9.3)
# Collecting langdetect
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      |████████████████████████████████| 981 kB 5.2 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from langdetect) (1.15.0)
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993242 sha256=c5ed370e8c95d7aa9ad3401f06a411dae8c165e1296d296ccc6db4f47201eef8
#   Stored in directory: /root/.cache/pip/wheels/c5/96/8a/f90c59ed25d75e50a8c10a1b1c2d4c402e4dacfa87f3aff36a
# Successfully built langdetect
# Installing collected packages: langdetect
# Successfully installed langdetect-1.0.9

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, udf,lower
from pyspark.sql.types import StringType,IntegerType,FloatType,LongType
from pyspark.sql.types import StructType

spark = SparkSession.builder\
        .master("local")\
        .appName("RECOMMENDATION SYSTEM")\
        .config('spark.ui.port', '4050')\
        .getOrCreate()


spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://a980f4d9874e:4050">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.2.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>RECOMMENDATION SYSTEM</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
schema = StructType() \
      .add("Course_ID",IntegerType(),True) \
      .add("Course Title",StringType(),True) \
      .add("Course Organisation",StringType(),True) \
      .add("Course Certification Type",StringType(),True) \
      .add("Rating",FloatType(),True) \
      .add("course_difficulty",StringType(),True) \
      .add("Student Enrolled",StringType(),True) 
      
df_with_schema = spark.read.format("csv") \
      .option("header", True) \
      .schema(schema) \
      .load("/content/coursea_data.csv")

# %%
df_with_schema.show()
# Out:
# +---------+--------------------+--------------------+-------------------------+------+-----------------+----------------+
# |Course_ID|        Course Title| Course Organisation|Course Certification Type|Rating|course_difficulty|Student Enrolled|
# +---------+--------------------+--------------------+-------------------------+------+-----------------+----------------+
# |      134|(ISC)² Systems Se...|              (ISC)²|           SPECIALIZATION|   4.7|         Beginner|            5.3k|
# |      743|A Crash Course in...|University of Pen...|                   COURSE|   4.7|     Intermediate|             17k|
# |      874|A Crash Course in...|Johns Hopkins Uni...|                   COURSE|   4.5|            Mixed|            130k|
# |      413|A Law Student's T...|     Yale University|                   COURSE|   4.7|            Mixed|             91k|
# |      635|A Life of Happine...|Indian School of ...|                   COURSE|   4.8|            Mixed|            320k|
# |      661|ADHD: Everyday St...|University at Buf...|                   COURSE|   4.7|         Beginner|             39k|
# |       54|     AI For Everyone|     deeplearning.ai|                   COURSE|   4.8|         Beginner|            350k|
# |      488|AI For Medical Tr...|     deeplearning.ai|                   COURSE|   4.8|     Intermediate|            2.4k|
# |       58|AI Foundations fo...|                 IBM|           SPECIALIZATION|   4.7|         Beginner|             61k|
# |      129|AI for Medical Di...|     deeplearning.ai|                   COURSE|   4.7|     Intermediate|             12k|
# |      283|AI for Medical Pr...|     deeplearning.ai|                   COURSE|   4.6|     Intermediate|              4k|
# |       35|     AI for Medicine|     deeplearning.ai|           SPECIALIZATION|   4.7|     Intermediate|             13k|
# |       43|    AWS Fundamentals| Amazon Web Services|           SPECIALIZATION|   4.6|         Beginner|            130k|
# |      631|AWS Fundamentals:...| Amazon Web Services|                   COURSE|   4.3|         Beginner|             11k|
# |      861|AWS Fundamentals:...| Amazon Web Services|                   COURSE|   4.7|         Beginner|             27k|
# |      281|AWS Fundamentals:...| Amazon Web Services|                   COURSE|   4.7|         Beginner|            110k|
# |      828|AWS Fundamentals:...| Amazon Web Services|                   COURSE|   4.5|     Intermediate|             13k|
# |      819|Aboriginal Worldv...|University of Tor...|                   COURSE|   4.7|            Mixed|            6.6k|
# |       63|Academic English:...|University of Cal...|           SPECIALIZATION|   4.7|         Beginner|            540k|
# |      142|Accelerated Compu...|University of Ill...|           SPECIALIZATION|   4.7|     Intermediate|             22k|
# +---------+--------------------+--------------------+-------------------------+------+-----------------+----------------+
# only showing top 20 rows

# %%
#removed punctuations
from pyspark.sql.functions import udf

import string
regular_punct = list(string.punctuation)
extra_punct = [
    ',', '.', '"', ':', ')', '(', '!', '?', '|', ';', "'", '$', '&',
    '/', '[', ']', '>', '%', '=', '#', '*', '+', '\\', '•',  '~', '@', '£',
    '·', '_', '{', '}', '©', '^', '®', '`',  '<', '→', '°', '€', '™', '›',
    '♥', '←', '×', '§', '″', '′', 'Â', '█', '½', 'à', '…', '“', '★', '”',
    '–', '●', 'â', '►', '−', '¢', '²', '¬', '░', '¶', '↑', '±', '¿', '▾',
    '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─', '▒', '：', '¼', '⊕', '▼',
    '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲',
    'è', '¸', '¾', 'Ã', '⋅', '‘', '∞', '∙', '）', '↓', '、', '│', '（', '»',
    '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø',
    '¹', '≤', '‡', '√', '«', '»', '´', 'º', '¾', '¡', '§', '£', '₤','⌨','☝']

all_punct = list(set(regular_punct + extra_punct))

def remove_punctuation(text):
    for punc in all_punct:
        if punc in text:
            text = text.replace(punc, ' ')
    return (text.strip().lower())
    

DF_string_remover = udf(lambda m: remove_punctuation(m))

df_with_schema=df_with_schema.withColumn("Course Title",DF_string_remover("Course Title"))
df_with_schema=df_with_schema.withColumn("Course Organisation",DF_string_remover("Course Organisation"))
df_with_schema.show(5)
# Out:
# +---------+--------------------+--------------------+-------------------------+------+-----------------+----------------+
# |Course_ID|        Course Title| Course Organisation|Course Certification Type|Rating|course_difficulty|Student Enrolled|
# +---------+--------------------+--------------------+-------------------------+------+-----------------+----------------+
# |      134|isc   systems sec...|                 isc|           SPECIALIZATION|   4.7|         Beginner|            5.3k|
# |      743|a crash course in...|university of pen...|                   COURSE|   4.7|     Intermediate|             17k|
# |      874|a crash course in...|johns hopkins uni...|                   COURSE|   4.5|            Mixed|            130k|
# |      413|a law student s t...|     yale university|                   COURSE|   4.7|            Mixed|             91k|
# |      635|a life of happine...|indian school of ...|                   COURSE|   4.8|            Mixed|            320k|
# +---------+--------------------+--------------------+-------------------------+------+-----------------+----------------+
# only showing top 5 rows

# %%
#languae check 
#spelling corector

# %%
#tokenise
from pyspark.ml.feature import Tokenizer

tokenizer1 = Tokenizer(inputCol="Course Title", outputCol="Course Title_tokenise")
df_Title_tokenise= tokenizer1.transform(df_with_schema).select("Course Title_tokenise")

tokenizer = Tokenizer(inputCol="Course Organisation", outputCol="Course Organisation_tokenise")
df_Organisation_tokenise= tokenizer.transform(df_with_schema).select("Course Organisation_tokenise")

# %%
df_Organisation_tokenise.show()
df_Title_tokenise.show()
# Out:
# +----------------------------+
# |Course Organisation_tokenise|
# +----------------------------+
# |                       [isc]|
# |        [university, of, ...|
# |        [johns, hopkins, ...|
# |          [yale, university]|
# |        [indian, school, ...|
# |        [university, at, ...|
# |          [deeplearning, ai]|
# |          [deeplearning, ai]|
# |                       [ibm]|
# |          [deeplearning, ai]|
# |          [deeplearning, ai]|
# |          [deeplearning, ai]|
# |        [amazon, web, ser...|
# |        [amazon, web, ser...|
# |        [amazon, web, ser...|
# |        [amazon, web, ser...|
# |        [amazon, web, ser...|
# |        [university, of, ...|
# |        [university, of, ...|
# |        [university, of, ...|
# +----------------------------+
# only showing top 20 rows
#
# +---------------------+
# |Course Title_tokenise|
# +---------------------+
# | [isc, , , systems...|
# | [a, crash, course...|
# | [a, crash, course...|
# | [a, law, student,...|
# | [a, life, of, hap...|
# | [adhd, , everyday...|
# |  [ai, for, everyone]|
# | [ai, for, medical...|
# | [ai, foundations,...|
# | [ai, for, medical...|
# | [ai, for, medical...|
# |  [ai, for, medicine]|
# |  [aws, fundamentals]|
# | [aws, fundamental...|
# | [aws, fundamental...|
# | [aws, fundamental...|
# | [aws, fundamental...|
# | [aboriginal, worl...|
# | [academic, englis...|
# | [accelerated, com...|
# +---------------------+
# only showing top 20 rows

# %%
#stopwords
from pyspark.ml.feature import StopWordsRemover


remover1 = StopWordsRemover()
stopwords = remover1.getStopWords()
remover1.setInputCol("Course Organisation_tokenise")
remover1.setOutputCol("Course Organisation_tokenise_no_stopw")
Course_Organisation_no_stopw_df = remover1.transform(df_Organisation_tokenise).select("Course Organisation_tokenise_no_stopw")



remover2 = StopWordsRemover()
stopwords = remover2.getStopWords()
remover2.setInputCol("Course Title_tokenise")
remover2.setOutputCol("Course Title_tokenise_no_stopw")
Course_Title_no_stopw_df = remover2.transform(df_Title_tokenise).select("Course Title_tokenise_no_stopw")

# %%
#Course_Organisation_no_stopw_df.show()
Course_Title_no_stopw_df.show()
# Out:
# +------------------------------+
# |Course Title_tokenise_no_stopw|
# +------------------------------+
# |          [isc, , , systems...|
# |          [crash, course, c...|
# |          [crash, course, d...|
# |          [law, student, to...|
# |          [life, happiness,...|
# |          [adhd, , everyday...|
# |                [ai, everyone]|
# |          [ai, medical, tre...|
# |          [ai, foundations,...|
# |          [ai, medical, dia...|
# |          [ai, medical, pro...|
# |                [ai, medicine]|
# |           [aws, fundamentals]|
# |          [aws, fundamental...|
# |          [aws, fundamental...|
# |          [aws, fundamental...|
# |          [aws, fundamental...|
# |          [aboriginal, worl...|
# |          [academic, englis...|
# |          [accelerated, com...|
# +------------------------------+
# only showing top 20 rows

# %%
# !pip install fasttext
# Out:
# Requirement already satisfied: fasttext in /usr/local/lib/python3.7/dist-packages (0.9.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from fasttext) (1.21.5)
# Requirement already satisfied: pybind11>=2.2 in /usr/local/lib/python3.7/dist-packages (from fasttext) (2.9.1)
# Requirement already satisfied: setuptools>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from fasttext) (57.4.0)

# %%
#https://analyticsindiamag.com/hands-on-guide-to-word-embeddings-using-glove/
import os
import urllib.request
import matplotlib.pyplot as plt
from scipy import spatial
from sklearn.manifold import TSNE
import numpy as np

# %%
urllib.request.urlretrieve('https://nlp.stanford.edu/data/glove.6B.zip','glove.6B.zip')
# !unzip "/content/glove.6B.zip"
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-6eab0951ebcc> in <module>()
# ----> 1 urllib.request.urlretrieve('https://nlp.stanford.edu/data/glove.6B.zip','glove.6B.zip')
#       2 get_ipython().system('unzip "/content/glove.6B.zip"')
#
# /usr/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     274
#     275             while True:
# --> 276                 block = fp.read(bs)
#     277                 if not block:
#     278                     break
#
# /usr/lib/python3.7/http/client.py in read(self, amt)
#     463             # Amount is given, implement using readinto
#     464             b = bytearray(amt)
# --> 465             n = self.readinto(b)
#     466             return memoryview(b)[:n].tobytes()
#     467         else:
#
# /usr/lib/python3.7/http/client.py in readinto(self, b)
#     507         # connection, and the user is reading more bytes than will be provided
#     508         # (for example, reading in 1k chunks)
# --> 509         n = self.fp.readinto(b)
#     510         if not n and b:
#     511             # Ideally, we would raise IncompleteRead if the content-length
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
emmbed_dict = {}
with open('/content/glove.6B.50d.txt','r') as f:
  for line in f:
    values = line.split()
    word = values[0]
    vector = np.asarray(values[1:],'float32')
    emmbed_dict[word]=vector

# %%
list12=[]
list1=emmbed_dict["hi"]
for i in list1:
  list12.append(i)
list2=emmbed_dict["bro"]
for i in list2:
  list12.append(i)

list12
# Out:
# [-0.54313,
#  0.34427,
#  0.27125,
#  1.0487,
#  -1.1642,
#  -1.2722,
#  0.35781,
#  -0.56527,
#  -0.29879,
#  0.85179,
#  0.52222,
#  -0.0019718,
#  -0.46435,
#  0.033631,
#  0.048367,
#  0.78762,
#  0.075995,
#  0.51577,
#  0.34778,
#  0.53802,
#  0.28299,
#  -0.1313,
#  -0.073753,
#  0.42614,
#  0.030954,
#  -0.55033,
#  -0.99789,
#  -0.28947,
#  0.30517,
#  -1.1194,
#  1.2957,
#  0.91165,
#  0.32222,
#  0.93405,
#  -0.34152,
#  -0.62713,
#  -0.092165,
#  0.50901,
#  0.29204,
#  -0.20122,
#  0.19614,
#  -0.45882,
#  1.1099,
#  -0.68737,
#  1.5724,
#  -0.10446,
#  0.23594,
#  -0.56594,
#  0.43676,
#  0.98093,
#  -0.38585,
#  0.15491,
#  -0.35731,
#  -0.62233,
#  -0.50594,
#  -0.12473,
#  0.44711,
#  -0.29007,
#  -0.51312,
#  -0.34471,
#  -0.18583,
#  0.86388,
#  -0.4041,
#  -0.74427,
#  -0.33632,
#  0.2364,
#  -0.12313,
#  0.28241,
#  0.62132,
#  0.29675,
#  -0.46514,
#  -0.38196,
#  0.39958,
#  0.39733,
#  0.41027,
#  0.15278,
#  -0.5617,
#  0.029929,
#  -0.32652,
#  -0.90463,
#  -0.32284,
#  0.68215,
#  -0.1259,
#  0.65031,
#  -0.5831,
#  -0.11666,
#  0.79877,
#  -0.58943,
#  1.0938,
#  0.62151,
#  0.33655,
#  -0.2608,
#  -1.1699,
#  -0.048766,
#  0.75291,
#  0.36884,
#  0.082115,
#  -0.2423,
#  0.40968,
#  0.71508]

# %%
def find_similar_word(emmbedes):
  nearest = sorted(emmbed_dict.keys(), key=lambda word: spatial.distance.euclidean(emmbed_dict[word], emmbedes))
  return nearest

# %%
find_similar_word(emmbed_dict["isc"])[0:10]
# Out:
# ['isc', 'iasc', 'acca', 'asc', 'sra', 'clc', 'gtc', 'amba', 'isb', 'tcc']

# %%
#check for emply spaces
@udf(returnType=FloatType())
def word_vec(text):

    with open('/content/glove.6B.50d.txt','r') as f:
        for line in f:
          values = line.split()
          word = values[0]
          vector = np.asarray(values[1:],'float32')
          emmbed_dict[word]=vector
          word2vec_list=[]
          for words in text:
            if len(words)>1:
               vec=emmbed_dict[text]
               for i in vec:
                 word2vec_list.append(i)  
          return(word2vec_list)

# %%
# Below are quick examples
# Using df.to_numpy() method.


# Convert specific column to numpy array.
pandasDF_title = Course_Title_no_stopw_df.toPandas()
print(pandasDF_title)
# Out:
#                         Course Title_tokenise_no_stopw
# 0    [isc, , , systems, security, certified, practi...
# 1    [crash, course, causality, , , inferring, caus...
# 2                       [crash, course, data, science]
# 3                              [law, student, toolkit]
# 4                       [life, happiness, fulfillment]
# ..                                                 ...
# 840             [write, professional, emails, english]
# 841                              [write, first, novel]
# 842                                [writing, sciences]
# 843  [e, learning, ecologies, , innovative, approac...
# 844                     [ios, app, development, swift]
#
# [845 rows x 1 columns]

# %%
# !pip install googletrans
# Out:
# Collecting googletrans
#   Downloading googletrans-3.0.0.tar.gz (17 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.2 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2021.10.8)
# Collecting hstspreload
#   Downloading hstspreload-2021.12.1-py3-none-any.whl (1.3 MB)
#      |████████████████████████████████| 1.3 MB 10.1 MB/s
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (2.10)
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.1 MB/s
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.7/dist-packages (from httpx==0.13.3->googletrans) (3.0.4)
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 2.3 MB/s
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.9 MB/s
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.0.0-py3-none-any.whl size=15735 sha256=647944f948ee0229d2ccdbfb084199b98d2116a85bc996b69d0b3ea88c787236
#   Stored in directory: /root/.cache/pip/wheels/20/da/eb/a54579056f265eede0417df537dd56d3df5b9eb2b25df0003d
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-3.0.0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2021.12.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.2.0

# %%
from googletrans import Translator
import time
for title in pandasDF_title["Course Title_tokenise_no_stopw"]:
  print("Title::::",title)
  
  vect_word=[]
  for words in title:
    if len(words) >1:
        print("Words:::::",words)
        time.sleep(1)
         
        try:
            vec=emmbed_dict[words]
            print("Word to vector:::",vec)
            
            for i in vec:
                vect_word.append(i)

        except:
          print("Adding zeros........")
          
          for i in range(0,50):
              vect_word.append(0)
# Out:
# Streaming output truncated to the last 5000 lines.
#   0.3505     0.47577  ]
# Words::::: lifecycle
# Word to vector::: [ 1.4304   -0.1765   -0.4981    0.28046  -0.50782   0.22503   0.21176
#  -1.3831    1.5038    0.42261   0.6498    0.26753  -0.38346  -0.64164
#   0.33974  -0.17874  -0.12311   0.5156    1.0581   -0.47244   0.069606
#  -0.59469  -0.8349    0.062369 -0.31252   1.7006    0.53305  -0.20277
#  -0.11023   0.78985   1.0232   -0.091621 -0.49417  -0.31405  -0.48516
#   0.84373  -0.19373   0.24859   0.67772  -0.59678   0.54902  -1.5021
#  -0.87419   0.74147  -0.64884  -0.47666   1.4977    0.30523   0.12266
#   0.30392 ]
# Title:::: ['software', 'processes', 'agile', 'practices']
# Words::::: software
# Word to vector::: [ 0.40093  -1.1683    1.2586    1.3243   -0.60614  -0.36914  -1.2668
#  -1.7872    0.67804   1.1791    0.72633   0.7432   -0.32346  -0.31177
#  -0.025236  0.072382 -0.84757   0.70602   0.88824  -0.67657   0.54001
#  -0.11735  -0.90053   0.4227    0.21735  -0.5767   -0.40095  -1.1345
#   0.064297 -0.44729   3.3038   -1.0716   -0.37677  -0.48321  -0.11032
#   0.27934  -0.51331   0.22437   0.3481   -0.6764    1.27     -0.37939
#  -0.1754    0.94066  -0.12009   0.40097   0.93773   0.57618   0.30619
#   0.30187 ]
# Words::::: processes
# Word to vector::: [ 6.1197e-01 -6.0295e-01 -4.2840e-01  7.6196e-01 -3.2541e-01  8.8258e-01
#   8.4506e-01 -3.7229e-01  6.0830e-01  4.0079e-01  8.9268e-01 -6.0419e-02
#   2.1804e-01  3.8568e-01 -3.0283e-01  1.4164e-01  1.1993e-01  4.2922e-02
#   9.3532e-01 -1.2095e+00  8.3877e-01 -5.5725e-01  1.7631e-01 -3.6916e-01
#   4.0532e-01  3.9720e-01 -2.1413e-01 -6.4954e-01  6.9299e-01  3.6156e-01
#   3.0854e+00 -7.2815e-01 -6.0417e-01 -1.7646e+00 -2.6031e-01  3.0175e-01
#  -2.7016e-01  6.7567e-01  6.3831e-01  7.4889e-01 -3.7753e-01 -1.0050e+00
#   9.6075e-02  7.6113e-01 -3.1183e-01 -1.0902e-01  1.0392e+00  6.2969e-01
#  -1.3316e-01  9.4026e-04]
# Words::::: agile
# Word to vector::: [ 0.71119  -1.5489    0.06334  -0.42547   0.28846  -0.28962   0.19401
#  -0.93455  -0.042159  1.0063    0.63096   0.18817   0.14596   0.64077
#  -1.3497   -0.61065   0.8378    0.96092  -0.20185  -0.57102  -1.3186
#   0.25381  -0.8394   -0.24225   0.66162   0.16156   0.43025  -0.14992
#   0.26084   0.061553  1.2198   -0.25787   0.22042   0.033313 -0.065144
#   0.12101  -0.47562   1.0143   -0.61853  -0.66864   0.31813  -0.40497
#   0.23962   0.74005   0.71539  -0.92229   0.67247   0.14286   0.18336
#   1.3002  ]
# Words::::: practices
# Word to vector::: [-0.34665  -0.91222  -1.6818   -0.016127 -0.47689   0.049569 -0.40343
#  -0.17988 ]
# Title:::: ['ios', 'app', 'development', 'swift']
# Words::::: ios
# Word to vector::: [ 0.91469  -1.065     1.2364    1.9629   -0.30918   0.58056  -1.0473
#  -1.6864    0.71842   1.0104    0.68317   0.13833   0.73098  -0.73879
#  -0.073441  0.23054  -1.9024    0.29207   0.092255  0.16521  -0.1067
#  -0.38415   0.14004   0.31119   0.60329   1.2917    1.1269   -0.54676
#  -0.075934 -0.71478   1.2856   -0.58295  -0.80207  -0.36768   0.57726
#   0.19357   0.99239  -0.13174  -0.92452  -1.2805    0.52945  -0.86402
#  -1.5647   -0.20522   0.096842  0.67339   0.71777  -0.48488   1.1383
#  -0.063947]
# Words::::: app
# Word to vector::: [ 0.40037  -0.79645   1.3763    1.2684   -0.031567 -0.40912  -0.56085
#  -1.3984    1.3722    0.82495   0.083732 -0.17466   0.52424  -0.56194
#   0.3338    0.46696  -1.1922    0.55259   0.71635   0.37038   0.253
#  -0.15675   0.33699   1.124     0.91561  -0.012376 -0.19162  -0.41561
#  -0.38949  -0.48658   1.4432   -0.64322  -0.5163    0.22316   0.16515
#  -0.040618  0.69223  -0.19183  -0.59174  -0.76782   1.0376   -0.14846
#  -1.1534   -0.17238   0.37247   0.75415   0.36382   0.18685   1.0523
#   0.38187 ]
# Words::::: development
# Word to vector::: [ 0.73598    0.42827   -0.41797    0.9281    -0.17954    0.079438
#  -0.42414   -1.4107     0.86105    0.095253   0.59344    0.14376
#  -0.24424   -0.29302   -0.69447    0.55168    0.84157    0.68757
#   0.60488    0.47378    0.54431   -0.11859   -0.80833   -0.71785
#   0.39173   -0.72462    0.34971   -0.72175   -0.6445     0.5687
#   4.027      0.06102   -0.1615    -1.0245    -0.11469    0.10332
#  -0.40129    0.64716    0.0044513  0.19815   -1.0598    -0.6211
#  -0.028941  -0.58078    0.22744    0.10194   -0.11013    0.54247
#   0.3505     0.47577  ]
# Words::::: swift
# Word to vector::: [ 0.37214   -0.31333   -0.25042   -0.40004   -0.52135    0.40727
#  -0.081176   0.69469    0.72797    0.31538   -0.61422    0.32752
#   0.11098   -0.16131   -0.49548   -0.56698    0.54909   -0.81166
#  -0.37403   -0.54684    0.13185    0.017158  -0.3294    -0.81264
#   0.69736   -0.96474    0.25996   -0.23349    0.25092    0.32761
#   1.6872    -0.30351   -0.56583    0.099568   0.12995   -0.51687
#   0.33941   -0.52954   -0.68261   -0.61911   -0.046125   0.065805
#  -0.31601   -0.88756    0.54661   -0.23167   -0.0051238  0.29813
#  -0.076025   0.80216  ]

# %%
import numpy as np
np_vect_word=np.asarray(vect_word)
np_vect_word.shape
# Out:
# (200,)

# %%
try:
    a=emmbed_dict.get["xqxx"]
    print("found")
except:
  print(":not found")
# Out:
# :not found

# %%
#Course_Organisation_no_stopw_df.show()
Course_Title_no_stopw_df.columns
# Out:
# ['Course Title_tokenise_no_stopw']

# %%
numpy_course_name=Course_Title_no_stopw_df['Course Title_tokenise_no_stopw'].to_numpy()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-75-505254e91b40> in <module>()
# ----> 1 numpy_course_name=Course_Title_no_stopw_df['Course Title_tokenise_no_stopw'].to_numpy()
#
# TypeError: 'Column' object is not callable

# %%
Course_Title_no_stopw_df.select("Title_word2vec").show()
# Out:
# ---------------------------------------------------------------------------
# PythonException                           Traceback (most recent call last)
# <ipython-input-70-6dda93adb333> in <module>()
# ----> 1 Course_Title_no_stopw_df.select("Title_word2vec").show()
#
# /usr/local/lib/python3.7/dist-packages/pyspark/sql/dataframe.py in show(self, n, truncate, vertical)
#     492
#     493         if isinstance(truncate, bool) and truncate:
# --> 494             print(self._jdf.showString(n, 20, vertical))
#     495         else:
#     496             try:
#
# /usr/local/lib/python3.7/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
# -> 1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#    1324         for temp_arg in temp_args:
#
# /usr/local/lib/python3.7/dist-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# PythonException:
#   An exception was thrown from the Python worker. Please see the stack trace below.
# Traceback (most recent call last):
#   File "<ipython-input-67-6e6858f9ab5b>", line 17, in word_vec
# TypeError: unhashable type: 'list'

# %%
@udf(returnType=FloatType())
def names_without_spaces(text):
    for words in text:
        if len(words) >1:
          return(emmbed_dict[text])   

            else:
              return()

# %%
word_vec("cool")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-7c2025c5dc3c> in <module>()
# ----> 1 word_vec("cool")
#
# <ipython-input-10-acb5ea459f9a> in word_vec(text)
#       4     emmbed_dict = {}
#       5     with open('/content/glove.6B.50d.txt','r') as f:
# ----> 6         for line in f:
#       7           values = line.split()
#       8           word = values[0]
#
# <ipython-input-10-acb5ea459f9a> in <lambda>(word)
#      11
#      12   nearest = sorted(emmbed_dict.keys(), key=lambda word: spatial.distance.euclidean(emmbed_dict[word], emmbed_dict[subtext]))
# ---> 13   nearest_value=sorted(emmbed_dict.values(), key=lambda word: spatial.distance.euclidean(emmbed_dict[word], emmbed_dict[subtext]))
#      14   return(nearest[0:5], nearest_value[0:5])
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
pandasDF = Course_Title_no_stopw_df.toPandas()
print(pandasDF)
# Out:
#                         Course Title_tokenise_no_stopw
# 0    [isc, , , systems, security, certified, practi...
# 1    [crash, course, causality, , , inferring, caus...
# 2                       [crash, course, data, science]
# 3                              [law, student, toolkit]
# 4                       [life, happiness, fulfillment]
# ..                                                 ...
# 886                     [программирование, на, python]
# 887            [психолингвистика, , psycholinguistics]
# 888  [разработка, интерфейсов, , вёрстка, и, javasc...
# 889                        [русский, как, иностранный]
# 890  [финансовые, инструменты, для, частного, инвес...
#
# [891 rows x 1 columns]

# %%
print(pandasDF["Course Organisation_tokenise_no_stopw"].values[0] )
# Out:
# ['isc']

# %%
DF_word_numeric = udf(lambda m: word_vec(m))
df_org_vector=Course_Organisation_no_stopw_df.withColumn("Course Organisation_numeric",DF_word_numeric ("Course Organisation_tokenise_no_stopw"))
df_org_vector.show()
# Out:
# ---------------------------------------------------------------------------
# PythonException                           Traceback (most recent call last)
# <ipython-input-26-66671ebe8313> in <module>()
#       2 DF_word_numeric = udf(lambda m: word_vec(m))
#       3 df_org_vector=Course_Organisation_no_stopw_df.withColumn("Course Organisation_numeric",DF_word_numeric ("Course Organisation_tokenise_no_stopw"))
# ----> 4 df_org_vector.show()
#       5
#
# /usr/local/lib/python3.7/dist-packages/pyspark/sql/dataframe.py in show(self, n, truncate, vertical)
#     492
#     493         if isinstance(truncate, bool) and truncate:
# --> 494             print(self._jdf.showString(n, 20, vertical))
#     495         else:
#     496             try:
#
# /usr/local/lib/python3.7/dist-packages/py4j/java_gateway.py in __call__(self, *args)
#    1320         answer = self.gateway_client.send_command(command)
#    1321         return_value = get_return_value(
# -> 1322             answer, self.gateway_client, self.target_id, self.name)
#    1323
#    1324         for temp_arg in temp_args:
#
# /usr/local/lib/python3.7/dist-packages/pyspark/sql/utils.py in deco(*a, **kw)
#     115                 # Hide where the exception came from that shows a non-Pythonic
#     116                 # JVM exception message.
# --> 117                 raise converted from None
#     118             else:
#     119                 raise
#
# PythonException:
#   An exception was thrown from the Python worker. Please see the stack trace below.
# Traceback (most recent call last):
#   File "<ipython-input-26-66671ebe8313>", line 2, in <lambda>
# NameError: name 'word_vec' is not defined

# %%
df_title_vector=Course_Title_no_stopw_df.withColumn("Course Title_numeric",DF_word_numeric ("Course Title_tokenise_no_stopw"))
df_title_vector.show(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-ff7c56c758ef> in <module>()
# ----> 1 df_title_vector=Course_Title_no_stopw_df.withColumn("Course Title_numeric",DF_word_numeric ("Course Title_tokenise_no_stopw"))
#       2 df_title_vector.show(5)
#
# NameError: name 'DF_word_numeric' is not defined

# %%
df_with_schema=df_with_schema.withColumn("Course Organisation_numeric}",DF_word_numeric ("Course Organisation"))
df_with_schema.show(5)

# %%
word_vec("cool")[0:50]
# Out:
# ['text',
#  'reference',
#  'translation',
#  'document',
#  'copy',
#  'texts',
#  'read',
#  'translated',
#  'addresses',
#  'letters',
#  'references',
#  'translations',
#  'page',
#  'description',
#  'printed',
#  'written',
#  'notes',
#  'note',
#  'words',
#  'word',
#  'reads',
#  'describing',
#  'refers',
#  'explaining',
#  'instructions',
#  'context',
#  'publish',
#  'phrase',
#  'follows',
#  'phrases',
#  'message',
#  'mentioned',
#  'preface',
#  'letter',
#  'introduction',
#  'instance',
#  'stating',
#  'uses',
#  'mentions',
#  'passages',
#  'contents',
#  'descriptions',
#  'articles',
#  'edit',
#  'referred',
#  'quotations',
#  'article',
#  'example',
#  'explicit',
#  'interpreted']

# %%
Course_Organisation_no_stopw_df.show()
# Out:
# +-------------------------------------+
# |Course Organisation_tokenise_no_stopw|
# +-------------------------------------+
# |                                [isc]|
# |                 [university, penn...|
# |                 [johns, hopkins, ...|
# |                   [yale, university]|
# |                 [indian, school, ...|
# |                 [university, buff...|
# |                   [deeplearning, ai]|
# |                   [deeplearning, ai]|
# |                                [ibm]|
# |                   [deeplearning, ai]|
# |                   [deeplearning, ai]|
# |                   [deeplearning, ai]|
# |                 [amazon, web, ser...|
# |                 [amazon, web, ser...|
# |                 [amazon, web, ser...|
# |                 [amazon, web, ser...|
# |                 [amazon, web, ser...|
# |                 [university, toro...|
# |                 [university, cali...|
# |                 [university, illi...|
# +-------------------------------------+
# only showing top 20 rows

# %%
joined_title_1=[]
for i,title in enumerate(numpy_organisation):
  
  for j in range(len(title[0])):
      joined="".join(str(title[0][j]))
  joined_title_1.append(joined)  


Tit_jponed=" ".join(joined_comments)
comments_jponed

# %%
str_organisation=[]
for i in numpy_organisation:
  text_org=[]
  text=i[0]
  
  for j in range(len(text)):
    #print(j)
    text_org.append(str(i[0][j]))
  #print(text_org)
  str_organisation.append(text_org)  

str_organisation
# Out:
# [['isc'],
#  ['univers', 'pennsylvania'],
#  ['john', 'hopkin', 'univers'],
#  ['yale', 'univers'],
#  ['indian', 'school', 'busi'],
#  ['univers', 'buffalo'],
#  ['deeplearn'],
#  ['deeplearn'],
#  ['ibm'],
#  ['deeplearn'],
#  ['deeplearn'],
#  ['deeplearn'],
#  ['amazon', 'web', 'servic'],
#  ['amazon', 'web', 'servic'],
#  ['amazon', 'web', 'servic'],
#  ['amazon', 'web', 'servic'],
#  ['amazon', 'web', 'servic'],
#  ['univers', 'toronto'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['isc'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'michigan'],
#  ['univers', 'pennsylvania'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['yale', 'univers'],
#  ['univers', 'colorado', 'boulder'],
#  ['ibm'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom'],
#  ['googl', 'cloud'],
#  ['erasmu', 'univers', 'rotterdam'],
#  ['duke', 'univers'],
#  ['yale', 'univers'],
#  ['univers', 'virginia'],
#  ['univers', 'virginia'],
#  ['atlassian'],
#  ['scrumtrek'],
#  ['univers', 'california', 'san', 'diego'],
#  ['stanford', 'univers'],
#  ['univers', 'colorado', 'system'],
#  ['yale', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['copenhagen', 'busi', 'school'],
#  ['univers', 'california', 'irvin'],
#  ['macquari', 'univers'],
#  ['univers', 'michigan'],
#  ['yale', 'univers'],
#  ['univers', 'michigan'],
#  ['univers', 'pennsylvania'],
#  ['vanderbilt', 'univers'],
#  ['univers', 'edinburgh'],
#  ['stanford', 'univers'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['technic', 'univers', 'denmark', 'dtu'],
#  ['ibm'],
#  ['ibm'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['universidad', 'austral'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['univers', 'california', 'san', 'diego'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['arizona', 'state', 'univers'],
#  ['museum', 'modern', 'art'],
#  ['museum', 'modern', 'art'],
#  ['nation', 'art', 'strategi'],
#  ['universit', 'bocconi'],
#  ['univers', 'virginia'],
#  ['univers', 'edinburgh'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['univers', 'california', 'davi'],
#  ['autodesk'],
#  ['autodesk'],
#  ['autodesk'],
#  ['autodesk'],
#  ['nation', 'taiwan', 'univers'],
#  ['univers', 'amsterdam'],
#  ['univers', 'california', 'santa', 'cruz'],
#  ['univers', 'california', 'santa', 'cruz'],
#  ['googl', 'spectrum', 'share'],
#  ['michigan', 'state', 'univers'],
#  ['univers', 'colorado', 'system'],
#  ['case', 'western', 'reserv', 'univers'],
#  ['univers', 'cape', 'town'],
#  ['duke', 'univers'],
#  ['univers', 'michigan'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['emori', 'univers'],
#  ['univers', 'california', 'san', 'diego'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'buffalo'],
#  ['insead'],
#  ['insead'],
#  ['consensi', 'academi'],
#  ['hec', 'pari'],
#  ['london', 'busi', 'school'],
#  ['busi', 'school'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'alberta'],
#  ['hebrew', 'univers', 'jerusalem'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['hec', 'pari'],
#  ['univers', 'pennsylvania'],
#  ['arizona', 'state', 'univers'],
#  ['univers', 'washington'],
#  ['univers', 'washington'],
#  ['univers', 'pennsylvania'],
#  ['hec', 'pari'],
#  ['rice', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'virginia'],
#  ['indian', 'school', 'busi'],
#  ['googl', 'cloud'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'california', 'santa', 'cruz'],
#  ['univers', 'colorado', 'system'],
#  ['john', 'hopkin', 'univers'],
#  ['osmosi'],
#  ['michigan', 'state', 'univers'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['univers', 'michigan'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'lausann'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'edinburgh'],
#  ['stanford', 'univers'],
#  ['peke', 'univers'],
#  ['cisco'],
#  ['univers', 'amsterdam'],
#  ['ies', 'busi', 'school'],
#  ['yale', 'univers'],
#  ['univers', 'pittsburgh'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['learnquest'],
#  ['googl', 'cloud'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'edinburgh'],
#  ['rice', 'univers'],
#  ['univers', 'toronto'],
#  ['univers', 'colorado', 'boulder'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['ludwig', 'maximilian', 'universität', 'münchen', 'lmu'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'colorado', 'system'],
#  ['univers', 'california', 'irvin'],
#  ['columbia', 'univers'],
#  ['columbia', 'univers'],
#  ['columbia', 'univers'],
#  ['columbia', 'univers'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['northwestern', 'univers'],
#  ['univers', 'virginia'],
#  ['georgia', 'institut', 'technolog'],
#  ['deeplearn'],
#  ['deeplearn'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['ies', 'busi', 'school'],
#  ['ucl', 'school', 'manag'],
#  ['universit', 'bocconi'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['univers', 'virginia'],
#  ['universidad', 'chile'],
#  ['googl'],
#  ['univers', 'minnesota'],
#  ['wesleyan', 'univers'],
#  ['wesleyan', 'univers'],
#  ['arizona', 'state', 'univers'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['universidad', 'chile'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'new', 'mexico'],
#  ['northwestern', 'univers'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['univers', 'system', 'georgia'],
#  ['univers', 'colorado', 'system'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['pennsylvania', 'state', 'univers'],
#  ['wesleyan', 'univers'],
#  ['pwc'],
#  ['ibm'],
#  ['univers', 'amsterdam'],
#  ['univers', 'michigan'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['vanderbilt', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['john', 'hopkin', 'univers'],
#  ['duke', 'univers'],
#  ['ibm'],
#  ['john', 'hopkin', 'univers'],
#  ['john', 'hopkin', 'univers'],
#  ['duke', 'univers'],
#  ['pwc'],
#  ['ibm'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'colorado', 'system'],
#  ['john', 'hopkin', 'univers'],
#  ['pwc'],
#  ['ibm'],
#  ['universiteit', 'leiden'],
#  ['univers', 'pennsylvania'],
#  ['deeplearn'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['univers', 'michigan'],
#  ['novosibirsk', 'state', 'univers'],
#  ['univers', 'virginia'],
#  ['univers', 'virginia'],
#  ['john', 'hopkin', 'univers'],
#  ['michigan', 'state', 'univers'],
#  ['univers', 'sydney'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['univers', 'colorado', 'boulder'],
#  ['berkle', 'colleg', 'music'],
#  ['berkle', 'colleg', 'music'],
#  ['ticket', 'chang'],
#  ['univers', 'colorado', 'boulder'],
#  ['lund', 'univers'],
#  ['univers', 'buffalo'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'virginia'],
#  ['univers', 'virginia'],
#  ['univers', 'alberta'],
#  ['univers', 'melbourn'],
#  ['tecnológico', 'monterrey'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['stanford', 'univers'],
#  ['duke', 'univers'],
#  ['erasmu', 'univers', 'rotterdam'],
#  ['univers', 'california', 'san', 'diego'],
#  ['univers', 'california', 'san', 'diego'],
#  ['univers', 'washington'],
#  ['univers', 'colorado', 'system'],
#  ['american', 'museum', 'natur', 'histori'],
#  ['erasmu', 'univers', 'rotterdam'],
#  ['columbia', 'univers'],
#  ['univers', 'geneva'],
#  ['univers', 'pennsylvania'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['universidad', 'austral'],
#  ['googl', 'cloud'],
#  ['duke', 'univers'],
#  ['berkle', 'colleg', 'music'],
#  ['yonsei', 'univers'],
#  ['univers', 'buffalo'],
#  ['new', 'york', 'univers'],
#  ['rice', 'univers'],
#  ['duke', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['moscow', 'institut', 'physic', 'technolog'],
#  ['univers', 'pennsylvania'],
#  ['peter', 'great', 'petersburg', 'polytechn', 'univers'],
#  ['duke', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['hec', 'pari'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['pennsylvania', 'state', 'univers'],
#  ['univers', 'pittsburgh'],
#  ['imperi', 'colleg', 'london'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'north', 'carolina', 'chapel', 'hill'],
#  ['univers', 'melbourn'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'california', 'irvin'],
#  ['john', 'hopkin', 'univers'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['georg', 'washington', 'univers'],
#  ['univers', 'melbourn'],
#  ['yale', 'univers'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['univers', 'colorado', 'boulder'],
#  ['yale', 'univers'],
#  ['macquari', 'univers'],
#  ['macquari', 'univers'],
#  ['macquari', 'univers'],
#  ['macquari', 'univers'],
#  ['macquari', 'univers'],
#  ['duke', 'univers'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'colorado', 'boulder'],
#  ['john', 'hopkin', 'univers'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['museum', 'modern', 'art'],
#  ['univers', 'california', 'santa', 'cruz'],
#  ['duke', 'univers'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['rice', 'univers'],
#  ['emori', 'univers'],
#  ['univers', 'virginia'],
#  ['univers', 'pennsylvania'],
#  ['columbia', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['yale', 'univers'],
#  ['indian', 'school', 'busi'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'michigan'],
#  ['universit', 'bocconi'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['univers', 'michigan'],
#  ['univers', 'pennsylvania'],
#  ['yonsei', 'univers'],
#  ['universit', 'bocconi'],
#  ['west', 'virginia', 'univers'],
#  ['universidad', 'and'],
#  ['univers', 'michigan'],
#  ['univers', 'virginia'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['john', 'hopkin', 'univers'],
#  ['ies', 'busi', 'school'],
#  ['emori', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['imperi', 'colleg', 'london'],
#  ['googl', 'cloud'],
#  ['univers', 'tokyo'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['cole', 'polytechniqu', 'rale', 'lausann'],
#  ['cole', 'polytechniqu', 'rale', 'lausann'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['rice', 'univers'],
#  ['georgia', 'institut', 'technolog'],
#  ['univers', 'california', 'davi'],
#  ['california', 'institut', 'art'],
#  ['rice', 'univers'],
#  ['rice', 'univers'],
#  ['univers', 'edinburgh'],
#  ['univers', 'virginia'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'alberta'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'pennsylvania'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['universidad', 'austral'],
#  ['universidad', 'and'],
#  ['tecnológico', 'monterrey'],
#  ['univers', 'california', 'davi'],
#  ['institut', 'futur'],
#  ['googl', 'cloud'],
#  ['univers', 'toronto'],
#  ['michigan', 'state', 'univers'],
#  ['stanford', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pittsburgh'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'california', 'davi'],
#  ['scienc'],
#  ['esad', 'busi', 'law', 'school'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['bloomsburi', 'learn', 'exchang'],
#  ['michigan', 'state', 'univers'],
#  ['amazon', 'web', 'servic'],
#  ['univers', 'california', 'irvin'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  [],
#  ['soa', 'univers', 'london'],
#  ['soa', 'univers', 'london'],
#  ['soa', 'univers', 'london'],
#  ['technic', 'univers', 'denmark', 'dtu'],
#  ['rice', 'univers'],
#  ['edhec', 'busi', 'school'],
#  ['univers', 'pennsylvania'],
#  ['busi', 'school'],
#  ['univers', 'michigan'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl'],
#  ['googl'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'pennsylvania'],
#  ['lund', 'univers'],
#  ['berkle', 'colleg', 'music'],
#  ['univers', 'california', 'san', 'diego'],
#  ['john', 'hopkin', 'univers'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'florida'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'minnesota'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['northwestern', 'univers'],
#  ['univers', 'colorado', 'system'],
#  ['essec', 'busi', 'school'],
#  ['univers', 'virginia'],
#  ['state', 'univers', 'new', 'york'],
#  ['michigan', 'state', 'univers'],
#  ['univers', 'minnesota'],
#  ['ibm'],
#  ['ibm'],
#  ['ibm'],
#  ['ibm'],
#  ['ibm'],
#  ['ibm'],
#  ['googl'],
#  ['isc'],
#  ['busi', 'school'],
#  ['autom', 'anywher'],
#  ['georgia', 'institut', 'technolog'],
#  ['deeplearn'],
#  ['luther', 'colleg', 'univers', 'regina'],
#  ['museum', 'modern', 'art'],
#  ['univers', 'alberta'],
#  ['googl', 'cloud'],
#  ['imperi', 'colleg', 'london'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['macquari', 'univers'],
#  ['royal', 'holloway', 'univers', 'london'],
#  ['new', 'york', 'univers'],
#  ['univers', 'minnesota'],
#  ['univers', 'california', 'irvin'],
#  ['erasmu', 'univers', 'rotterdam'],
#  ['univers', 'sydney'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['hec', 'pari'],
#  ['case', 'western', 'reserv', 'univers'],
#  ['univers', 'michigan'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'michigan'],
#  ['univers', 'minnesota'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'california', 'san', 'diego'],
#  ['escp', 'busi', 'school'],
#  ['univers', 'london'],
#  ['state', 'univers', 'new', 'york'],
#  ['kalshoven', 'giesk', 'forum'],
#  ['universiteit', 'leiden'],
#  ['universiteit', 'leiden'],
#  ['universit', 'bocconi'],
#  ['yonsei', 'univers'],
#  ['univers', 'geneva'],
#  ['erasmu', 'univers', 'rotterdam'],
#  ['stanford', 'univers'],
#  ['scienc'],
#  ['cisco'],
#  ['univers', 'chicago'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['univers', 'geneva'],
#  ['berkle', 'colleg', 'music'],
#  ['ibm'],
#  ['univers', 'california', 'san', 'diego'],
#  ['insead'],
#  ['yale', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'michigan'],
#  ['univers', 'sydney'],
#  ['duke', 'univers'],
#  ['yale', 'univers'],
#  ['ibm'],
#  ['goldsmith', 'univers', 'london'],
#  ['goldsmith', 'univers', 'london'],
#  ['univers', 'pennsylvania'],
#  ['new', 'york', 'univers'],
#  ['new', 'york', 'univers'],
#  ['ibm'],
#  ['rice', 'univers'],
#  ['ibm'],
#  ['univers', 'michigan'],
#  ['univers', 'pennsylvania'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom'],
#  ['georgia', 'institut', 'technolog'],
#  ['univers', 'colorado', 'boulder'],
#  ['georgia', 'institut', 'technolog'],
#  ['univers', 'north', 'carolina', 'chapel', 'hill'],
#  ['univers', 'pennsylvania'],
#  ['nanyang', 'technolog', 'univers', 'singapor'],
#  ['michigan', 'state', 'univers'],
#  ['duke', 'univers'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'michigan'],
#  ['california', 'institut', 'art'],
#  ['univers', 'pennsylvania'],
#  ['case', 'western', 'reserv', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['stanford', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'virginia'],
#  ['univers', 'edinburgh'],
#  ['edhec', 'busi', 'school'],
#  ['duke', 'univers'],
#  ['duke', 'univers'],
#  ['vanderbilt', 'univers'],
#  ['yale', 'univers'],
#  ['rice', 'univers'],
#  ['univers', 'toronto'],
#  ['univers', 'pennsylvania'],
#  ['imperi', 'colleg', 'london'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['john', 'hopkin', 'univers'],
#  ['unsw', 'sydney', 'univers', 'new', 'south', 'wale'],
#  ['deeplearn'],
#  ['univers', 'michigan'],
#  ['new', 'york', 'institut', 'financ'],
#  ['california', 'institut', 'art'],
#  ['georgia', 'institut', 'technolog'],
#  ['univers', 'michigan'],
#  ['univers', 'california', 'davi'],
#  ['john', 'hopkin', 'univers'],
#  ['duke', 'univers'],
#  ['universidad', 'são', 'paulo'],
#  ['universidad', 'são', 'paulo'],
#  ['univers', 'geneva'],
#  ['edhec', 'busi', 'school'],
#  ['rice', 'univers'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['duke', 'univers'],
#  ['duke', 'univers'],
#  ['univers', 'cape', 'town'],
#  ['jetbrain'],
#  ['essec', 'busi', 'school'],
#  ['essec', 'busi', 'school'],
#  ['rice', 'univers'],
#  ['copenhagen', 'busi', 'school'],
#  ['georg', 'washington', 'univers'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['macquari', 'univers'],
#  ['peke', 'univers'],
#  ['tsinghua', 'univers'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['shanghai', 'jiao', 'tong', 'univers'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'toronto'],
#  ['yonsei', 'univers'],
#  ['unsw', 'sydney', 'univers', 'new', 'south', 'wale'],
#  ['busi', 'school'],
#  ['essec', 'busi', 'school'],
#  ['universidad', 'and'],
#  ['georgia', 'institut', 'technolog'],
#  ['stanford', 'univers'],
#  ['univers', 'washington'],
#  ['stanford', 'univers'],
#  ['univers', 'washington'],
#  ['new', 'york', 'univers'],
#  ['univers', 'london'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['ibm'],
#  ['googl', 'cloud'],
#  ['universitat', 'barcelona'],
#  ['school', 'architectur', 'design'],
#  ['universit', 'bocconi'],
#  ['univers', 'virginia'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['hec', 'pari'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'toronto'],
#  ['univers', 'california', 'davi'],
#  ['universidad', 'são', 'paulo'],
#  ['universidad', 'austral'],
#  ['universidad', 'chile'],
#  ['busi', 'school'],
#  ['busi', 'school'],
#  ['universidad', 'and'],
#  ['tecnológico', 'monterrey'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['duke', 'univers'],
#  ['learnquest'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'california', 'davi'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom'],
#  ['imperi', 'colleg', 'london'],
#  ['imperi', 'colleg', 'london'],
#  ['imperi', 'colleg', 'london'],
#  ['imperi', 'colleg', 'london'],
#  ['univers', 'colorado', 'boulder'],
#  ['duke', 'univers'],
#  ['wesleyan', 'univers'],
#  ['univers', 'amsterdam'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'pennsylvania'],
#  ['mcmaster', 'univers'],
#  ['universiteit', 'leiden'],
#  ['univers', 'michigan'],
#  ['univers', 'pennsylvania'],
#  ['museum', 'modern', 'art'],
#  ['cloudera'],
#  ['northwestern', 'univers'],
#  ['googl', 'cloud'],
#  ['yale', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'alberta'],
#  ['cole', 'polytechniqu', 'rale', 'lausann'],
#  ['berkle', 'colleg', 'music'],
#  ['berkle', 'colleg', 'music'],
#  ['berkle', 'colleg', 'music'],
#  ['duke', 'univers'],
#  ['deeplearn'],
#  ['univers', 'michigan'],
#  ['essec', 'busi', 'school'],
#  ['vmware'],
#  ['googl', 'cloud'],
#  ['deeplearn'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['univers', 'colorado', 'system'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['ludwig', 'maximilian', 'universität', 'münchen', 'lmu'],
#  ['univers', 'california', 'san', 'diego'],
#  ['duke', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'alberta'],
#  ['duke', 'univers'],
#  ['linux', 'foundat'],
#  ['googl'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'colorado', 'boulder'],
#  ['northwestern', 'univers'],
#  ['universiteit', 'leiden'],
#  ['univers', 'colorado', 'system'],
#  ['palo', 'alto', 'network'],
#  ['rice', 'univers'],
#  ['univers', 'geneva'],
#  ['john', 'hopkin', 'univers'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'california', 'irvin'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['michigan', 'state', 'univers'],
#  ['univers', 'toronto'],
#  ['scienc'],
#  ['univers', 'sydney'],
#  ['univers', 'north', 'carolina', 'chapel', 'hill'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'colorado', 'boulder'],
#  ['mathwork'],
#  ['state', 'univers', 'new', 'york'],
#  ['googl', 'cloud'],
#  ['univers', 'minnesota'],
#  ['learn', 'develop', 'fund'],
#  ['bcg'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['universit', 'bocconi'],
#  ['stanford', 'univers'],
#  ['univers', 'london'],
#  ['eindhoven', 'univers', 'technolog'],
#  ['duke', 'univers'],
#  ['duke', 'univers'],
#  ['univers', 'michigan'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'virginia'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['ibm'],
#  ['univers', 'michigan'],
#  ['univers', 'amsterdam'],
#  ['univers', 'colorado', 'system'],
#  ['john', 'hopkin', 'univers'],
#  ['institut', 'futur'],
#  ['univers', 'minnesota'],
#  ['univers', 'minnesota'],
#  ['univers', 'alberta'],
#  ['duke', 'univers'],
#  ['essec', 'busi', 'school'],
#  ['univers', 'colorado', 'system'],
#  ['univers', 'edinburgh'],
#  ['univers', 'minnesota'],
#  ['goldsmith', 'univers', 'london'],
#  ['universiteit', 'leiden'],
#  ['universidad', 'estadu', 'campina'],
#  ['univers', 'pennsylvania'],
#  ['yale', 'univers'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['essec', 'busi', 'school'],
#  [],
#  [],
#  ['univers', 'california', 'davi'],
#  ['west', 'virginia', 'univers'],
#  ['hubspot', 'academi'],
#  ['univers', 'alberta'],
#  ['northwestern', 'univers'],
#  ['univers', 'colorado', 'system'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'california', 'davi'],
#  ['universiteit', 'leiden'],
#  ['googl', 'cloud'],
#  ['univers', 'toronto'],
#  ['deeplearn'],
#  ['universidad', 'and'],
#  ['california', 'institut', 'art'],
#  ['googl', 'cloud'],
#  ['univers', 'system', 'georgia'],
#  ['univers', 'system', 'georgia'],
#  ['univers', 'michigan'],
#  ['cole', 'polytechniqu', 'rale', 'lausann'],
#  ['copenhagen', 'busi', 'school'],
#  ['northwestern', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['columbia', 'univers'],
#  ['wesleyan', 'univers'],
#  ['stanford', 'univers'],
#  ['univers', 'alberta'],
#  ['univers', 'minnesota'],
#  ['univers', 'alberta'],
#  ['univers', 'alberta'],
#  ['state', 'univers', 'new', 'york'],
#  ['berkle', 'colleg', 'music'],
#  ['crece', 'con', 'googl'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'california', 'davi'],
#  ['georgia', 'institut', 'technolog'],
#  ['northwestern', 'univers'],
#  ['duke', 'univers'],
#  ['stanford', 'univers'],
#  ['stanford', 'univers'],
#  ['imperi', 'colleg', 'london'],
#  ['univers', 'michigan'],
#  ['duke', 'univers'],
#  ['stanford', 'univers'],
#  ['essec', 'busi', 'school'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['copenhagen', 'busi', 'school'],
#  ['copenhagen', 'busi', 'school'],
#  ['fundação', 'instituto', 'administração'],
#  ['macquari', 'univers'],
#  ['ies', 'busi', 'school'],
#  ['deeplearn'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'michigan'],
#  ['john', 'hopkin', 'univers'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['new', 'york', 'institut', 'financ'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['georgia', 'institut', 'technolog'],
#  ['ucl', 'institut', 'educ'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['univers', 'copenhagen'],
#  ['learnquest'],
#  ['googl'],
#  ['icahn', 'school', 'medicin', 'mount', 'sinai'],
#  ['john', 'hopkin', 'univers'],
#  ['arizona', 'state', 'univers'],
#  ['arizona', 'state', 'univers'],
#  ['arizona', 'state', 'univers'],
#  ['arizona', 'state', 'univers'],
#  ['relay', 'graduat', 'school', 'educ'],
#  ['univers', 'colorado', 'boulder'],
#  ['googl'],
#  ['deeplearn'],
#  ['deeplearn'],
#  ['universiteit', 'leiden'],
#  ['emori', 'univers'],
#  ['berkle', 'colleg', 'music'],
#  ['northwestern', 'univers'],
#  ['univers', 'toronto'],
#  ['googl'],
#  ['univers', 'pennsylvania'],
#  ['berkle', 'colleg', 'music'],
#  ['universiteit', 'leiden'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['berkle', 'colleg', 'music'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['yale', 'univers'],
#  ['univers', 'florida'],
#  ['birkbeck', 'univers', 'london'],
#  ['univers', 'virginia'],
#  ['univers', 'virginia'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['american', 'museum', 'natur', 'histori'],
#  ['univers', 'michigan'],
#  ['univers', 'florida'],
#  ['yale', 'univers'],
#  ['berkle', 'colleg', 'music'],
#  ['univers', 'toronto'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'copenhagen'],
#  ['univers', 'colorado', 'boulder'],
#  ['berkle', 'colleg', 'music'],
#  ['univers', 'edinburgh'],
#  ['cole', 'pont', 'paristech'],
#  ['duke', 'univers'],
#  ['ibm'],
#  ['indian', 'school', 'busi'],
#  ['unsw', 'sydney', 'univers', 'new', 'south', 'wale'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'geneva'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'california', 'irvin'],
#  ['california', 'institut', 'art'],
#  ['california', 'institut', 'art'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'cape', 'town'],
#  ['stanford', 'univers'],
#  ['yale', 'univers'],
#  ['american', 'institut', 'busi', 'econom'],
#  ['tel', 'aviv', 'univers'],
#  ['soa', 'univers', 'london'],
#  ['univers', 'michigan'],
#  ['univers', 'chicago'],
#  ['uniti'],
#  ['uniti'],
#  ['univers', 'hong', 'kong'],
#  ['univers', 'amsterdam'],
#  ['univers', 'michigan'],
#  ['univers', 'minnesota'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['googl'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['atlassian'],
#  ['univers', 'pennsylvania'],
#  ['goldsmith', 'univers', 'london'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['emori', 'univers'],
#  ['museum', 'modern', 'art'],
#  ['ucl', 'institut', 'educ'],
#  ['univers', 'pennsylvania'],
#  ['ibm'],
#  ['northwestern', 'univers'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'pennsylvania'],
#  ['michigan', 'state', 'univers'],
#  ['georgia', 'institut', 'technolog'],
#  ['michigan', 'state', 'univers'],
#  ['stanford', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'toronto'],
#  ['ies', 'busi', 'school'],
#  ['cole', 'polytechniqu'],
#  ['univers', 'california', 'irvin'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['learn', 'develop', 'fund'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom'],
#  ['learn', 'develop', 'fund'],
#  ['learn', 'develop', 'fund'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom'],
#  ['learn', 'develop', 'fund'],
#  ['moscow', 'institut', 'physic', 'technolog'],
#  ['mail', 'group'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['learn', 'develop', 'fund'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom']]

# %%
removed_organisation_indices=[]
str_organisation_sanitised=[]
for i,content in enumerate(str_organisation):
  if len(content)!=0:
    str_organisation_sanitised.append(content)
  else:
    removed_organisation_indices.append(i)

# %%
docs_organisation=" ".join(joined_organisation)
docs_organisation
# Out:
# 'isc pennsylvania univers univers busi buffalo deeplearn deeplearn ibm deeplearn deeplearn deeplearn servic servic servic servic servic toronto irvin champaign isc pennsylvania michigan pennsylvania xico univers boulder ibm econom cloud rotterdam univers univers virginia virginia atlassian scrumtrek diego univers system univers pennsylvania school irvin univers michigan univers michigan pennsylvania univers edinburgh univers xico dtu ibm ibm michigan michigan michigan austral xico diego cloud cloud cloud univers art art strategi bocconi virginia edinburgh chile davi autodesk autodesk autodesk autodesk univers amsterdam cruz cruz share univers system univers town univers michigan barcelona univers diego univers boulder buffalo insead insead academi pari school school irvin alberta jerusalem cloud cloud cloud cloud pari pennsylvania univers washington washington pennsylvania pari univers pennsylvania virginia busi cloud boulder pennsylvania cruz system univers osmos
 'univers'],
#  ['univers', 'virginia'],
#  ['univers', 'virginia'],
#  ['atlassian'],
#  ['scrumtrek'],
#  ['univers', 'california', 'san', 'diego'],
#  ['stanford', 'univers'],
#  ['univers', 'colorado', 'system'],
#  ['yale', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['copenhagen', 'busi', 'school'],
#  ['univers', 'california', 'irvin'],
#  ['macquari', 'univers'],
#  ['univers', 'michigan'],
#  ['yale', 'univers'],
#  ['univers', 'michigan'],
#  ['univers', 'pennsylvania'],
#  ['vanderbilt', 'univers'],
#  ['univers', 'edinburgh'],
#  ['stanford', 'univers'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['technic', 'univers', 'denmark', 'dtu'],
#  ['ibm'],
#  ['ibm'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['universidad', 'austral'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['univers', 'california', 'san', 'diego'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['arizona', 'state', 'univers'],
#  ['museum', 'modern', 'art'],
#  ['museum', 'modern', 'art'],
#  ['nation', 'art', 'strategi'],
#  ['universit', 'bocconi'],
#  ['univers', 'virginia'],
#  ['univers', 'edinburgh'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['univers', 'california', 'davi'],
#  ['autodesk'],
#  ['autodesk'],
#  ['autodesk'],
#  ['autodesk'],
#  ['nation', 'taiwan', 'univers'],
#  ['univers', 'amsterdam'],
#  ['univers', 'california', 'santa', 'cruz'],
#  ['univers', 'california', 'santa', 'cruz'],
#  ['googl', 'spectrum', 'share'],
#  ['michigan', 'state', 'univers'],
#  ['univers', 'colorado', 'system'],
#  ['case', 'western', 'reserv', 'univers'],
#  ['univers', 'cape', 'town'],
#  ['duke', 'univers'],
#  ['univers', 'michigan'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['emori', 'univers'],
#  ['univers', 'california', 'san', 'diego'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'buffalo'],
#  ['insead'],
#  ['insead'],
#  ['consensi', 'academi'],
#  ['hec', 'pari'],
#  ['london', 'busi', 'school'],
#  ['busi', 'school'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'alberta'],
#  ['hebrew', 'univers', 'jerusalem'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['hec', 'pari'],
#  ['univers', 'pennsylvania'],
#  ['arizona', 'state', 'univers'],
#  ['univers', 'washington'],
#  ['univers', 'washington'],
#  ['univers', 'pennsylvania'],
#  ['hec', 'pari'],
#  ['rice', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'virginia'],
#  ['indian', 'school', 'busi'],
#  ['googl', 'cloud'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'california', 'santa', 'cruz'],
#  ['univers', 'colorado', 'system'],
#  ['john', 'hopkin', 'univers'],
#  ['osmosi'],
#  ['michigan', 'state', 'univers'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['univers', 'michigan'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'lausann'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'edinburgh'],
#  ['stanford', 'univers'],
#  ['peke', 'univers'],
#  ['cisco'],
#  ['univers', 'amsterdam'],
#  ['ies', 'busi', 'school'],
#  ['yale', 'univers'],
#  ['univers', 'pittsburgh'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['learnquest'],
#  ['googl', 'cloud'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'edinburgh'],
#  ['rice', 'univers'],
#  ['univers', 'toronto'],
#  ['univers', 'colorado', 'boulder'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['ludwig', 'maximilian', 'universität', 'münchen', 'lmu'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'colorado', 'system'],
#  ['univers', 'california', 'irvin'],
#  ['columbia', 'univers'],
#  ['columbia', 'univers'],
#  ['columbia', 'univers'],
#  ['columbia', 'univers'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['northwestern', 'univers'],
#  ['univers', 'virginia'],
#  ['georgia', 'institut', 'technolog'],
#  ['deeplearn'],
#  ['deeplearn'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['ies', 'busi', 'school'],
#  ['ucl', 'school', 'manag'],
#  ['universit', 'bocconi'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['univers', 'virginia'],
#  ['universidad', 'chile'],
#  ['googl'],
#  ['univers', 'minnesota'],
#  ['wesleyan', 'univers'],
#  ['wesleyan', 'univers'],
#  ['arizona', 'state', 'univers'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['universidad', 'chile'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'new', 'mexico'],
#  ['northwestern', 'univers'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['univers', 'system', 'georgia'],
#  ['univers', 'colorado', 'system'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['pennsylvania', 'state', 'univers'],
#  ['wesleyan', 'univers'],
#  ['pwc'],
#  ['ibm'],
#  ['univers', 'amsterdam'],
#  ['univers', 'michigan'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['vanderbilt', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['john', 'hopkin', 'univers'],
#  ['duke', 'univers'],
#  ['ibm'],
#  ['john', 'hopkin', 'univers'],
#  ['john', 'hopkin', 'univers'],
#  ['duke', 'univers'],
#  ['pwc'],
#  ['ibm'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'colorado', 'system'],
#  ['john', 'hopkin', 'univers'],
#  ['pwc'],
#  ['ibm'],
#  ['universiteit', 'leiden'],
#  ['univers', 'pennsylvania'],
#  ['deeplearn'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['univers', 'michigan'],
#  ['novosibirsk', 'state', 'univers'],
#  ['univers', 'virginia'],
#  ['univers', 'virginia'],
#  ['john', 'hopkin', 'univers'],
#  ['michigan', 'state', 'univers'],
#  ['univers', 'sydney'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['univers', 'colorado', 'boulder'],
#  ['berkle', 'colleg', 'music'],
#  ['berkle', 'colleg', 'music'],
#  ['ticket', 'chang'],
#  ['univers', 'colorado', 'boulder'],
#  ['lund', 'univers'],
#  ['univers', 'buffalo'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'virginia'],
#  ['univers', 'virginia'],
#  ['univers', 'alberta'],
#  ['univers', 'melbourn'],
#  ['tecnológico', 'monterrey'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['stanford', 'univers'],
#  ['duke', 'univers'],
#  ['erasmu', 'univers', 'rotterdam'],
#  ['univers', 'california', 'san', 'diego'],
#  ['univers', 'california', 'san', 'diego'],
#  ['univers', 'washington'],
#  ['univers', 'colorado', 'system'],
#  ['american', 'museum', 'natur', 'histori'],
#  ['erasmu', 'univers', 'rotterdam'],
#  ['columbia', 'univers'],
#  ['univers', 'geneva'],
#  ['univers', 'pennsylvania'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['universidad', 'austral'],
#  ['googl', 'cloud'],
#  ['duke', 'univers'],
#  ['berkle', 'colleg', 'music'],
#  ['yonsei', 'univers'],
#  ['univers', 'buffalo'],
#  ['new', 'york', 'univers'],
#  ['rice', 'univers'],
#  ['duke', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['moscow', 'institut', 'physic', 'technolog'],
#  ['univers', 'pennsylvania'],
#  ['peter', 'great', 'petersburg', 'polytechn', 'univers'],
#  ['duke', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['hec', 'pari'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['pennsylvania', 'state', 'univers'],
#  ['univers', 'pittsburgh'],
#  ['imperi', 'colleg', 'london'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'north', 'carolina', 'chapel', 'hill'],
#  ['univers', 'melbourn'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'california', 'irvin'],
#  ['john', 'hopkin', 'univers'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['georg', 'washington', 'univers'],
#  ['univers', 'melbourn'],
#  ['yale', 'univers'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['univers', 'colorado', 'boulder'],
#  ['yale', 'univers'],
#  ['macquari', 'univers'],
#  ['macquari', 'univers'],
#  ['macquari', 'univers'],
#  ['macquari', 'univers'],
#  ['macquari', 'univers'],
#  ['duke', 'univers'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'colorado', 'boulder'],
#  ['john', 'hopkin', 'univers'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['museum', 'modern', 'art'],
#  ['univers', 'california', 'santa', 'cruz'],
#  ['duke', 'univers'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['rice', 'univers'],
#  ['emori', 'univers'],
#  ['univers', 'virginia'],
#  ['univers', 'pennsylvania'],
#  ['columbia', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['yale', 'univers'],
#  ['indian', 'school', 'busi'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'michigan'],
#  ['universit', 'bocconi'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['univers', 'michigan'],
#  ['univers', 'pennsylvania'],
#  ['yonsei', 'univers'],
#  ['universit', 'bocconi'],
#  ['west', 'virginia', 'univers'],
#  ['universidad', 'and'],
#  ['univers', 'michigan'],
#  ['univers', 'virginia'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['john', 'hopkin', 'univers'],
#  ['ies', 'busi', 'school'],
#  ['emori', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['imperi', 'colleg', 'london'],
#  ['googl', 'cloud'],
#  ['univers', 'tokyo'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['cole', 'polytechniqu', 'rale', 'lausann'],
#  ['cole', 'polytechniqu', 'rale', 'lausann'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['rice', 'univers'],
#  ['georgia', 'institut', 'technolog'],
#  ['univers', 'california', 'davi'],
#  ['california', 'institut', 'art'],
#  ['rice', 'univers'],
#  ['rice', 'univers'],
#  ['univers', 'edinburgh'],
#  ['univers', 'virginia'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'alberta'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'pennsylvania'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['universidad', 'austral'],
#  ['universidad', 'and'],
#  ['tecnológico', 'monterrey'],
#  ['univers', 'california', 'davi'],
#  ['institut', 'futur'],
#  ['googl', 'cloud'],
#  ['univers', 'toronto'],
#  ['michigan', 'state', 'univers'],
#  ['stanford', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pittsburgh'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'california', 'davi'],
#  ['scienc'],
#  ['esad', 'busi', 'law', 'school'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['bloomsburi', 'learn', 'exchang'],
#  ['michigan', 'state', 'univers'],
#  ['amazon', 'web', 'servic'],
#  ['univers', 'california', 'irvin'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['soa', 'univers', 'london'],
#  ['soa', 'univers', 'london'],
#  ['soa', 'univers', 'london'],
#  ['technic', 'univers', 'denmark', 'dtu'],
#  ['rice', 'univers'],
#  ['edhec', 'busi', 'school'],
#  ['univers', 'pennsylvania'],
#  ['busi', 'school'],
#  ['univers', 'michigan'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['googl'],
#  ['googl'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'pennsylvania'],
#  ['lund', 'univers'],
#  ['berkle', 'colleg', 'music'],
#  ['univers', 'california', 'san', 'diego'],
#  ['john', 'hopkin', 'univers'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'florida'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'minnesota'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['northwestern', 'univers'],
#  ['univers', 'colorado', 'system'],
#  ['essec', 'busi', 'school'],
#  ['univers', 'virginia'],
#  ['state', 'univers', 'new', 'york'],
#  ['michigan', 'state', 'univers'],
#  ['univers', 'minnesota'],
#  ['ibm'],
#  ['ibm'],
#  ['ibm'],
#  ['ibm'],
#  ['ibm'],
#  ['ibm'],
#  ['googl'],
#  ['isc'],
#  ['busi', 'school'],
#  ['autom', 'anywher'],
#  ['georgia', 'institut', 'technolog'],
#  ['deeplearn'],
#  ['luther', 'colleg', 'univers', 'regina'],
#  ['museum', 'modern', 'art'],
#  ['univers', 'alberta'],
#  ['googl', 'cloud'],
#  ['imperi', 'colleg', 'london'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['macquari', 'univers'],
#  ['royal', 'holloway', 'univers', 'london'],
#  ['new', 'york', 'univers'],
#  ['univers', 'minnesota'],
#  ['univers', 'california', 'irvin'],
#  ['erasmu', 'univers', 'rotterdam'],
#  ['univers', 'sydney'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['hec', 'pari'],
#  ['case', 'western', 'reserv', 'univers'],
#  ['univers', 'michigan'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'michigan'],
#  ['univers', 'minnesota'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'california', 'san', 'diego'],
#  ['escp', 'busi', 'school'],
#  ['univers', 'london'],
#  ['state', 'univers', 'new', 'york'],
#  ['kalshoven', 'giesk', 'forum'],
#  ['universiteit', 'leiden'],
#  ['universiteit', 'leiden'],
#  ['universit', 'bocconi'],
#  ['yonsei', 'univers'],
#  ['univers', 'geneva'],
#  ['erasmu', 'univers', 'rotterdam'],
#  ['stanford', 'univers'],
#  ['scienc'],
#  ['cisco'],
#  ['univers', 'chicago'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['pontificia', 'universidad', 'católica', 'chile'],
#  ['univers', 'geneva'],
#  ['berkle', 'colleg', 'music'],
#  ['ibm'],
#  ['univers', 'california', 'san', 'diego'],
#  ['insead'],
#  ['yale', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'michigan'],
#  ['univers', 'sydney'],
#  ['duke', 'univers'],
#  ['yale', 'univers'],
#  ['ibm'],
#  ['goldsmith', 'univers', 'london'],
#  ['goldsmith', 'univers', 'london'],
#  ['univers', 'pennsylvania'],
#  ['new', 'york', 'univers'],
#  ['new', 'york', 'univers'],
#  ['ibm'],
#  ['rice', 'univers'],
#  ['ibm'],
#  ['univers', 'michigan'],
#  ['univers', 'pennsylvania'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom'],
#  ['georgia', 'institut', 'technolog'],
#  ['univers', 'colorado', 'boulder'],
#  ['georgia', 'institut', 'technolog'],
#  ['univers', 'north', 'carolina', 'chapel', 'hill'],
#  ['univers', 'pennsylvania'],
#  ['nanyang', 'technolog', 'univers', 'singapor'],
#  ['michigan', 'state', 'univers'],
#  ['duke', 'univers'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'michigan'],
#  ['california', 'institut', 'art'],
#  ['univers', 'pennsylvania'],
#  ['case', 'western', 'reserv', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['stanford', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'virginia'],
#  ['univers', 'edinburgh'],
#  ['edhec', 'busi', 'school'],
#  ['duke', 'univers'],
#  ['duke', 'univers'],
#  ['vanderbilt', 'univers'],
#  ['yale', 'univers'],
#  ['rice', 'univers'],
#  ['univers', 'toronto'],
#  ['univers', 'pennsylvania'],
#  ['imperi', 'colleg', 'london'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['john', 'hopkin', 'univers'],
#  ['unsw', 'sydney', 'univers', 'new', 'south', 'wale'],
#  ['deeplearn'],
#  ['univers', 'michigan'],
#  ['new', 'york', 'institut', 'financ'],
#  ['california', 'institut', 'art'],
#  ['georgia', 'institut', 'technolog'],
#  ['univers', 'michigan'],
#  ['univers', 'california', 'davi'],
#  ['john', 'hopkin', 'univers'],
#  ['duke', 'univers'],
#  ['universidad', 'são', 'paulo'],
#  ['universidad', 'são', 'paulo'],
#  ['univers', 'geneva'],
#  ['edhec', 'busi', 'school'],
#  ['rice', 'univers'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['duke', 'univers'],
#  ['duke', 'univers'],
#  ['univers', 'cape', 'town'],
#  ['jetbrain'],
#  ['essec', 'busi', 'school'],
#  ['essec', 'busi', 'school'],
#  ['rice', 'univers'],
#  ['copenhagen', 'busi', 'school'],
#  ['georg', 'washington', 'univers'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['macquari', 'univers'],
#  ['peke', 'univers'],
#  ['tsinghua', 'univers'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['shanghai', 'jiao', 'tong', 'univers'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'toronto'],
#  ['yonsei', 'univers'],
#  ['unsw', 'sydney', 'univers', 'new', 'south', 'wale'],
#  ['busi', 'school'],
#  ['essec', 'busi', 'school'],
#  ['universidad', 'and'],
#  ['georgia', 'institut', 'technolog'],
#  ['stanford', 'univers'],
#  ['univers', 'washington'],
#  ['stanford', 'univers'],
#  ['univers', 'washington'],
#  ['new', 'york', 'univers'],
#  ['univers', 'london'],
#  ['googl', 'cloud'],
#  ['googl', 'cloud'],
#  ['ibm'],
#  ['googl', 'cloud'],
#  ['universitat', 'barcelona'],
#  ['school', 'architectur', 'design'],
#  ['universit', 'bocconi'],
#  ['univers', 'virginia'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['hec', 'pari'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'toronto'],
#  ['univers', 'california', 'davi'],
#  ['universidad', 'são', 'paulo'],
#  ['universidad', 'austral'],
#  ['universidad', 'chile'],
#  ['busi', 'school'],
#  ['busi', 'school'],
#  ['universidad', 'and'],
#  ['tecnológico', 'monterrey'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['duke', 'univers'],
#  ['learnquest'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'california', 'davi'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom'],
#  ['imperi', 'colleg', 'london'],
#  ['imperi', 'colleg', 'london'],
#  ['imperi', 'colleg', 'london'],
#  ['imperi', 'colleg', 'london'],
#  ['univers', 'colorado', 'boulder'],
#  ['duke', 'univers'],
#  ['wesleyan', 'univers'],
#  ['univers', 'amsterdam'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'pennsylvania'],
#  ['mcmaster', 'univers'],
#  ['universiteit', 'leiden'],
#  ['univers', 'michigan'],
#  ['univers', 'pennsylvania'],
#  ['museum', 'modern', 'art'],
#  ['cloudera'],
#  ['northwestern', 'univers'],
#  ['googl', 'cloud'],
#  ['yale', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'alberta'],
#  ['cole', 'polytechniqu', 'rale', 'lausann'],
#  ['berkle', 'colleg', 'music'],
#  ['berkle', 'colleg', 'music'],
#  ['berkle', 'colleg', 'music'],
#  ['duke', 'univers'],
#  ['deeplearn'],
#  ['univers', 'michigan'],
#  ['essec', 'busi', 'school'],
#  ['vmware'],
#  ['googl', 'cloud'],
#  ['deeplearn'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['univers', 'colorado', 'system'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['ludwig', 'maximilian', 'universität', 'münchen', 'lmu'],
#  ['univers', 'california', 'san', 'diego'],
#  ['duke', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'alberta'],
#  ['duke', 'univers'],
#  ['linux', 'foundat'],
#  ['googl'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'colorado', 'boulder'],
#  ['northwestern', 'univers'],
#  ['universiteit', 'leiden'],
#  ['univers', 'colorado', 'system'],
#  ['palo', 'alto', 'network'],
#  ['rice', 'univers'],
#  ['univers', 'geneva'],
#  ['john', 'hopkin', 'univers'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'california', 'irvin'],
#  ['universidad', 'nacion', 'autónoma', 'xico'],
#  ['michigan', 'state', 'univers'],
#  ['univers', 'toronto'],
#  ['scienc'],
#  ['univers', 'sydney'],
#  ['univers', 'north', 'carolina', 'chapel', 'hill'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'colorado', 'boulder'],
#  ['mathwork'],
#  ['state', 'univers', 'new', 'york'],
#  ['googl', 'cloud'],
#  ['univers', 'minnesota'],
#  ['learn', 'develop', 'fund'],
#  ['bcg'],
#  ['universitat', 'autònoma', 'barcelona'],
#  ['universit', 'bocconi'],
#  ['stanford', 'univers'],
#  ['univers', 'london'],
#  ['eindhoven', 'univers', 'technolog'],
#  ['duke', 'univers'],
#  ['duke', 'univers'],
#  ['univers', 'michigan'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'virginia'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['ibm'],
#  ['univers', 'michigan'],
#  ['univers', 'amsterdam'],
#  ['univers', 'colorado', 'system'],
#  ['john', 'hopkin', 'univers'],
#  ['institut', 'futur'],
#  ['univers', 'minnesota'],
#  ['univers', 'minnesota'],
#  ['univers', 'alberta'],
#  ['duke', 'univers'],
#  ['essec', 'busi', 'school'],
#  ['univers', 'colorado', 'system'],
#  ['univers', 'edinburgh'],
#  ['univers', 'minnesota'],
#  ['goldsmith', 'univers', 'london'],
#  ['universiteit', 'leiden'],
#  ['universidad', 'estadu', 'campina'],
#  ['univers', 'pennsylvania'],
#  ['yale', 'univers'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['essec', 'busi', 'school'],
#  ['univers', 'california', 'davi'],
#  ['west', 'virginia', 'univers'],
#  ['hubspot', 'academi'],
#  ['univers', 'alberta'],
#  ['northwestern', 'univers'],
#  ['univers', 'colorado', 'system'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'california', 'davi'],
#  ['universiteit', 'leiden'],
#  ['googl', 'cloud'],
#  ['univers', 'toronto'],
#  ['deeplearn'],
#  ['universidad', 'and'],
#  ['california', 'institut', 'art'],
#  ['googl', 'cloud'],
#  ['univers', 'system', 'georgia'],
#  ['univers', 'system', 'georgia'],
#  ['univers', 'michigan'],
#  ['cole', 'polytechniqu', 'rale', 'lausann'],
#  ['copenhagen', 'busi', 'school'],
#  ['northwestern', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['columbia', 'univers'],
#  ['wesleyan', 'univers'],
#  ['stanford', 'univers'],
#  ['univers', 'alberta'],
#  ['univers', 'minnesota'],
#  ['univers', 'alberta'],
#  ['univers', 'alberta'],
#  ['state', 'univers', 'new', 'york'],
#  ['berkle', 'colleg', 'music'],
#  ['crece', 'con', 'googl'],
#  ['univers', 'colorado', 'boulder'],
#  ['univers', 'california', 'davi'],
#  ['georgia', 'institut', 'technolog'],
#  ['northwestern', 'univers'],
#  ['duke', 'univers'],
#  ['stanford', 'univers'],
#  ['stanford', 'univers'],
#  ['imperi', 'colleg', 'london'],
#  ['univers', 'michigan'],
#  ['duke', 'univers'],
#  ['stanford', 'univers'],
#  ['essec', 'busi', 'school'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['copenhagen', 'busi', 'school'],
#  ['copenhagen', 'busi', 'school'],
#  ['fundação', 'instituto', 'administração'],
#  ['macquari', 'univers'],
#  ['ies', 'busi', 'school'],
#  ['deeplearn'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'michigan'],
#  ['john', 'hopkin', 'univers'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['new', 'york', 'institut', 'financ'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['rutger', 'state', 'univers', 'new', 'jersey'],
#  ['georgia', 'institut', 'technolog'],
#  ['ucl', 'institut', 'educ'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['univers', 'copenhagen'],
#  ['learnquest'],
#  ['googl'],
#  ['icahn', 'school', 'medicin', 'mount', 'sinai'],
#  ['john', 'hopkin', 'univers'],
#  ['arizona', 'state', 'univers'],
#  ['arizona', 'state', 'univers'],
#  ['arizona', 'state', 'univers'],
#  ['arizona', 'state', 'univers'],
#  ['relay', 'graduat', 'school', 'educ'],
#  ['univers', 'colorado', 'boulder'],
#  ['googl'],
#  ['deeplearn'],
#  ['deeplearn'],
#  ['universiteit', 'leiden'],
#  ['emori', 'univers'],
#  ['berkle', 'colleg', 'music'],
#  ['northwestern', 'univers'],
#  ['univers', 'toronto'],
#  ['googl'],
#  ['univers', 'pennsylvania'],
#  ['berkle', 'colleg', 'music'],
#  ['universiteit', 'leiden'],
#  ['univers', 'maryland', 'colleg', 'park'],
#  ['berkle', 'colleg', 'music'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'pennsylvania'],
#  ['yale', 'univers'],
#  ['univers', 'florida'],
#  ['birkbeck', 'univers', 'london'],
#  ['univers', 'virginia'],
#  ['univers', 'virginia'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'california', 'irvin'],
#  ['hong', 'kong', 'univers', 'scienc', 'technolog'],
#  ['american', 'museum', 'natur', 'histori'],
#  ['univers', 'michigan'],
#  ['univers', 'florida'],
#  ['yale', 'univers'],
#  ['berkle', 'colleg', 'music'],
#  ['univers', 'toronto'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'copenhagen'],
#  ['univers', 'colorado', 'boulder'],
#  ['berkle', 'colleg', 'music'],
#  ['univers', 'edinburgh'],
#  ['cole', 'pont', 'paristech'],
#  ['duke', 'univers'],
#  ['ibm'],
#  ['indian', 'school', 'busi'],
#  ['unsw', 'sydney', 'univers', 'new', 'south', 'wale'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'geneva'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'california', 'irvin'],
#  ['california', 'institut', 'art'],
#  ['california', 'institut', 'art'],
#  ['john', 'hopkin', 'univers'],
#  ['univers', 'cape', 'town'],
#  ['stanford', 'univers'],
#  ['yale', 'univers'],
#  ['american', 'institut', 'busi', 'econom'],
#  ['tel', 'aviv', 'univers'],
#  ['soa', 'univers', 'london'],
#  ['univers', 'michigan'],
#  ['univers', 'chicago'],
#  ['uniti'],
#  ['uniti'],
#  ['univers', 'hong', 'kong'],
#  ['univers', 'amsterdam'],
#  ['univers', 'michigan'],
#  ['univers', 'minnesota'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['googl'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['atlassian'],
#  ['univers', 'pennsylvania'],
#  ['goldsmith', 'univers', 'london'],
#  ['univers', 'california', 'irvin'],
#  ['univers', 'pennsylvania'],
#  ['univers', 'michigan'],
#  ['univers', 'michigan'],
#  ['emori', 'univers'],
#  ['museum', 'modern', 'art'],
#  ['ucl', 'institut', 'educ'],
#  ['univers', 'pennsylvania'],
#  ['ibm'],
#  ['northwestern', 'univers'],
#  ['univers', 'california', 'davi'],
#  ['univers', 'pennsylvania'],
#  ['michigan', 'state', 'univers'],
#  ['georgia', 'institut', 'technolog'],
#  ['michigan', 'state', 'univers'],
#  ['stanford', 'univers'],
#  ['univers', 'illinoi', 'urbana', 'champaign'],
#  ['univers', 'toronto'],
#  ['ies', 'busi', 'school'],
#  ['cole', 'polytechniqu'],
#  ['univers', 'california', 'irvin'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['learn', 'develop', 'fund'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom'],
#  ['learn', 'develop', 'fund'],
#  ['learn', 'develop', 'fund'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom'],
#  ['learn', 'develop', 'fund'],
#  ['moscow', 'institut', 'physic', 'technolog'],
#  ['mail', 'group'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['learn', 'develop', 'fund'],
#  ['saint', 'petersburg', 'state', 'univers'],
#  ['nation', 'research', 'univers', 'higher', 'school', 'econom']]

# %%
doc_orgs=[]
def convert_stng(data):
  text=""
  for i in data:
      text=text+" "+str(i)
  return(text.strip())
for i in str_organisation_sanitised:
  doc_orgs.append(convert_stng(i))
doc_orgs
# Out:
# ['isc',
#  'univers pennsylvania',
#  'john hopkin univers',
#  'yale univers',
#  'indian school busi',
#  'univers buffalo',
#  'deeplearn',
#  'deeplearn',
#  'ibm',
#  'deeplearn',
#  'deeplearn',
#  'deeplearn',
#  'amazon web servic',
#  'amazon web servic',
#  'amazon web servic',
#  'amazon web servic',
#  'amazon web servic',
#  'univers toronto',
#  'univers california irvin',
#  'univers illinoi urbana champaign',
#  'isc',
#  'univers pennsylvania',
#  'univers michigan',
#  'univers pennsylvania',
#  'universidad nacion autónoma xico',
#  'yale univers',
#  'univers colorado boulder',
#  'ibm',
#  'nation research univers higher school econom',
#  'googl cloud',
#  'erasmu univers rotterdam',
#  'duke univers',
#  'yale univers',
#  'univers virginia',
#  'univers virginia',
#  'atlassian',
#  'scrumtrek',
#  'univers california san diego',
#  'stanford univers',
#  'univers colorado system',
#  'yale univers',
#  'univers pennsylvania',
#  'copenhagen busi school',
#  'univers california irvin',
#  'macquari univers',
#  'univers michigan',
#  'yale univers',
#  'univers michigan',
#  'univers pennsylvania',
#  'vanderbilt univers',
#  'univers edinburgh',
#  'stanford univers',
#  'universidad nacion autónoma xico',
#  'technic univers denmark dtu',
#  'ibm',
#  'ibm',
#  'univers michigan',
#  'univers michigan',
#  'univers michigan',
#  'universidad austral',
#  'universidad nacion autónoma xico',
#  'univers california san diego',
#  'googl cloud',
#  'googl cloud',
#  'googl cloud',
#  'arizona state univers',
#  'museum modern art',
#  'museum modern art',
#  'nation art strategi',
#  'universit bocconi',
#  'univers virginia',
#  'univers edinburgh',
#  'pontificia universidad católica chile',
#  'univers california davi',
#  'autodesk',
#  'autodesk',
#  'autodesk',
#  'autodesk',
#  'nation taiwan univers',
#  'univers amsterdam',
#  'univers california santa cruz',
#  'univers california santa cruz',
#  'googl spectrum share',
#  'michigan state univers',
#  'univers colorado system',
#  'case western reserv univers',
#  'univers cape town',
#  'duke univers',
#  'univers michigan',
#  'universitat autònoma barcelona',
#  'emori univers',
#  'univers california san diego',
#  'john hopkin univers',
#  'univers colorado boulder',
#  'univers buffalo',
#  'insead',
#  'insead',
#  'consensi academi',
#  'hec pari',
#  'london busi school',
#  'busi school',
#  'univers california irvin',
#  'univers alberta',
#  'hebrew univers jerusalem',
#  'googl cloud',
#  'googl cloud',
#  'googl cloud',
#  'googl cloud',
#  'hec pari',
#  'univers pennsylvania',
#  'arizona state univers',
#  'univers washington',
#  'univers washington',
#  'univers pennsylvania',
#  'hec pari',
#  'rice univers',
#  'univers pennsylvania',
#  'univers virginia',
#  'indian school busi',
#  'googl cloud',
#  'univers colorado boulder',
#  'univers pennsylvania',
#  'univers california santa cruz',
#  'univers colorado system',
#  'john hopkin univers',
#  'osmosi',
#  'michigan state univers',
#  'pontificia universidad católica chile',
#  'univers michigan',
#  'univers california irvin',
#  'univers lausann',
#  'john hopkin univers',
#  'univers edinburgh',
#  'stanford univers',
#  'peke univers',
#  'cisco',
#  'univers amsterdam',
#  'ies busi school',
#  'yale univers',
#  'univers pittsburgh',
#  'univers illinoi urbana champaign',
#  'learnquest',
#  'googl cloud',
#  'univers california davi',
#  'univers edinburgh',
#  'rice univers',
#  'univers toronto',
#  'univers colorado boulder',
#  'universitat autònoma barcelona',
#  'ludwig maximilian universität münchen lmu',
#  'univers california davi',
#  'univers pennsylvania',
#  'univers colorado system',
#  'univers california irvin',
#  'columbia univers',
#  'columbia univers',
#  'columbia univers',
#  'columbia univers',
#  'universidad nacion autónoma xico',
#  'northwestern univers',
#  'univers virginia',
#  'georgia institut technolog',
#  'deeplearn',
#  'deeplearn',
#  'univers illinoi urbana champaign',
#  'ies busi school',
#  'ucl school manag',
#  'universit bocconi',
#  'universitat autònoma barcelona',
#  'univers virginia',
#  'universidad chile',
#  'googl',
#  'univers minnesota',
#  'wesleyan univers',
#  'wesleyan univers',
#  'arizona state univers',
#  'universidad nacion autónoma xico',
#  'universidad chile',
#  'univers pennsylvania',
#  'univers new mexico',
#  'northwestern univers',
#  'univers maryland colleg park',
#  'univers system georgia',
#  'univers colorado system',
#  'universitat autònoma barcelona',
#  'pennsylvania state univers',
#  'wesleyan univers',
#  'pwc',
#  'ibm',
#  'univers amsterdam',
#  'univers michigan',
#  'googl cloud',
#  'googl cloud',
#  'googl cloud',
#  'vanderbilt univers',
#  'univers illinoi urbana champaign',
#  'john hopkin univers',
#  'duke univers',
#  'ibm',
#  'john hopkin univers',
#  'john hopkin univers',
#  'duke univers',
#  'pwc',
#  'ibm',
#  'univers california davi',
#  'univers colorado system',
#  'john hopkin univers',
#  'pwc',
#  'ibm',
#  'universiteit leiden',
#  'univers pennsylvania',
#  'deeplearn',
#  'universitat autònoma barcelona',
#  'univers michigan',
#  'novosibirsk state univers',
#  'univers virginia',
#  'univers virginia',
#  'john hopkin univers',
#  'michigan state univers',
#  'univers sydney',
#  'googl cloud',
#  'googl cloud',
#  'googl cloud',
#  'univers colorado boulder',
#  'berkle colleg music',
#  'berkle colleg music',
#  'ticket chang',
#  'univers colorado boulder',
#  'lund univers',
#  'univers buffalo',
#  'univers illinoi urbana champaign',
#  'univers illinoi urbana champaign',
#  'univers virginia',
#  'univers virginia',
#  'univers alberta',
#  'univers melbourn',
#  'tecnológico monterrey',
#  'pontificia universidad católica chile',
#  'stanford univers',
#  'duke univers',
#  'erasmu univers rotterdam',
#  'univers california san diego',
#  'univers california san diego',
#  'univers washington',
#  'univers colorado system',
#  'american museum natur histori',
#  'erasmu univers rotterdam',
#  'columbia univers',
#  'univers geneva',
#  'univers pennsylvania',
#  'universitat autònoma barcelona',
#  'universidad austral',
#  'googl cloud',
#  'duke univers',
#  'berkle colleg music',
#  'yonsei univers',
#  'univers buffalo',
#  'new york univers',
#  'rice univers',
#  'duke univers',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'moscow institut physic technolog',
#  'univers pennsylvania',
#  'peter great petersburg polytechn univers',
#  'duke univers',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'hec pari',
#  'univers maryland colleg park',
#  'pennsylvania state univers',
#  'univers pittsburgh',
#  'imperi colleg london',
#  'john hopkin univers',
#  'univers north carolina chapel hill',
#  'univers melbourn',
#  'univers california davi',
#  'univers california irvin',
#  'john hopkin univers',
#  'googl cloud',
#  'googl cloud',
#  'georg washington univers',
#  'univers melbourn',
#  'yale univers',
#  'universidad nacion autónoma xico',
#  'universidad nacion autónoma xico',
#  'univers colorado boulder',
#  'yale univers',
#  'macquari univers',
#  'macquari univers',
#  'macquari univers',
#  'macquari univers',
#  'macquari univers',
#  'duke univers',
#  'univers colorado boulder',
#  'univers colorado boulder',
#  'john hopkin univers',
#  'pontificia universidad católica chile',
#  'museum modern art',
#  'univers california santa cruz',
#  'duke univers',
#  'hong kong univers scienc technolog',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'rice univers',
#  'emori univers',
#  'univers virginia',
#  'univers pennsylvania',
#  'columbia univers',
#  'univers illinoi urbana champaign',
#  'yale univers',
#  'indian school busi',
#  'univers illinoi urbana champaign',
#  'univers michigan',
#  'universit bocconi',
#  'universidad nacion autónoma xico',
#  'universidad nacion autónoma xico',
#  'univers michigan',
#  'univers pennsylvania',
#  'yonsei univers',
#  'universit bocconi',
#  'west virginia univers',
#  'universidad and',
#  'univers michigan',
#  'univers virginia',
#  'univers illinoi urbana champaign',
#  'john hopkin univers',
#  'ies busi school',
#  'emori univers',
#  'univers pennsylvania',
#  'imperi colleg london',
#  'googl cloud',
#  'univers tokyo',
#  'hong kong univers scienc technolog',
#  'hong kong univers scienc technolog',
#  'hong kong univers scienc technolog',
#  'hong kong univers scienc technolog',
#  'cole polytechniqu rale lausann',
#  'cole polytechniqu rale lausann',
#  'john hopkin univers',
#  'univers illinoi urbana champaign',
#  'rice univers',
#  'georgia institut technolog',
#  'univers california davi',
#  'california institut art',
#  'rice univers',
#  'rice univers',
#  'univers edinburgh',
#  'univers virginia',
#  'univers pennsylvania',
#  'univers alberta',
#  'univers california davi',
#  'univers pennsylvania',
#  'universidad nacion autónoma xico',
#  'universidad austral',
#  'universidad and',
#  'tecnológico monterrey',
#  'univers california davi',
#  'institut futur',
#  'googl cloud',
#  'univers toronto',
#  'michigan state univers',
#  'stanford univers',
#  'univers pennsylvania',
#  'univers pittsburgh',
#  'john hopkin univers',
#  'univers california davi',
#  'scienc',
#  'esad busi law school',
#  'pontificia universidad católica chile',
#  'bloomsburi learn exchang',
#  'michigan state univers',
#  'amazon web servic',
#  'univers california irvin',
#  'googl cloud',
#  'googl cloud',
#  'soa univers london',
#  'soa univers london',
#  'soa univers london',
#  'technic univers denmark dtu',
#  'rice univers',
#  'edhec busi school',
#  'univers pennsylvania',
#  'busi school',
#  'univers michigan',
#  'googl cloud',
#  'googl cloud',
#  'googl',
#  'googl',
#  'univers california irvin',
#  'univers colorado boulder',
#  'univers pennsylvania',
#  'lund univers',
#  'berkle colleg music',
#  'univers california san diego',
#  'john hopkin univers',
#  'universidad nacion autónoma xico',
#  'pontificia universidad católica chile',
#  'univers colorado boulder',
#  'univers florida',
#  'john hopkin univers',
#  'univers california davi',
#  'univers pennsylvania',
#  'univers minnesota',
#  'rutger state univers new jersey',
#  'northwestern univers',
#  'univers colorado system',
#  'essec busi school',
#  'univers virginia',
#  'state univers new york',
#  'michigan state univers',
#  'univers minnesota',
#  'ibm',
#  'ibm',
#  'ibm',
#  'ibm',
#  'ibm',
#  'ibm',
#  'googl',
#  'isc',
#  'busi school',
#  'autom anywher',
#  'georgia institut technolog',
#  'deeplearn',
#  'luther colleg univers regina',
#  'museum modern art',
#  'univers alberta',
#  'googl cloud',
#  'imperi colleg london',
#  'rutger state univers new jersey',
#  'macquari univers',
#  'royal holloway univers london',
#  'new york univers',
#  'univers minnesota',
#  'univers california irvin',
#  'erasmu univers rotterdam',
#  'univers sydney',
#  'univers illinoi urbana champaign',
#  'hec pari',
#  'case western reserv univers',
#  'univers michigan',
#  'univers illinoi urbana champaign',
#  'univers michigan',
#  'univers minnesota',
#  'univers pennsylvania',
#  'univers california san diego',
#  'escp busi school',
#  'univers london',
#  'state univers new york',
#  'kalshoven giesk forum',
#  'universiteit leiden',
#  'universiteit leiden',
#  'universit bocconi',
#  'yonsei univers',
#  'univers geneva',
#  'erasmu univers rotterdam',
#  'stanford univers',
#  'scienc',
#  'cisco',
#  'univers chicago',
#  'univers maryland colleg park',
#  'universidad nacion autónoma xico',
#  'pontificia universidad católica chile',
#  'univers geneva',
#  'berkle colleg music',
#  'ibm',
#  'univers california san diego',
#  'insead',
#  'yale univers',
#  'univers illinoi urbana champaign',
#  'univers michigan',
#  'univers sydney',
#  'duke univers',
#  'yale univers',
#  'ibm',
#  'goldsmith univers london',
#  'goldsmith univers london',
#  'univers pennsylvania',
#  'new york univers',
#  'new york univers',
#  'ibm',
#  'rice univers',
#  'ibm',
#  'univers michigan',
#  'univers pennsylvania',
#  'nation research univers higher school econom',
#  'georgia institut technolog',
#  'univers colorado boulder',
#  'georgia institut technolog',
#  'univers north carolina chapel hill',
#  'univers pennsylvania',
#  'nanyang technolog univers singapor',
#  'michigan state univers',
#  'duke univers',
#  'john hopkin univers',
#  'univers michigan',
#  'california institut art',
#  'univers pennsylvania',
#  'case western reserv univers',
#  'univers pennsylvania',
#  'stanford univers',
#  'univers pennsylvania',
#  'univers virginia',
#  'univers edinburgh',
#  'edhec busi school',
#  'duke univers',
#  'duke univers',
#  'vanderbilt univers',
#  'yale univers',
#  'rice univers',
#  'univers toronto',
#  'univers pennsylvania',
#  'imperi colleg london',
#  'univers illinoi urbana champaign',
#  'john hopkin univers',
#  'unsw sydney univers new south wale',
#  'deeplearn',
#  'univers michigan',
#  'new york institut financ',
#  'california institut art',
#  'georgia institut technolog',
#  'univers michigan',
#  'univers california davi',
#  'john hopkin univers',
#  'duke univers',
#  'universidad são paulo',
#  'universidad são paulo',
#  'univers geneva',
#  'edhec busi school',
#  'rice univers',
#  'saint petersburg state univers',
#  'duke univers',
#  'duke univers',
#  'univers cape town',
#  'jetbrain',
#  'essec busi school',
#  'essec busi school',
#  'rice univers',
#  'copenhagen busi school',
#  'georg washington univers',
#  'univers michigan',
#  'univers michigan',
#  'macquari univers',
#  'peke univers',
#  'tsinghua univers',
#  'univers california irvin',
#  'univers california irvin',
#  'univers california irvin',
#  'shanghai jiao tong univers',
#  'univers california davi',
#  'univers california davi',
#  'univers toronto',
#  'yonsei univers',
#  'unsw sydney univers new south wale',
#  'busi school',
#  'essec busi school',
#  'universidad and',
#  'georgia institut technolog',
#  'stanford univers',
#  'univers washington',
#  'stanford univers',
#  'univers washington',
#  'new york univers',
#  'univers london',
#  'googl cloud',
#  'googl cloud',
#  'ibm',
#  'googl cloud',
#  'universitat barcelona',
#  'school architectur design',
#  'universit bocconi',
#  'univers virginia',
#  'univers illinoi urbana champaign',
#  'hec pari',
#  'univers california irvin',
#  'univers pennsylvania',
#  'univers toronto',
#  'univers california davi',
#  'universidad são paulo',
#  'universidad austral',
#  'universidad chile',
#  'busi school',
#  'busi school',
#  'universidad and',
#  'tecnológico monterrey',
#  'univers illinoi urbana champaign',
#  'duke univers',
#  'learnquest',
#  'john hopkin univers',
#  'univers california davi',
#  'nation research univers higher school econom',
#  'imperi colleg london',
#  'imperi colleg london',
#  'imperi colleg london',
#  'imperi colleg london',
#  'univers colorado boulder',
#  'duke univers',
#  'wesleyan univers',
#  'univers amsterdam',
#  'univers illinoi urbana champaign',
#  'univers pennsylvania',
#  'mcmaster univers',
#  'universiteit leiden',
#  'univers michigan',
#  'univers pennsylvania',
#  'museum modern art',
#  'cloudera',
#  'northwestern univers',
#  'googl cloud',
#  'yale univers',
#  'univers pennsylvania',
#  'univers alberta',
#  'cole polytechniqu rale lausann',
#  'berkle colleg music',
#  'berkle colleg music',
#  'berkle colleg music',
#  'duke univers',
#  'deeplearn',
#  'univers michigan',
#  'essec busi school',
#  'vmware',
#  'googl cloud',
#  'deeplearn',
#  'saint petersburg state univers',
#  'univers maryland colleg park',
#  'univers colorado system',
#  'universidad nacion autónoma xico',
#  'ludwig maximilian universität münchen lmu',
#  'univers california san diego',
#  'duke univers',
#  'univers illinoi urbana champaign',
#  'univers alberta',
#  'duke univers',
#  'linux foundat',
#  'googl',
#  'univers pennsylvania',
#  'univers colorado boulder',
#  'northwestern univers',
#  'universiteit leiden',
#  'univers colorado system',
#  'palo alto network',
#  'rice univers',
#  'univers geneva',
#  'john hopkin univers',
#  'universitat autònoma barcelona',
#  'univers pennsylvania',
#  'univers california irvin',
#  'universidad nacion autónoma xico',
#  'michigan state univers',
#  'univers toronto',
#  'scienc',
#  'univers sydney',
#  'univers north carolina chapel hill',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'univers colorado boulder',
#  'mathwork',
#  'state univers new york',
#  'googl cloud',
#  'univers minnesota',
#  'learn develop fund',
#  'bcg',
#  'universitat autònoma barcelona',
#  'universit bocconi',
#  'stanford univers',
#  'univers london',
#  'eindhoven univers technolog',
#  'duke univers',
#  'duke univers',
#  'univers michigan',
#  'univers california irvin',
#  'univers california irvin',
#  'univers california irvin',
#  'univers california irvin',
#  'univers california irvin',
#  'john hopkin univers',
#  'univers virginia',
#  'univers michigan',
#  'univers michigan',
#  'univers michigan',
#  'univers michigan',
#  'hong kong univers scienc technolog',
#  'ibm',
#  'univers michigan',
#  'univers amsterdam',
#  'univers colorado system',
#  'john hopkin univers',
#  'institut futur',
#  'univers minnesota',
#  'univers minnesota',
#  'univers alberta',
#  'duke univers',
#  'essec busi school',
#  'univers colorado system',
#  'univers edinburgh',
#  'univers minnesota',
#  'goldsmith univers london',
#  'universiteit leiden',
#  'universidad estadu campina',
#  'univers pennsylvania',
#  'yale univers',
#  'saint petersburg state univers',
#  'saint petersburg state univers',
#  'essec busi school',
#  'univers california davi',
#  'west virginia univers',
#  'hubspot academi',
#  'univers alberta',
#  'northwestern univers',
#  'univers colorado system',
#  'univers colorado boulder',
#  'univers california davi',
#  'univers california davi',
#  'universiteit leiden',
#  'googl cloud',
#  'univers toronto',
#  'deeplearn',
#  'universidad and',
#  'california institut art',
#  'googl cloud',
#  'univers system georgia',
#  'univers system georgia',
#  'univers michigan',
#  'cole polytechniqu rale lausann',
#  'copenhagen busi school',
#  'northwestern univers',
#  'univers pennsylvania',
#  'columbia univers',
#  'wesleyan univers',
#  'stanford univers',
#  'univers alberta',
#  'univers minnesota',
#  'univers alberta',
#  'univers alberta',
#  'state univers new york',
#  'berkle colleg music',
#  'crece con googl',
#  'univers colorado boulder',
#  'univers california davi',
#  'georgia institut technolog',
#  'northwestern univers',
#  'duke univers',
#  'stanford univers',
#  'stanford univers',
#  'imperi colleg london',
#  'univers michigan',
#  'duke univers',
#  'stanford univers',
#  'essec busi school',
#  'univers california irvin',
#  'univers illinoi urbana champaign',
#  'copenhagen busi school',
#  'copenhagen busi school',
#  'fundação instituto administração',
#  'macquari univers',
#  'ies busi school',
#  'deeplearn',
#  'univers pennsylvania',
#  'univers michigan',
#  'john hopkin univers',
#  'rutger state univers new jersey',
#  'new york institut financ',
#  'rutger state univers new jersey',
#  'rutger state univers new jersey',
#  'rutger state univers new jersey',
#  'georgia institut technolog',
#  'ucl institut educ',
#  'univers maryland colleg park',
#  'univers copenhagen',
#  'learnquest',
#  'googl',
#  'icahn school medicin mount sinai',
#  'john hopkin univers',
#  'arizona state univers',
#  'arizona state univers',
#  'arizona state univers',
#  'arizona state univers',
#  'relay graduat school educ',
#  'univers colorado boulder',
#  'googl',
#  'deeplearn',
#  'deeplearn',
#  'universiteit leiden',
#  'emori univers',
#  'berkle colleg music',
#  'northwestern univers',
#  'univers toronto',
#  'googl',
#  'univers pennsylvania',
#  'berkle colleg music',
#  'universiteit leiden',
#  'univers maryland colleg park',
#  'berkle colleg music',
#  'john hopkin univers',
#  'univers pennsylvania',
#  'yale univers',
#  'univers florida',
#  'birkbeck univers london',
#  'univers virginia',
#  'univers virginia',
#  'univers pennsylvania',
#  'univers california irvin',
#  'univers california irvin',
#  'univers california irvin',
#  'hong kong univers scienc technolog',
#  'american museum natur histori',
#  'univers michigan',
#  'univers florida',
#  'yale univers',
#  'berkle colleg music',
#  'univers toronto',
#  'univers california davi',
#  'univers copenhagen',
#  'univers colorado boulder',
#  'berkle colleg music',
#  'univers edinburgh',
#  'cole pont paristech',
#  'duke univers',
#  'ibm',
#  'indian school busi',
#  'unsw sydney univers new south wale',
#  'univers california irvin',
#  'univers geneva',
#  'univers illinoi urbana champaign',
#  'univers california irvin',
#  'california institut art',
#  'california institut art',
#  'john hopkin univers',
#  'univers cape town',
#  'stanford univers',
#  'yale univers',
#  'american institut busi econom',
#  'tel aviv univers',
#  'soa univers london',
#  'univers michigan',
#  'univers chicago',
#  'uniti',
#  'uniti',
#  'univers hong kong',
#  'univers amsterdam',
#  'univers michigan',
#  'univers minnesota',
#  'univers michigan',
#  'univers michigan',
#  'googl',
#  'univers illinoi urbana champaign',
#  'atlassian',
#  'univers pennsylvania',
#  'goldsmith univers london',
#  'univers california irvin',
#  'univers pennsylvania',
#  'univers michigan',
#  'univers michigan',
#  'emori univers',
#  'museum modern art',
#  'ucl institut educ',
#  'univers pennsylvania',
#  'ibm',
#  'northwestern univers',
#  'univers california davi',
#  'univers pennsylvania',
#  'michigan state univers',
#  'georgia institut technolog',
#  'michigan state univers',
#  'stanford univers',
#  'univers illinoi urbana champaign',
#  'univers toronto',
#  'ies busi school',
#  'cole polytechniqu',
#  'univers california irvin',
#  'saint petersburg state univers',
#  'learn develop fund',
#  'nation research univers higher school econom',
#  'learn develop fund',
#  'learn develop fund',
#  'nation research univers higher school econom',
#  'nation research univers higher school econom',
#  'learn develop fund',
#  'moscow institut physic technolog',
#  'mail group',
#  'saint petersburg state univers',
#  'learn develop fund',
#  'saint petersburg state univers',
#  'nation research univers higher school econom']

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer2 = CountVectorizer()
bog_vector= vectorizer2.fit_transform(doc_orgs)
vectorizer2.get_feature_names_out()
# Out:
# array(['academi', 'administração', 'alberta', 'alto', 'amazon',
#        'american', 'amsterdam', 'and', 'anywher', 'architectur',
#        'arizona', 'art', 'atlassian', 'austral', 'autodesk', 'autom',
#        'autònoma', 'autónoma', 'aviv', 'barcelona', 'bcg', 'berkle',
#        'birkbeck', 'bloomsburi', 'bocconi', 'boulder', 'buffalo', 'busi',
#        'california', 'campina', 'cape', 'carolina', 'case', 'católica',
#        'champaign', 'chang', 'chapel', 'chicago', 'chile', 'cisco',
#        'cloud', 'cloudera', 'cole', 'colleg', 'colorado', 'columbia',
#        'con', 'consensi', 'copenhagen', 'crece', 'cruz', 'davi',
#        'deeplearn', 'denmark', 'design', 'develop', 'diego', 'dtu',
#        'duke', 'econom', 'edhec', 'edinburgh', 'educ', 'eindhoven',
#        'emori', 'erasmu', 'esad', 'escp', 'essec', 'estadu', 'exchang',
#        'financ', 'florida', 'forum', 'foundat', 'fund', 'fundação',
#        'futur', 'geneva', 'georg', 'georgia', 'giesk', 'goldsmith',
#        'googl', 'graduat', 'great', 'group', 'hebrew', 'hec', 'higher',
#        'hill', 'histori', 'holloway', 'hong', 'hopkin', 'hubspot', 'ibm',
#        'icahn', 'ies', 'illinoi', 'imperi', 'indian', 'insead',
#        'institut', 'instituto', 'irvin', 'isc', 'jersey', 'jerusalem',
#        'jetbrain', 'jiao', 'john', 'kalshoven', 'kong', 'lausann', 'law',
#        'learn', 'learnquest', 'leiden', 'linux', 'lmu', 'london',
#        'ludwig', 'lund', 'luther', 'macquari', 'mail', 'manag',
#        'maryland', 'mathwork', 'maximilian', 'mcmaster', 'medicin',
#        'melbourn', 'mexico', 'michigan', 'minnesota', 'modern',
#        'monterrey', 'moscow', 'mount', 'museum', 'music', 'münchen',
#        'nacion', 'nanyang', 'nation', 'natur', 'network', 'new', 'north',
#        'northwestern', 'novosibirsk', 'osmosi', 'palo', 'pari',
#        'paristech', 'park', 'paulo', 'peke', 'pennsylvania', 'peter',
#        'petersburg', 'physic', 'pittsburgh', 'polytechn', 'polytechniqu',
#        'pont', 'pontificia', 'pwc', 'rale', 'regina', 'relay', 'research',
#        'reserv', 'rice', 'rotterdam', 'royal', 'rutger', 'saint', 'san',
#        'santa', 'school', 'scienc', 'scrumtrek', 'servic', 'shanghai',
#        'share', 'sinai', 'singapor', 'soa', 'south', 'spectrum',
#        'stanford', 'state', 'strategi', 'sydney', 'system', 'são',
#        'taiwan', 'technic', 'technolog', 'tecnológico', 'tel', 'ticket',
#        'tokyo', 'tong', 'toronto', 'town', 'tsinghua', 'ucl', 'uniti',
#        'univers', 'universidad', 'universit', 'universitat',
#        'universiteit', 'universität', 'unsw', 'urbana', 'vanderbilt',
#        'virginia', 'vmware', 'wale', 'washington', 'web', 'wesleyan',
#        'west', 'western', 'xico', 'yale', 'yonsei', 'york'], dtype=object)

# %%
Organisation_bog=bog_vector.toarray()
Organisation_bog.shape
# Out:
# (888, 233)

# %%
numpy_Title
# Out:
# array([[list(['isc', 'system', 'secur', 'certifi', 'practition', 'sscp'])],
#        [list(['crash', 'cours', 'causal', 'infer', 'causal', 'effect', 'observ', 'data'])],
#        [list(['crash', 'cours', 'data', 'scienc'])],
#        [list(['law', 'student', 'toolkit'])],
#        [list(['life', 'happi', 'fulfil'])],
#        [list(['adhd', 'everyday', 'strategi', 'elementari', 'student'])],
#        [list(['everyon'])],
#        [list(['medic', 'treatment'])],
#        [list(['foundat', 'everyon'])],
#        [list(['medic', 'diagnosi'])],
#        [list(['medic', 'prognosi'])],
#        [list(['medicin'])],
#        [list(['fundament'])],
#        [list(['fundament', 'address', 'secur', 'risk'])],
#        [list(['fundament', 'build', 'serverless', 'applic'])],
#        [list(['fundament', 'cloud', 'nativ'])],
#        [list(['fundament', 'migrat', 'cloud'])],
#        [list(['aborigin', 'worldview', 'educ'])],
#        [list(['academ', 'english', 'write'])],
#        [list(['acceler', 'comput', 'scienc', 'fundament'])],
#        [list(['access', 'control'])],
#        [list(['account', 'analyt'])],
#        [list(['account', 'decis', 'make'])],
#        [list(['achiev', 'person', 'profession', 'success'])],
#        [list(['actualización', 'manejo', 'del', 'pacient', 'con', 'diabet', 'mellitu', 'tipo'])],
#        [list(['addict', 'treatment', 'clinic', 'skill', 'healthcar', 'provid'])],
#        [list(['advanc', 'busi', 'analyt'])],
#        [list(['advanc', 'data', 'scienc', 'ibm'])],
#        [list(['advanc', 'machin', 'learn'])],
#        [list(['advanc', 'machin', 'learn', 'tensorflow', 'googl', 'cloud', 'platform'])],
#        [list(['advanc', 'valuat', 'strategi', 'privat', 'equiti', 'ventur', 'capit'])],
#        [list(['advertis', 'societi'])],
#        [list(['age', 'cathedr'])],
#        [list(['agil', 'develop'])],
#        [list(['agil', 'meet', 'design', 'think'])],
#        [list(['agil', 'atlassian', 'jira'])],
#        [list(['agil', 'scrum', 'работе', 'над', 'проектами', 'продуктами'])],
#        [list(['algorithm', 'toolbox'])],
#        [list(['algorithm'])],
#        [list(['algorithm', 'batteri', 'manag', 'system'])],
#        [list(['american', 'contract', 'law'])],
#        [list(['introduct', 'american', 'law'])],
#        [list(['introduct', 'consum', 'neurosci', 'neuromarket'])],
#        [list(['introduct', 'program', 'internet', 'thing', 'iot'])],
#        [list(['analys', 'numer', 'digit', 'literaci'])],
#        [list(['anatomi'])],
#        [list(['anatomi', 'chest', 'abdomen', 'pelvi'])],
#        [list(['anatomi', 'musculoskelet', 'integumentari', 'system'])],
#        [list(['ancient', 'philosophi', 'aristotl', 'successor'])],
#        [list(['android', 'app', 'develop'])],
#        [list(['anim', 'behaviour', 'welfar'])],
#        [list(['antibiot', 'stewardship'])],
#        [list(['anticorrupción', 'introducción', 'concepto', 'perspectiva', 'práctica'])],
#        [list(['antimicrobi', 'resist', 'theori', 'method'])],
#        [list(['appli', 'data', 'scienc'])],
#        [list(['appli', 'data', 'scienc', 'capston'])],
#        [list(['appli', 'data', 'scienc', 'python'])],
#        [list(['appli', 'machin', 'learn', 'python'])],
#        [list(['appli', 'plot', 'chart', 'data', 'represent', 'python'])],
#        [list(['aprend', 'programar', 'con', 'python'])],
#        [list(['aprend'])],
#        [list(['aprendiendo', 'aprend', 'poderosa', 'herramienta', 'mental', 'con', 'que', 'podrá', 'dominar', 'tema', 'difícil', 'learn', 'learn'])],
#        [list(['architect', 'googl', 'cloud', 'platform', '日本語版'])],
#        [list(['architect', 'googl', 'comput', 'engin'])],
#        [list(['architect', 'googl', 'kubernet', 'engin', '日本語版'])],
#        [list(['arizona', 'state', 'univers', 'tesol'])],
#        [list(['art', 'activ', 'interact', 'strategi', 'engag', 'art'])],
#        [list(['art', 'idea', 'teach', 'theme'])],
#        [list(['art', 'cultur', 'strategi'])],
#        [list(['art', 'heritag', 'manag'])],
#        [list(['aspecto', 'básico', 'planificación', 'gestión', 'proyecto'])],
#        [list(['astrobiolog', 'search', 'extraterrestri', 'life'])],
#        [list(['atención', 'primaria', 'salud', 'desafío', 'enfermedad', 'transmis'])],
#        [list(['autism', 'spectrum', 'disord'])],
#        [list(['autodesk', 'cad', 'cam', 'manufactur'])],
#        [list(['autodesk', 'cad', 'cam', 'cae', 'mechan', 'engin'])],
#        [list(['autodesk', 'certifi', 'profession', 'autocad', 'design', 'draft', 'exam', 'prep'])],
#        [list(['autodesk', 'certifi', 'profession', 'revit', 'architectur', 'design', 'exam', 'prep'])],
#        [list(['bim', 'fundament', 'engin'])],
#        [list(['basic', 'statist'])],
#        [list(['bayesian', 'statist', 'concept', 'data', 'analysi'])],
#        [list(['bayesian', 'statist', 'techniqu', 'model'])],
#        [list(['becom', 'cbr', 'certifi', 'profession', 'instal', 'googl'])],
#        [list(['becom', 'journalist', 'report', 'news'])],
#        [list(['becom', 'sustain', 'busi', 'chang', 'agent'])],
#        [list(['becom', 'sport', 'agent'])],
#        [list(['becom', 'changemak', 'introduct', 'social', 'innov'])],
#        [list(['behavior', 'financ'])],
#        [list(['beyond', 'sustain', 'develop', 'goal', 'sdg', 'address', 'sustain', 'develop'])],
#        [list(['big', 'data', 'introducción', 'uso', 'práctico', 'dato', 'masivo'])],
#        [list(['biohack', 'brain', 'health'])],
#        [list(['biolog', 'meet', 'program', 'bioinformat', 'beginn'])],
#        [list(['biostatist', 'public', 'health'])],
#        [list(['blend', 'languag', 'learn', 'design', 'practic', 'teacher'])],
#        [list(['blockchain'])],
#        [list(['blockchain', 'revolut'])],
#        [list(['blockchain', 'revolut', 'financi', 'servic'])],
#        [list(['blockchain', 'foundat', 'use', 'case'])],
#        [list(['boost', 'creativ', 'innov'])],
#        [list(['brand', 'manag', 'align', 'busi', 'brand', 'behaviour'])],
#        [list(['brand', 'creativ', 'journey'])],
#        [list(['budget', 'schedul', 'project'])],
#        [list(['bug', '101', 'insect', 'human', 'interact'])],
#        [list(['build', 'modern', 'comput', 'first', 'principl', 'nand', 'tetri', 'project', 'center', 'cours'])],
#        [list(['build', 'batch', 'data', 'pipelin', 'gcp'])],
#        [list(['build', 'convers', 'experi', 'dialogflow'])],
#        [list(['build', 'resili', 'stream', 'analyt', 'system', 'gcp'])],
#        [list(['build', 'scalabl', 'java', 'microservic', 'spring', 'boot', 'spring', 'cloud'])],
#        [list(['build', 'leadership', 'skill'])],
#        [list(['busi', 'analyt'])],
#        [list(['busi', 'english'])],
#        [list(['busi', 'english', 'commun', 'skill'])],
#        [list(['busi', 'english', 'network'])],
#        [list(['busi', 'foundat'])],
#        [list(['busi', 'model', 'innov'])],
#        [list(['busi', 'statist', 'analysi'])],
#        [list(['busi', 'strategi', 'better', 'world'])],
#        [list(['busi', 'strategi'])],
#        [list(['busi', 'technolog', 'manag'])],
#        [list(['busi', 'transform', 'googl', 'cloud'])],
#        [list(['busi', 'write'])],
#        [list(['busi', 'financi', 'model'])],
#        [list(['everyon', 'program', 'fundament'])],
#        [list(['program', 'uniti', 'game', 'develop'])],
#        [list(['covid', 'contact', 'trace'])],
#        [list(['covid', 'need', 'know', 'cme', 'elig'])],
#        [list(['camera', 'exposur', 'photographi'])],
#        [list(['camino', 'excelencia', 'gestión', 'proyecto'])],
#        [list(['capston', 'retriev', 'process', 'visual', 'data', 'python'])],
#        [list(['career', 'success'])],
#        [list(['challeng', 'forens', 'scienc', 'scienc', 'speak', 'court'])],
#        [list(['chemic', 'health'])],
#        [list(['chicken', 'behaviour', 'welfar'])],
#        [list(['child', 'nutrit', 'cook'])],
#        [list(['chines', 'hsk'])],
#        [list(['cisco', 'network', 'basic'])],
#        [list(['classic', 'sociolog', 'theori'])],
#        [list(['clave', 'dirección', 'empresa'])],
#        [list(['climat', 'chang', 'health', 'scienc', 'action'])],
#        [list(['clinic', 'terminolog', 'intern', 'student'])],
#        [list(['cloud', 'comput'])],
#        [list(['cloud', 'comput', 'basic', 'cloud', '101'])],
#        [list(['cloud', 'engin', 'googl', 'cloud'])],
#        [list(['coach', 'skill', 'manag'])],
#        [list(['code', 'introduct', 'program'])],
#        [list(['commun', 'skill', 'engin'])],
#        [list(['commun', 'strategi', 'virtual', 'age'])],
#        [list(['compassion', 'leadership', 'servic', 'learn', 'jane', 'goodal', 'root', 'shoot'])],
#        [list(['competencia', 'digital', 'herramienta', 'ofimática', 'microsoft', 'word', 'excel', 'power', 'point'])],
#        [list(['competit', 'strategi', 'organ', 'design'])],
#        [list(['comput', 'social', 'scienc'])],
#        [list(['comput', 'think', 'problem', 'solv'])],
#        [list(['comput', 'secur', 'system', 'manag'])],
#        [list(['conflict', 'manag'])],
#        [list(['construct', 'cost', 'estim', 'cost', 'control'])],
#        [list(['construct', 'manag'])],
#        [list(['construct', 'project', 'manag'])],
#        [list(['construct', 'schedul'])],
#        [list(['contabilidad', 'para', 'contador'])],
#        [list(['content', 'strategi', 'profession'])],
#        [list(['continu', 'deliveri', 'devop'])],
#        [list(['control', 'mobil', 'robot'])],
#        [list(['convolut', 'neural', 'network'])],
#        [list(['convolut', 'neural', 'network', 'tensorflow'])],
#        [list(['corpor', 'commerci', 'law', 'contract', 'employ', 'law'])],
#        [list(['corpor', 'financ', 'essenti'])],
#        [list(['corpor', 'strategi'])],
#        [list(['corpor', 'sustain', 'understand', 'seiz', 'strateg', 'opportun'])],
#        [list(['corrección', 'estilo', 'variacion', 'lengua', 'española'])],
#        [list(['cost', 'econom', 'price', 'strategi'])],
#        [list(['costo', 'para', 'negocio'])],
#        [list(['crash', 'cours', 'python'])],
#        [list(['creativ', 'problem', 'solv'])],
#        [list(['creativ', 'write'])],
#        [list(['creativ', 'write', 'craft', 'plot'])],
#        [list(['creatividad', 'diseño', 'innovación', 'cnica', 'herramienta'])],
#        [list(['cuidado', 'herida', 'ámbito', 'hospitalario'])],
#        [list(['cuidado', 'procedimiento', 'general', 'atención', 'del', 'reci', 'nacido'])],
#        [list(['cultur', 'driven', 'team', 'build'])],
#        [list(['curanderismo', 'tradit', 'heal', 'use', 'plant'])],
#        [list(['custom', 'segment', 'prospect'])],
#        [list(['cybersecur'])],
#        [list(['cybersecur', 'ten', 'domain'])],
#        [list(['cybersecur', 'busi'])],
#        [list(['cómo', 'hablar', 'bien', 'público'])],
#        [list(['dairi', 'product', 'manag'])],
#        [list(['data', 'analysi', 'interpret'])],
#        [list(['data', 'analysi', 'present', 'skill', 'pwc', 'approach'])],
#        [list(['data', 'analysi', 'python'])],
#        [list(['data', 'analyt', 'lean', 'six', 'sigma'])],
#        [list(['data', 'collect', 'process', 'python'])],
#        [list(['data', 'engin', 'googl', 'cloud', 'platform', '日本語版'])],
#        [list(['data', 'engin', 'googl', 'cloud'])],
#        [list(['data', 'engin', 'big', 'data', 'machin', 'learn', 'gcp'])],
#        [list(['data', 'manag', 'clinic', 'research'])],
#        [list(['data', 'mine'])],
#        [list(['data', 'scienc'])],
#        [list(['data', 'scienc', 'math', 'skill'])],
#        [list(['data', 'scienc', 'methodolog'])],
#        [list(['data', 'scienc', 'foundat', 'use'])],
#        [list(['data', 'scienc', 'statist', 'machin', 'learn'])],
#        [list(['data', 'visual', 'commun', 'tableau'])],
#        [list(['data', 'visual', 'advanc', 'excel'])],
#        [list(['data', 'visual', 'python'])],
#        [list(['data', 'visual', 'tableau'])],
#        [list(['data', 'wareh', 'busi', 'intellig'])],
#        [list(['data', 'health', 'indic', 'public', 'health', 'practic'])],
#        [list(['data', 'driven', 'decis', 'make'])],
#        [list(['databas', 'sql', 'data', 'scienc'])],
#        [list(['mystifi', 'mind'])],
#        [list(['decis', 'make', 'scenario'])],
#        [list(['deep', 'learn'])],
#        [list(['democracia', 'decision', 'pública', 'introducción', 'análisi', 'política', 'pública'])],
#        [list(['dentistri', '101'])],
#        [list(['dermatolog', 'trip', 'skin'])],
#        [list(['design', 'think', 'innov'])],
#        [list(['design', 'think', 'greater', 'good', 'innov', 'social', 'sector'])],
#        [list(['design', 'interpret', 'clinic', 'trial'])],
#        [list(['design', 'make', 'infograph', 'project', 'center', 'cours'])],
#        [list(['design', 'led', 'strategi', 'design', 'think', 'busi', 'strategi', 'entrepreneurship'])],
#        [list(['develop', 'api', 'googl', 'cloud', 'apige', 'api', 'platform'])],
#        [list(['develop', 'applic', 'googl', 'cloud', 'platform'])],
#        [list(['develop', 'applic', 'googl', 'cloud', 'platform', '日本語版'])],
#        [list(['develop', 'industri', 'internet', 'thing'])],
#        [list(['develop', 'musicianship'])],
#        [list(['develop', 'musicianship'])],
#        [list(['devenir', 'entrepreneur', 'changement'])],
#        [list(['digit', 'advertis', 'strategi'])],
#        [list(['digit', 'busi', 'model'])],
#        [list(['digit', 'manufactur', 'design', 'technolog'])],
#        [list(['digit', 'market'])],
#        [list(['digit', 'media', 'market', 'strategi'])],
#        [list(['digit', 'product', 'manag'])],
#        [list(['digit', 'product', 'manag', 'modern', 'fundament'])],
#        [list(['dino', '101', 'dinosaur', 'paleobiolog'])],
#        [list(['discret', 'optim'])],
#        [list(['diseño', 'instruccion', 'aprendizaj', 'activo', 'pedagogía', 'digit'])],
#        [list(['diseño', 'creación', 'emprendimiento', 'social'])],
#        [list(['divid', 'conquer', 'sort', 'search', 'random', 'algorithm'])],
#        [list(['dog', 'emot', 'cognit'])],
#        [list(['drive', 'busi', 'toward', 'sustain', 'develop', 'goal'])],
#        [list(['drug', 'commerci'])],
#        [list(['drug', 'discoveri'])],
#        [list(['dynam', 'public', 'speak'])],
#        [list(['emt', 'foundat'])],
#        [list(['ecolog', 'ecosystem', 'dynam', 'conserv'])],
#        [list(['econometr', 'method', 'applic'])],
#        [list(['econom', 'money', 'bank'])],
#        [list(['ecosystem', 'servic', 'method', 'sustain', 'develop'])],
#        [list(['effect', 'complianc', 'program'])],
#        [list(['egiptología', 'egyptolog'])],
#        [list(['abogado', 'del', 'futuro', 'legaltech', 'transformación', 'digit', 'del', 'derecho'])],
#        [list(['elast', 'googl', 'cloud', 'infrastructur', 'scale', 'autom'])],
#        [list(['electr', 'industri', 'oper', 'market'])],
#        [list(['electron', 'music', 'product'])],
#        [list(['emerg', 'technolog', 'smartphon', 'iot', 'big', 'data'])],
#        [list(['energi', 'product', 'distribut', 'safeti'])],
#        [list(['engin', 'health', 'introduct', 'yoga', 'physiolog'])],
#        [list(['engin', 'project', 'manag', 'initi', 'plan'])],
#        [list(['english', 'composit'])],
#        [list(['english', 'busi', 'entrepreneurship'])],
#        [list(['english', 'career', 'develop'])],
#        [list(['english', 'journal'])],
#        [list(['english', 'research', 'public', 'purpos'])],
#        [list(['english', 'scienc', 'technolog', 'engin', 'mathemat'])],
#        [list(['enterpris', 'architectur'])],
#        [list(['entrepreneuri', 'financ', 'strategi', 'innov'])],
#        [list(['entrepreneurship'])],
#        [list(['entrepreneurship', 'develop', 'opportun'])],
#        [list(['entrepreneurship', 'launch', 'start'])],
#        [list(['entrepreneurship', 'growth', 'strategi'])],
#        [list(['entrepreneurship', 'strategi', 'ideat', 'exit'])],
#        [list(['entrepreneurship', 'launch', 'innov', 'busi'])],
#        [list(['epidem', 'dynam', 'infecti', 'diseas'])],
#        [list(['epidem', 'pandem', 'outbreak'])],
#        [list(['epidemiolog', 'public', 'health'])],
#        [list(['epidemiolog', 'public', 'health', 'practic'])],
#        [list(['epidemiolog', 'basic', 'scienc', 'public', 'health'])],
#        [list(['epigenet', 'control', 'gene', 'express'])],
#        [list(['equin', 'welfar', 'manag'])],
#        [list(['esport'])],
#        [list(['essenti', 'epidemiolog', 'tool', 'public', 'health', 'practic'])],
#        [list(['essenti', 'googl', 'cloud', 'infrastructur', 'core', 'servic'])],
#        [list(['essenti', 'googl', 'cloud', 'infrastructur', 'foundat'])],
#        [list(['essenti', 'clinic', 'simul', 'across', 'health', 'profess'])],
#        [list(['essenti', 'corpor', 'financ'])],
#        [list(['essenti', 'global', 'health'])],
#        [list(['estadística', 'probabilidad'])],
#        [list(['evaluación', 'educativa'])],
#        [list(['everyday', 'excel', 'part'])],
#        [list(['everyday', 'parent', 'abc', 'child', 'rear'])],
#        [list(['excel', 'skill', 'busi'])],
#        [list(['excel', 'skill', 'busi', 'advanc'])],
#        [list(['excel', 'skill', 'busi', 'essenti'])],
#        [list(['excel', 'skill', 'busi', 'intermedi'])],
#        [list(['excel', 'skill', 'busi', 'intermedi'])],
#        [list(['excel', 'mysql', 'analyt', 'techniqu', 'busi'])],
#        [list(['excel', 'vba', 'creativ', 'problem', 'solv'])],
#        [list(['excel', 'vba', 'creativ', 'problem', 'solv', 'part'])],
#        [list(['execut', 'data', 'scienc'])],
#        [list(['explorando', 'energía', 'sustent'])],
#        [list(['fashion', 'design'])],
#        [list(['femin', 'social', 'justic'])],
#        [list(['fintech', 'law', 'polici'])],
#        [list(['fintech', 'financ', 'industri', 'transform', 'regul'])],
#        [list(['fintech', 'foundat', 'payment', 'regul'])],
#        [list(['financ', 'quantit', 'model', 'analyst'])],
#        [list(['financ', 'non', 'financ', 'profession'])],
#        [list(['financ', 'non', 'financi', 'manag'])],
#        [list(['financi', 'account', 'fundament'])],
#        [list(['financi', 'acumen', 'non', 'financi', 'manag'])],
#        [list(['financi', 'engin', 'risk', 'manag', 'part'])],
#        [list(['financi', 'manag'])],
#        [list(['financi', 'market'])],
#        [list(['financi', 'market', 'invest', 'strategi'])],
#        [list(['financi', 'report'])],
#        [list(['financi', 'technolog', 'fintech', 'innov'])],
#        [list(['financ', 'invest', 'infrastructur'])],
#        [list(['finanza', 'corporativa'])],
#        [list(['finanza', 'personal'])],
#        [list(['find', 'purpos', 'mean', 'life', 'live', 'matter'])],
#        [list(['fintech', 'foundat', 'applic', 'financi', 'technolog'])],
#        [list(['first', 'step', 'korean'])],
#        [list(['food', 'beverag', 'manag'])],
#        [list(['forens', 'account', 'fraud', 'examin'])],
#        [list(['formulación', 'evaluación', 'proyecto', 'complejo'])],
#        [list(['foundat', 'financ', 'strateg', 'decis', 'make'])],
#        [list(['foundat', 'busi', 'strategi'])],
#        [list(['foundat', 'everyday', 'leadership'])],
#        [list(['foundat', 'global', 'health'])],
#        [list(['foundat', 'manag'])],
#        [list(['foundat', 'market', 'analyt'])],
#        [list(['foundat', 'posit', 'psycholog'])],
#        [list(['foundat', 'public', 'health', 'practic'])],
#        [list(['data', 'insight', 'googl', 'cloud', 'platform'])],
#        [list(['big', 'bang', 'dark', 'energi'])],
#        [list(['front', 'end', 'web', 'develop', 'react'])],
#        [list(['front', 'end', 'web', 'framework', 'tool', 'bootstrap'])],
#        [list(['full', 'stack', 'web', 'multiplatform', 'mobil', 'app', 'develop'])],
#        [list(['full', 'stack', 'web', 'develop', 'react'])],
#        [list(['function', 'program', 'principl', 'scala'])],
#        [list(['function', 'program', 'scala'])],
#        [list(['fundament', 'neurosci', 'neuroimag'])],
#        [list(['fundament', 'account'])],
#        [list(['fundament', 'comput'])],
#        [list(['fundament', 'engin', 'exam', 'review'])],
#        [list(['fundament'])],
#        [list(['fundament', 'graphic', 'design'])],
#        [list(['fundament', 'immunolog'])],
#        [list(['fundament', 'immunolog', 'innat', 'immun', 'cell', 'function'])],
#        [list(['fundament', 'music', 'theori'])],
#        [list(['fundament', 'project', 'plan', 'manag'])],
#        [list(['fundament', 'quantit', 'model'])],
#        [list(['fundament', 'reinforc', 'learn'])],
#        [list(['fundament', 'visual', 'tableau'])],
#        [list(['fundamento', 'empresarial'])],
#        [list(['fundamento', 'estrat', 'gico', 'empresarial'])],
#        [list(['fundamento', 'excel', 'para', 'negocio'])],
#        [list(['fundamento', 'finanza', 'empresarial'])],
#        [list(['fundamento', 'escritura'])],
#        [list(['fundrais', 'develop'])],
#        [list(['futur', 'think'])],
#        [list(['suit', 'administr'])],
#        [list(['map', 'spatial', 'analysi'])],
#        [list(['game', 'design', 'develop'])],
#        [list(['game', 'theori'])],
#        [list(['gamif'])],
#        [list(['gender', 'sexual', 'divers', 'inclus', 'workplac'])],
#        [list(['genom', 'data', 'scienc'])],
#        [list(['geograph', 'inform', 'system'])],
#        [list(['geopolit', 'europ'])],
#        [list(['geopolítica', 'gobernanza', 'global', 'riesgo', 'oportunidad'])],
#        [list(['gestión', 'organizacion', 'efectiva'])],
#        [list(['get', 'interact', 'practic', 'teach', 'technolog'])],
#        [list(['get', 'start', 'music', 'theori'])],
#        [list(['get', 'start', 'machin', 'learn'])],
#        [list(['get', 'start'])],
#        [list(['get', 'start', 'googl', 'kubernet', 'engin'])],
#        [list(['get', 'start', 'googl', 'sheet'])],
#        [list(['get', 'start', 'program'])],
#        [list(['global', 'diplomaci', 'diplomaci', 'modern', 'world'])],
#        [list(['global', 'diplomaci', 'unit', 'nation', 'world'])],
#        [list(['global', 'energi', 'climat', 'polici'])],
#        [list(['global', 'environment', 'manag'])],
#        [list(['global', 'financi', 'market', 'instrument'])],
#        [list(['global', 'financ', 'solut', 'edhec', 'soci', 'rale'])],
#        [list(['global', 'trend', 'busi', 'societi'])],
#        [list(['global', 'econom', 'growth', 'stabil'])],
#        [list(['good', 'word', 'write', 'edit'])],
#        [list(['googl', 'cloud', 'platform', 'big', 'data', 'machin', 'learn', 'fundament'])],
#        [list(['googl', 'cloud', 'platform', 'fundament', 'profession'])],
#        [list(['googl', 'autom', 'python'])],
#        [list(['googl', 'support'])],
#        [list(['grammar', 'punctuat'])],
#        [list(['graphic', 'design', 'element', 'non', 'design'])],
#        [list(['greek', 'roman', 'mytholog'])],
#        [list(['green', 'economi', 'sustain', 'citi'])],
#        [list(['guitar', 'beginn'])],
#        [list(['gut', 'check', 'explor', 'microbiom'])],
#        [list(['html', 'css', 'javascript', 'web', 'develop'])],
#        [list(['habilidad', 'gerencial'])],
#        [list(['hacia', 'una', 'práctica', 'constructivista', 'aula'])],
#        [list(['hardwar', 'descript', 'languag', 'fpga', 'design'])],
#        [list(['heal', 'art'])],
#        [list(['health', 'informat'])],
#        [list(['health', 'inform', 'literaci', 'data', 'analyt'])],
#        [list(['healthcar', 'law'])],
#        [list(['healthcar', 'marketplac'])],
#        [list(['healthcar', 'organ', 'oper'])],
#        [list(['high', 'perform', 'collabor', 'leadership', 'teamwork', 'negoti'])],
#        [list(['homeland', 'secur', 'cybersecur'])],
#        [list(['hotel', 'manag', 'distribut', 'revenu', 'demand', 'manag'])],
#        [list(['thing', 'work', 'introduct', 'physic'])],
#        [list(['creat', 'websit', 'weekend', 'project', 'center', 'cours'])],
#        [list(['start', 'busi'])],
#        [list(['human', 'resourc', 'manag', 'peopl', 'manag'])],
#        [list(['ibm', 'engin'])],
#        [list(['ibm', 'enterpris', 'workflow'])],
#        [list(['ibm', 'appli'])],
#        [list(['ibm', 'custom', 'engag', 'specialist', 'profession', 'certif'])],
#        [list(['ibm', 'data', 'scienc'])],
#        [list(['fundament', 'cybersecur'])],
#        [list(['secur', 'defens', 'digit', 'dark', 'art'])],
#        [list(['identifi', 'monitor', 'analyz', 'risk', 'incid', 'respons', 'recoveri'])],
#        [list(['implementación', 'del', 'market', 'mix'])],
#        [list(['implement', 'rpa', 'cognit', 'autom', 'analyt'])],
#        [list(['improv', 'english', 'commun', 'skill'])],
#        [list(['improv', 'deep', 'neural', 'network', 'hyperparamet', 'tune', 'regular', 'optim'])],
#        [list(['improv', 'leadership', 'govern', 'nonprofit', 'organ'])],
#        [list(['studio', 'postwar', 'abstract', 'paint'])],
#        [list(['indigen', 'canada'])],
#        [list(['industri', 'iot', 'googl', 'cloud', 'platform'])],
#        [list(['infecti', 'diseas', 'model'])],
#        [list(['influenc', 'market', 'strategi'])],
#        [list(['influenc', 'storytel', 'chang', 'manag', 'govern'])],
#        [list(['inform', 'secur', 'context', 'introduct'])],
#        [list(['inform', 'visual'])],
#        [list(['information\u200b', '\u200bsystem'])],
#        [list(['initi', 'plan', 'project'])],
#        [list(['innov', 'manag'])],
#        [list(['innov', 'design', 'think', 'make', 'break', 'repeat'])],
#        [list(['innov', 'creativ', 'entrepreneurship'])],
#        [list(['inspir', 'leadership', 'lead', 'sens'])],
#        [list(['inspir', 'leadership'])],
#        [list(['inspir', 'motiv', 'individu'])],
#        [list(['instruct', 'design', 'foundat', 'applic'])],
#        [list(['instruct', 'method', 'health', 'profess', 'educ'])],
#        [list(['integr', 'health', 'medicin'])],
#        [list(['intellectu', 'properti', 'law'])],
#        [list(['interact', 'design'])],
#        [list(['intercultur', 'manag'])],
#        [list(['intern', 'busi', 'essenti'])],
#        [list(['intern', 'cyber', 'conflict'])],
#        [list(['intern', 'humanitarian', 'law', 'theori', 'practic'])],
#        [list(['intern', 'law', 'action', 'guid', 'intern', 'court', 'tribun', 'hagu'])],
#        [list(['intern', 'law', 'action', 'arbitr', 'intern', 'disput'])],
#        [list(['intern', 'leadership', 'organiz', 'behavior'])],
#        [list(['intern', 'market', 'cross', 'industri', 'growth'])],
#        [list(['intern', 'organ', 'manag'])],
#        [list(['intern', 'secur', 'manag'])],
#        [list(['intern', 'women', 'health', 'human', 'right'])],
#        [list(['intern', 'migrat', 'global', 'issu'])],
#        [list(['internet', 'connect', 'get', 'onlin'])],
#        [list(['internet', 'giant', 'law', 'econom', 'media', 'platform'])],
#        [list(['interview', 'resum', 'write', 'english'])],
#        [list(['introducción', 'data', 'scienc', 'programación', 'estadística', 'con'])],
#        [list(['introducción', 'programación', 'python', 'aprendiendo', 'programar', 'con', 'python'])],
#        [list(['introduct', 'aux', 'droit', 'homm'])],
#        [list(['introduct', 'ableton', 'live'])],
#        [list(['introduct', 'artifici', 'intellig'])],
#        [list(['introduct', 'big', 'data'])],
#        [list(['introduct', 'blockchain', 'technolog'])],
#        [list(['introduct', 'breast', 'cancer'])],
#        [list(['introduct', 'busi', 'analyt', 'commun', 'data'])],
#        [list(['introduct', 'css3'])],
#        [list(['introduct', 'calculu'])],
#        [list(['introduct', 'chemistri', 'reaction', 'ratio'])],
#        [list(['introduct', 'classic', 'music'])],
#        [list(['introduct', 'cloud', 'comput'])],
#        [list(['introduct', 'comput', 'program'])],
#        [list(['introduct', 'comput', 'scienc', 'program'])],
#        [list(['introduct', 'corpor', 'financ'])],
#        [list(['introduct', 'cyber', 'attack'])],
#        [list(['introduct', 'cyber', 'secur'])],
#        [list(['introduct', 'cybersecur', 'tool', 'cyber', 'attack'])],
#        [list(['introduct', 'data', 'analysi', 'use', 'excel'])],
#        [list(['introduct', 'data', 'scienc'])],
#        [list(['introduct', 'data', 'scienc', 'python'])],
#        [list(['introduct', 'dental', 'medicin'])],
#        [list(['introduct', 'discret', 'mathemat', 'comput', 'scienc'])],
#        [list(['introduct', 'electron'])],
#        [list(['introduct', 'embed', 'system', 'softwar', 'develop', 'environ'])],
#        [list(['introduct', 'engin', 'mechan'])],
#        [list(['introduct', 'environment', 'law', 'polici'])],
#        [list(['introduct', 'financi', 'account'])],
#        [list(['introduct', 'forens', 'scienc'])],
#        [list(['introduct', 'game', 'develop'])],
#        [list(['introduct', 'genet', 'evolut'])],
#        [list(['introduct', 'genom', 'technolog'])],
#        [list(['introduct', 'html5'])],
#        [list(['introduct', 'imagemak'])],
#        [list(['introduct', 'intellectu', 'properti'])],
#        [list(['introduct', 'intern', 'crimin', 'law'])],
#        [list(['introduct', 'market'])],
#        [list(['introduct', 'mathemat', 'think'])],
#        [list(['introduct', 'oper', 'manag'])],
#        [list(['introduct', 'person', 'brand'])],
#        [list(['introduct', 'philosophi'])],
#        [list(['introduct', 'portfolio', 'construct', 'analysi', 'python'])],
#        [list(['introduct', 'probabl', 'data'])],
#        [list(['introduct', 'program'])],
#        [list(['introduct', 'program', 'matlab'])],
#        [list(['introduct', 'psycholog'])],
#        [list(['introduct', 'script', 'python'])],
#        [list(['introduct', 'self', 'drive', 'car'])],
#        [list(['introduct', 'spreadsheet', 'model'])],
#        [list(['introduct', 'statist', 'data', 'analysi', 'public', 'health'])],
#        [list(['introduct', 'sustain'])],
#        [list(['introduct', 'systemat', 'review', 'meta', 'analysi'])],
#        [list(['introduct', 'system', 'engin'])],
#        [list(['introduct', 'tensorflow', 'artifici', 'intellig', 'machin', 'learn', 'deep', 'learn'])],
#        [list(['introduct', 'thermodynam', 'transfer', 'energi'])],
#        [list(['introduct', 'trade', 'machin', 'learn', 'gcp'])],
#        [list(['introduct', 'typographi'])],
#        [list(['introduct', 'user', 'experi', 'design'])],
#        [list(['introduct', 'user', 'experi', 'principl', 'process'])],
#        [list(['introduct', 'web', 'develop'])],
#        [list(['introduct', 'biolog', 'cancer'])],
#        [list(['introductori', 'human', 'physiolog'])],
#        [list(['introdução', 'princípio', 'prática', 'gestão', 'projeto'])],
#        [list(['introdução', 'ciência', 'computação', 'com', 'python', 'part'])],
#        [list(['invest', 'manag'])],
#        [list(['invest', 'manag', 'python', 'machin', 'learn'])],
#        [list(['invest', 'portfolio', 'manag'])],
#        [list(['japanes', 'beginn'])],
#        [list(['java', 'program', 'softwar', 'engin', 'fundament'])],
#        [list(['java', 'program', 'solv', 'problem', 'softwar'])],
#        [list(['julia', 'scientif', 'program'])],
#        [list(['kotlin', 'java', 'develop'])],
#        [list(['excel', 'rationnel', 'pratiqu'])],
#        [list(['impact', 'invest', 'financ', 'qui', 'chang', 'mond'])],
#        [list(['leadership', 'develop', 'engin'])],
#        [list(['leadership', '21st', 'centuri', 'organ'])],
#        [list(['lead', 'healthcar', 'qualiti', 'safeti'])],
#        [list(['lead', 'peopl', 'team'])],
#        [list(['lead', 'equiti', 'divers', 'inclus', 'higher', 'educ'])],
#        [list(['lead', 'human', 'resourc', 'manag', 'leadership'])],
#        [list(['learn', 'chines', 'hsk', 'test', 'prepar'])],
#        [list(['learn', 'english'])],
#        [list(['learn', 'english', 'advanc', 'academ', 'speak', 'listen'])],
#        [list(['learn', 'english', 'advanc', 'grammar', 'punctuat'])],
#        [list(['learn', 'english', 'intermedi', 'grammar'])],
#        [list(['learn', 'mandarin', 'chines'])],
#        [list(['learn', 'sql', 'basic', 'data', 'scienc'])],
#        [list(['learn', 'spanish', 'basic', 'spanish', 'vocabulari'])],
#        [list(['learn', 'program', 'fundament'])],
#        [list(['learn', 'speak', 'korean'])],
#        [list(['learn', 'teach', 'onlin'])],
#        [list(['legal', 'tech', 'startup'])],
#        [list(['fondamentaux', 'gociat'])],
#        [list(['liderazgo', 'efectivo', 'para', 'siglo', 'xxi'])],
#        [list(['linear', 'circuit', 'analysi'])],
#        [list(['love', 'forc', 'social', 'justic'])],
#        [list(['machin', 'learn'])],
#        [list(['machin', 'learn'])],
#        [list(['machin', 'learn', 'foundat', 'case', 'studi', 'approach'])],
#        [list(['machin', 'learn', 'reinforc', 'learn', 'financ'])],
#        [list(['machin', 'learn'])],
#        [list(['machin', 'learn', 'busi', 'profession'])],
#        [list(['machin', 'learn', 'trade'])],
#        [list(['machin', 'learn', 'python'])],
#        [list(['machin', 'learn', 'tensorflow', 'googl', 'cloud', 'platform'])],
#        [list(['magic', 'middl', 'age'])],
#        [list(['make', 'architectur'])],
#        [list(['manag', 'fashion', 'luxuri', 'compani'])],
#        [list(['manageri', 'account', 'fundament'])],
#        [list(['manageri', 'econom', 'busi', 'analysi'])],
#        [list(['manag', 'innov', 'design', 'think'])],
#        [list(['manag', 'project', 'risk', 'chang'])],
#        [list(['manag', 'social', 'human', 'capit'])],
#        [list(['manag', 'health', 'role', 'physic', 'therapi', 'exercis'])],
#        [list(['market', 'research'])],
#        [list(['market', 'digit'])],
#        [list(['market', 'digit'])],
#        [list(['market', 'gerenci'])],
#        [list(['market', 'mix', 'implement'])],
#        [list(['market', 'strategi'])],
#        [list(['market', 'verd'])],
#        [list(['market', 'con', 'rede', 'social'])],
#        [list(['market', 'digit', 'world'])],
#        [list(['master', 'data', 'analysi', 'excel'])],
#        [list(['master', 'final', 'cut', 'pro'])],
#        [list(['master', 'softwar', 'develop'])],
#        [list(['materi', 'scienc', 'thing', 'everi', 'engin', 'know'])],
#        [list(['mathemat', 'data', 'scienc'])],
#        [list(['mathemat', 'machin', 'learn'])],
#        [list(['mathemat', 'machin', 'learn', 'linear', 'algebra'])],
#        [list(['mathemat', 'machin', 'learn', 'multivari', 'calculu'])],
#        [list(['mathemat', 'machin', 'learn', 'pca'])],
#        [list(['medic', 'cannabi', 'health', 'effect', 'thc', 'cbd'])],
#        [list(['medic', 'neurosci'])],
#        [list(['memoir', 'person', 'essay', 'write'])],
#        [list(['method', 'statist', 'social', 'scienc'])],
#        [list(['microeconom', 'principl'])],
#        [list(['microeconom', 'power', 'market'])],
#        [list(['mindshift', 'break', 'obstacl', 'learn', 'discov', 'hidden', 'potenti'])],
#        [list(['miracl', 'human', 'languag', 'introduct', 'linguist'])],
#        [list(['model', 'think'])],
#        [list(['model', 'risk', 'realiti'])],
#        [list(['modern', 'art', 'idea'])],
#        [list(['modern', 'big', 'data', 'analysi', 'sql'])],
#        [list(['modern', 'robot', 'mechan', 'plan', 'control'])],
#        [list(['modern', 'data', 'lake', 'data', 'warehous', 'gcp'])],
#        [list(['moral', 'foundat', 'polit'])],
#        [list(['introduct', 'financi', 'account'])],
#        [list(['mountain', '101'])],
#        [list(['municip', 'solid', 'wast', 'manag', 'develop', 'countri'])],
#        [list(['music', 'busi'])],
#        [list(['music', 'busi', 'foundat'])],
#        [list(['music', 'product'])],
#        [list(['nanotechnolog', 'maker', 'cours'])],
#        [list(['natur', 'languag', 'process', 'tensorflow'])],
#        [list(['negociación', 'exitosa', 'estrategia', 'habilidad', 'esencial', 'español'])],
#        [list(['negoti', 'mediat', 'conflict', 'resolut'])],
#        [list(['network', 'secur', 'architectur', 'vmware', 'nsx'])],
#        [list(['network', 'googl', 'cloud'])],
#        [list(['neural', 'network', 'deep', 'learn'])],
#        [list(['neurolinguist'])],
#        [list(['new', 'approach', 'counter', 'terror', 'counter', 'violent', 'extrem'])],
#        [list(['newborn', 'babi', 'care'])],
#        [list(['nutrición', 'obesidad', 'control', 'sobrepeso'])],
#        [list(['nutrit', 'lifestyl', 'pregnanc'])],
#        [list(['object', 'orient', 'java', 'program', 'data', 'structur', 'beyond'])],
#        [list(['object', 'orient', 'program', 'java'])],
#        [list(['object', 'orient', 'data', 'structur'])],
#        [list(['object', 'orient', 'design'])],
#        [list(['oil', 'industri', 'oper', 'market'])],
#        [list(['open', 'sourc', 'softwar', 'develop', 'linux', 'git'])],
#        [list(['oper', 'system', 'becom', 'power', 'user'])],
#        [list(['oper', 'analyt'])],
#        [list(['optic', 'engin'])],
#        [list(['organiz', 'leadership'])],
#        [list(['osteoarchaeolog', 'truth', 'bone'])],
#        [list(['palli', 'care', 'hospic', 'anymor'])],
#        [list(['palo', 'alto', 'network', 'cybersecur'])],
#        [list(['parallel', 'concurr', 'distribut', 'program', 'java'])],
#        [list(['particl', 'physic', 'introduct'])],
#        [list(['patient', 'safeti'])],
#        [list(['patrocinio', 'deportivo'])],
#        [list(['peopl', 'analyt'])],
#        [list(['perfect', 'tens', 'modal'])],
#        [list(['periodismo', 'digit', 'combat', 'fake', 'news'])],
#        [list(['photographi', 'basic', 'beyond', 'smartphon', 'dslr'])],
#        [list(['plant', 'bioinformat', 'method'])],
#        [list(['polit', 'econom', 'intern', 'energi'])],
#        [list(['posit', 'psychiatri', 'mental', 'health'])],
#        [list(['posit', 'psycholog'])],
#        [list(['posit', 'psycholog', 'applic', 'intervent'])],
#        [list(['posit', 'psycholog', 'martin', 'seligman', 'visionari', 'scienc'])],
#        [list(['posit', 'psycholog', 'resili', 'skill'])],
#        [list(['power', 'electron'])],
#        [list(['practic', 'data', 'scienc', 'matlab'])],
#        [list(['practic', 'time', 'seri', 'analysi'])],
#        [list(['prepar', 'googl', 'cloud', 'associ', 'cloud', 'engin', 'exam'])],
#        [list(['prepar', 'manag', 'human', 'resourc'])],
#        [list(['present', 'skill', 'speechwrit', 'slide', 'deliveri'])],
#        [list(['price', 'strategi', 'optim'])],
#        [list(['primero', 'auxilio', 'psicológico', 'pap'])],
#        [list(['privat', 'equiti', 'ventur', 'capit'])],
#        [list(['probabilist', 'graphic', 'model', 'represent'])],
#        [list(['probabl', 'statist'])],
#        [list(['process', 'mine', 'data', 'scienc', 'action'])],
#        [list(['program', 'foundat', 'javascript', 'html', 'css'])],
#        [list(['program', 'fundament'])],
#        [list(['program', 'everybodi', 'get', 'start', 'python'])],
#        [list(['program', 'googl'])],
#        [list(['project', 'execut'])],
#        [list(['project', 'launch'])],
#        [list(['project', 'manag', 'tool', 'career', 'develop'])],
#        [list(['project', 'manag', 'principl', 'practic'])],
#        [list(['psycholog', 'first', 'aid'])],
#        [list(['public', 'polici', 'challeng', '21st', 'centuri'])],
#        [list(['python', 'basic'])],
#        [list(['python', 'class', 'inherit'])],
#        [list(['python', 'data', 'structur'])],
#        [list(['python', 'function', 'file', 'dictionari'])],
#        [list(['python', 'statist', 'financi', 'analysi'])],
#        [list(['python', 'data', 'scienc'])],
#        [list(['python', 'everybodi'])],
#        [list(['quantit', 'method'])],
#        [list(['queer', 'ident', 'lgbtq', 'sexual', 'gender', 'ident'])],
#        [list(['program'])],
#        [list(['readi', 'set', 'futur', 'introduct', 'futur', 'think'])],
#        [list(['recommend', 'system'])],
#        [list(['recruit', 'hire', 'onboard', 'employe'])],
#        [list(['reinforc', 'learn'])],
#        [list(['renew', 'energi', 'green', 'build', 'entrepreneurship'])],
#        [list(['report', 'extra', 'financi', 'strat', 'gie', 'rse'])],
#        [list(['requir', 'engin', 'secur', 'softwar', 'specif'])],
#        [list(['research', 'data', 'manag', 'share'])],
#        [list(['resili', 'children', 'expos', 'trauma', 'disast', 'war', 'global', 'perspect'])],
#        [list(['respons', 'websit', 'develop', 'design'])],
#        [list(['rethink', 'intern', 'tax', 'law'])],
#        [list(['revisão', 'sistemática', 'meta', 'anális'])],
#        [list(['robot'])],
#        [list(['roman', 'architectur'])],
#        [list(['russian', 'alphabet'])],
#        [list(['russian', 'beginn', 'русский', 'язык'])],
#        [list(['ussir', 'changement'])],
#        [list(['programm'])],
#        [list(['visual', 'busi', 'analyt'])],
#        [list(['sql', 'data', 'scienc'])],
#        [list(['sale', 'oper', 'manag'])],
#        [list(['sale', 'train', 'high', 'perform', 'team'])],
#        [list(['sampl', 'base', 'learn', 'method'])],
#        [list(['scale', 'oper', 'link', 'strategi', 'execut'])],
#        [list(['school', 'health', 'children', 'adolesc'])],
#        [list(['scienc', 'exercis'])],
#        [list(['search', 'engin', 'optim', 'fundament'])],
#        [list(['secur', 'code', 'practic'])],
#        [list(['secur', 'safeti', 'challeng', 'global', 'world'])],
#        [list(['secur', 'googl', 'cloud', 'platform'])],
#        [list(['self', 'drive', 'car'])],
#        [list(['sequenc', 'model'])],
#        [list(['sexualidad', 'mucho', 'que', 'sexo'])],
#        [list(['sharpen', 'vision', 'poetri', 'workshop'])],
#        [list(['site', 'reliabl', 'engin', 'measur', 'manag', 'reliabl'])],
#        [list(['six', 'sigma', 'green', 'belt'])],
#        [list(['six', 'sigma', 'organ', 'advanc'])],
#        [list(['sleep', 'neurobiolog', 'medicin', 'societi'])],
#        [list(['smart', 'citi', 'manag', 'smart', 'urban', 'infrastructur'])],
#        [list(['social', 'entrepreneurship'])],
#        [list(['social', 'media', 'market'])],
#        [list(['social', 'norm', 'social', 'chang'])],
#        [list(['social', 'polici', 'social', 'servic', 'health', 'practition'])],
#        [list(['social', 'psycholog'])],
#        [list(['social', 'econom', 'network', 'model', 'analysi'])],
#        [list(['softwar', 'design', 'architectur'])],
#        [list(['softwar', 'develop', 'lifecycl'])],
#        [list(['softwar', 'process', 'agil', 'practic'])],
#        [list(['softwar', 'product', 'manag'])],
#        [list(['solar', 'energi', 'basic'])],
#        [list(['songwrit', 'write', 'lyric'])],
#        [list(['soport', 'tecnología', 'información', 'googl'])],
#        [list(['spacecraft', 'dynam', 'control'])],
#        [list(['spanish', 'vocabulari', 'meet', 'peopl'])],
#        [list(['speak', 'english', 'profession', 'person', 'onlin', 'phone'])],
#        [list(['sport', 'market'])],
#        [list(['sport', 'societi'])],
#        [list(['stanford', 'introduct', 'food', 'health'])],
#        [list(['stanford', 'short', 'cours', 'breastfeed'])],
#        [list(['statist', 'analysi', 'public', 'health'])],
#        [list(['statist', 'python'])],
#        [list(['statist'])],
#        [list(['stori', 'infect'])],
#        [list(['strateg', 'busi', 'analyt'])],
#        [list(['strateg', 'busi', 'manag', 'microeconom'])],
#        [list(['strateg', 'leadership', 'manag'])],
#        [list(['strateg', 'manag'])],
#        [list(['strateg', 'manag', 'innov'])],
#        [list(['strateg', 'sale', 'manag'])],
#        [list(['strategis', 'manag', 'global', 'competit', 'advantag'])],
#        [list(['strategi', 'sustain'])],
#        [list(['structur', 'machin', 'learn', 'project'])],
#        [list(['success'])],
#        [list(['success', 'negoti', 'essenti', 'strategi', 'skill'])],
#        [list(['summari', 'statist', 'public', 'health'])],
#        [list(['suppli', 'chain', 'analyt'])],
#        [list(['suppli', 'chain', 'financ', 'blockchain', 'technolog'])],
#        [list(['suppli', 'chain', 'logist'])],
#        [list(['suppli', 'chain', 'manag'])],
#        [list(['suppli', 'chain', 'oper'])],
#        [list(['suppli', 'chain', 'principl'])],
#        [list(['support', 'children', 'difficulti', 'read', 'write'])],
#        [list(['survey', 'data', 'collect', 'analyt'])],
#        [list(['sustain', 'tourism', 'promot', 'environment', 'public', 'health'])],
#        [list(['swift', 'applic', 'develop'])],
#        [list(['system', 'administr', 'infrastructur', 'servic'])],
#        [list(['system', 'biolog', 'biotechnolog'])],
#        [list(['system', 'think', 'public', 'health'])],
#        [list(['tesol', 'certif', 'part', 'teach', 'english'])],
#        [list(['tesol', 'certif', 'part', 'teach', 'english'])],
#        [list(['teach', 'english', 'foundat', 'principl'])],
#        [list(['teach', 'english', 'teach', 'languag', 'onlin'])],
#        [list(['teach', 'charact', 'creat', 'posit', 'classroom'])],
#        [list(['teamwork', 'skill', 'commun', 'effect', 'group'])],
#        [list(['technic', 'support', 'fundament'])],
#        [list(['tensorflow', 'practic'])],
#        [list(['tensorflow', 'data', 'deploy'])],
#        [list(['terror', 'counterterror', 'compar', 'theori', 'practic'])],
#        [list(['addict', 'brain'])],
#        [list(['art', 'music', 'product'])],
#        [list(['art', 'sale', 'master', 'sell', 'process'])],
#        [list(['art', 'scienc', 'relationship', 'understand', 'human', 'need'])],
#        [list(['bit', 'byte', 'comput', 'network'])],
#        [list(['busi', 'health', 'care'])],
#        [list(['busi', 'music', 'product'])],
#        [list(['chang', 'global', 'order'])],
#        [list(['cycl', 'manag', 'success', 'art', 'cultur', 'organ'])],
#        [list(['diy', 'musician'])],
#        [list(['data', 'scientist', 'toolbox'])],
#        [list(['econom', 'health', 'care', 'deliveri'])],
#        [list(['global', 'financi', 'crisi'])],
#        [list(['hors', 'cours', 'introduct', 'basic', 'care', 'manag'])],
#        [list(['manag', 'toolkit', 'practic', 'guid', 'manag', 'peopl', 'work'])],
#        [list(['modern', 'world', 'part', 'one', 'global', 'histori', '1760', '1910'])],
#        [list(['modern', 'world', 'part', 'two', 'global', 'histori', 'sinc', '1910'])],
#        [list(['oral', 'caviti', 'portal', 'health', 'diseas'])],
#        [list(['power', 'macroeconom', 'econom', 'principl', 'real', 'world'])],
#        [list(['power', 'microeconom', 'econom', 'principl', 'real', 'world'])],
#        [list(['pronunci', 'american', 'english'])],
#        [list(['scienc', 'gastronomi'])],
#        [list(['scienc', 'stem', 'cell'])],
#        [list(['scienc', 'success', 'research', 'know', 'know'])],
#        [list(['scienc', 'train', 'young', 'athlet'])],
#        [list(['scienc', 'well'])],
#        [list(['singer', 'songwrit'])],
#        [list(['social', 'context', 'mental', 'health', 'ill'])],
#        [list(['strategi', 'content', 'market'])],
#        [list(['sustain', 'develop', 'goal', 'global', 'transdisciplinari', 'vision', 'futur'])],
#        [list(['teacher', 'social', 'emot', 'learn', 'sel'])],
#        [list(['technolog', 'music', 'product'])],
#        [list(['truth', 'cat', 'dog'])],
#        [list(['hidden', 'valu', 'lean', 'manufactur', 'servic'])],
#        [list(['think', 'understand', 'argument'])],
#        [list(['tool', 'data', 'scienc'])],
#        [list(['trade', 'strategi', 'emerg', 'market'])],
#        [list(['transmedia', 'storytel', 'narr', 'world', 'emerg', 'technolog', 'global', 'audienc'])],
#        [list(['tricki', 'american', 'english', 'pronunci'])],
#        [list(['troubl', 'spectr', 'autism', 'diagnost'])],
#        [list(['feder', 'taxat'])],
#        [list(['uci', 'project', 'manag'])],
#        [list(['design'])],
#        [list(['design', 'fundament'])],
#        [list(['understand', 'cancer', 'metastasi'])],
#        [list(['understand', 'clinic', 'research', 'behind', 'statist'])],
#        [list(['understand', 'einstein', 'special', 'theori', 'rel'])],
#        [list(['understand', 'medic', 'research', 'facebook', 'friend', 'wrong'])],
#        [list(['understand', 'modern', 'financ'])],
#        [list(['understand', 'plant', 'part', 'plant', 'know'])],
#        [list(['understand', 'research', 'method'])],
#        [list(['understand', 'visual', 'data', 'python'])],
#        [list(['understand', 'brain', 'neurobiolog', 'everyday', 'life'])],
#        [list(['uniti', 'certifi', 'programm', 'exam', 'prepar'])],
#        [list(['uniti', 'build', 'app'])],
#        [list(['univers', 'teach'])],
#        [list(['unravel', 'cycl', 'citi'])],
#        [list(['user', 'experi', 'research', 'design'])],
#        [list(['user', 'interfac', 'design'])],
#        [list(['use', 'databas', 'python'])],
#        [list(['use', 'python', 'access', 'web', 'data'])],
#        [list(['use', 'python', 'interact', 'oper', 'system'])],
#        [list(['valu', 'chain', 'manag'])],
#        [list(['version', 'control', 'git'])],
#        [list(['viral', 'market', 'craft', 'contagi', 'content'])],
#        [list(['virtual', 'realiti'])],
#        [list(['virtual', 'teacher'])],
#        [list(['vital', 'sign', 'understand', 'bodi', 'tell'])],
#        [list(['web', 'applic', 'everybodi'])],
#        [list(['web', 'design', 'everybodi', 'basic', 'web', 'develop', 'code'])],
#        [list(['weight', 'manag', 'beyond', 'balanc', 'calori'])],
#        [list(['contemporari', 'art'])],
#        [list(['futur', 'educ'])],
#        [list(['complianc'])],
#        [list(['data', 'scienc'])],
#        [list(['social'])],
#        [list(['wine', 'tast', 'sensori', 'techniqu', 'wine', 'analysi'])],
#        [list(['wonder', 'ancient', 'egypt'])],
#        [list(['write', 'featur', 'length', 'screenplay', 'film', 'televis'])],
#        [list(['write', 'profession', 'email', 'english'])],
#        [list(['write', 'first', 'novel'])],
#        [list(['write', 'scienc'])],
#        [list(['learn', 'ecolog', 'innov', 'approach', 'teach', 'learn', 'digit', 'age'])],
#        [list(['app', 'develop', 'swift'])],
#        [list(['hacen', 'bueno', 'directivo', 'prioridad', 'alta', 'dirección'])],
#        [list(['tudier', 'franc', 'french', 'intermedi', 'cours'])],
#        [list(['xito', 'profesion'])],
#        [list(['искусство', 'ведения', 'бизнеса'])],
#        [list(['искусство', 'разработки', 'современном'])],
#        [list(['корпоративные', 'финансы', 'стоимость', 'компании'])],
#        [list(['математика', 'python', 'для', 'анализа', 'данных'])],
#        [list(['машинное', 'обучение', 'анализ', 'данных'])],
#        [list(['основы', 'digit', 'маркетинга'])],
#        [list(['основы', 'программирования', 'python'])],
#        [list(['основы', 'разработки', 'белый', 'пояс'])],
#        [list(['погружение', 'python'])],
#        [list(['программирование', 'python'])],
#        [list(['психолингвистика', 'psycholinguist'])],
#        [list(['разработка', 'интерфейсов', 'вёрстка', 'javascript'])],
#        [list(['русский', 'как', 'иностранный'])],
#        [list(['финансовые', 'инструменты', 'для', 'частного', 'инвестора'])]],
#       dtype=object)

# %%
doc_title=[]
def convert_stng(data):
  text=""
  for i in data:
      text=text+" "+str(i)
  return(text.strip())

for i in str_organisation_sanitised:
  doc_title.append(convert_stng(i))
doc_title
# Out:
# ['isc',
#  'univers pennsylvania',
#  'john hopkin univers',
#  'yale univers',
#  'indian school busi',
#  'univers buffalo',
#  'deeplearn',
#  'deeplearn',
#  'ibm',
#  'deeplearn',
#  'deeplearn',
#  'deeplearn',
#  'amazon web servic',
#  'amazon web servic',
#  'amazon web servic',
#  'amazon web servic',
#  'amazon web servic',
#  'univers toronto',
#  'univers california irvin',
#  'univers illinoi urbana champaign',
#  'isc',
#  'univers pennsylvania',
#  'univers michigan',
#  'univers pennsylvania',
#  'universidad nacion autónoma xico',
#  'yale univers',
#  'univers colorado boulder',
#  'ibm',
#  'nation research univers higher school econom',
#  'googl cloud',
#  'erasmu univers rotterdam',
#  'duke univers',
#  'yale univers',
#  'univers virginia',
#  'univers virginia',
#  'atlassian',
#  'scrumtrek',
#  'univers california san diego',
#  'stanford univers',
#  'univers colorado system',
#  'yale univers',
#  'univers pennsylvania',
#  'copenhagen busi school',
#  'univers california irvin',
#  'macquari univers',
#  'univers michigan',
#  'yale univers',
#  'univers michigan',
#  'univers pennsylvania',
#  'vanderbilt univers',
#  'univers edinburgh',
#  'stanford univers',
#  'universidad nacion autónoma xico',
#  'technic univers denmark dtu',
#  'ibm',
#  'ibm',
#  'univers michigan',
#  'univers michigan',
#  'univers michigan',
#  'universidad austral',
#  'universidad nacion autónoma xico',
#  'univers california san diego',
#  'googl cloud',
#  'googl cloud',
#  'googl cloud',
#  'arizona state univers',
#  'museum modern art',
#  'museum modern art',
#  'nation art strategi',
#  'universit bocconi',
#  'univers virginia',
#  'univers edinburgh',
#  'pontificia universidad católica chile',
#  'univers california davi',
#  'autodesk',
#  'autodesk',
#  'autodesk',
#  'autodesk',
#  'nation taiwan univers',
#  'univers amsterdam',
#  'univers california santa cruz',
#  'univers california santa cruz',
#  'googl spectrum share',
#  'michigan state univers',
#  'univers colorado system',
#  'case western reserv univers',
#  'univers cape town',
#  'duke univers',
#  'univers michigan',
#  'universitat autònoma barcelona',
#  'emori univers',
#  'univers california san diego',
#  'john hopkin univers',
#  'univers colorado boulder',
#  'univers buffalo',
#  'insead',
#  'insead',
#  'consensi academi',
#  'hec pari',
#  'london busi school',
#  'busi school',
#  'univers california irvin',
#  'univers alberta',
#  'hebrew univers jerusalem',
#  'googl cloud',
#  'googl cloud',
#  'googl cloud',
#  'googl cloud',
#  'hec pari',
#  'univers pennsylvania',
#  'arizona state univers',
#  'univers washington',
#  'univers washington',
#  'univers pennsylvania',
#  'hec pari',
#  'rice univers',
#  'univers pennsylvania',
#  'univers virginia',
#  'indian school busi',
#  'googl cloud',
#  'univers colorado boulder',
#  'univers pennsylvania',
#  'univers california santa cruz',
#  'univers colorado system',
#  'john hopkin univers',
#  'osmosi',
#  'michigan state univers',
#  'pontificia universidad católica chile',
#  'univers michigan',
#  'univers california irvin',
#  'univers lausann',
#  'john hopkin univers',
#  'univers edinburgh',
#  'stanford univers',
#  'peke univers',
#  'cisco',
#  'univers amsterdam',
#  'ies busi school',
#  'yale univers',
#  'univers pittsburgh',
#  'univers illinoi urbana champaign',
#  'learnquest',
#  'googl cloud',
#  'univers california davi',
#  'univers edinburgh',
#  'rice univers',
#  'univers toronto',
#  'univers colorado boulder',
#  'universitat autònoma barcelona',
#  'ludwig maximilian universität münchen lmu',
#  'univers california davi',
#  'univers pennsylvania',
#  'univers colorado system',
#  'univers california irvin',
#  'columbia univers',
#  'columbia univers',
#  'columbia univers',
#  'columbia univers',
#  'universidad nacion autónoma xico',
#  'northwestern univers',
#  'univers virginia',
#  'georgia institut technolog',
#  'deeplearn',
#  'deeplearn',
#  'univers illinoi urbana champaign',
#  'ies busi school',
#  'ucl school manag',
#  'universit bocconi',
#  'universitat autònoma barcelona',
#  'univers virginia',
#  'universidad chile',
#  'googl',
#  'univers minnesota',
#  'wesleyan univers',
#  'wesleyan univers',
#  'arizona state univers',
#  'universidad nacion autónoma xico',
#  'universidad chile',
#  'univers pennsylvania',
#  'univers new mexico',
#  'northwestern univers',
#  'univers maryland colleg park',
#  'univers system georgia',
#  'univers colorado system',
#  'universitat autònoma barcelona',
#  'pennsylvania state univers',
#  'wesleyan univers',
#  'pwc',
#  'ibm',
#  'univers amsterdam',
#  'univers michigan',
#  'googl cloud',
#  'googl cloud',
#  'googl cloud',
#  'vanderbilt univers',
#  'univers illinoi urbana champaign',
#  'john hopkin univers',
#  'duke univers',
#  'ibm',
#  'john hopkin univers',
#  'john hopkin univers',
#  'duke univers',
#  'pwc',
#  'ibm',
#  'univers california davi',
#  'univers colorado system',
#  'john hopkin univers',
#  'pwc',
#  'ibm',
#  'universiteit leiden',
#  'univers pennsylvania',
#  'deeplearn',
#  'universitat autònoma barcelona',
#  'univers michigan',
#  'novosibirsk state univers',
#  'univers virginia',
#  'univers virginia',
#  'john hopkin univers',
#  'michigan state univers',
#  'univers sydney',
#  'googl cloud',
#  'googl cloud',
#  'googl cloud',
#  'univers colorado boulder',
#  'berkle colleg music',
#  'berkle colleg music',
#  'ticket chang',
#  'univers colorado boulder',
#  'lund univers',
#  'univers buffalo',
#  'univers illinoi urbana champaign',
#  'univers illinoi urbana champaign',
#  'univers virginia',
#  'univers virginia',
#  'univers alberta',
#  'univers melbourn',
#  'tecnológico monterrey',
#  'pontificia universidad católica chile',
#  'stanford univers',
#  'duke univers',
#  'erasmu univers rotterdam',
#  'univers california san diego',
#  'univers california san diego',
#  'univers washington',
#  'univers colorado system',
#  'american museum natur histori',
#  'erasmu univers rotterdam',
#  'columbia univers',
#  'univers geneva',
#  'univers pennsylvania',
#  'universitat autònoma barcelona',
#  'universidad austral',
#  'googl cloud',
#  'duke univers',
#  'berkle colleg music',
#  'yonsei univers',
#  'univers buffalo',
#  'new york univers',
#  'rice univers',
#  'duke univers',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'moscow institut physic technolog',
#  'univers pennsylvania',
#  'peter great petersburg polytechn univers',
#  'duke univers',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'hec pari',
#  'univers maryland colleg park',
#  'pennsylvania state univers',
#  'univers pittsburgh',
#  'imperi colleg london',
#  'john hopkin univers',
#  'univers north carolina chapel hill',
#  'univers melbourn',
#  'univers california davi',
#  'univers california irvin',
#  'john hopkin univers',
#  'googl cloud',
#  'googl cloud',
#  'georg washington univers',
#  'univers melbourn',
#  'yale univers',
#  'universidad nacion autónoma xico',
#  'universidad nacion autónoma xico',
#  'univers colorado boulder',
#  'yale univers',
#  'macquari univers',
#  'macquari univers',
#  'macquari univers',
#  'macquari univers',
#  'macquari univers',
#  'duke univers',
#  'univers colorado boulder',
#  'univers colorado boulder',
#  'john hopkin univers',
#  'pontificia universidad católica chile',
#  'museum modern art',
#  'univers california santa cruz',
#  'duke univers',
#  'hong kong univers scienc technolog',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'rice univers',
#  'emori univers',
#  'univers virginia',
#  'univers pennsylvania',
#  'columbia univers',
#  'univers illinoi urbana champaign',
#  'yale univers',
#  'indian school busi',
#  'univers illinoi urbana champaign',
#  'univers michigan',
#  'universit bocconi',
#  'universidad nacion autónoma xico',
#  'universidad nacion autónoma xico',
#  'univers michigan',
#  'univers pennsylvania',
#  'yonsei univers',
#  'universit bocconi',
#  'west virginia univers',
#  'universidad and',
#  'univers michigan',
#  'univers virginia',
#  'univers illinoi urbana champaign',
#  'john hopkin univers',
#  'ies busi school',
#  'emori univers',
#  'univers pennsylvania',
#  'imperi colleg london',
#  'googl cloud',
#  'univers tokyo',
#  'hong kong univers scienc technolog',
#  'hong kong univers scienc technolog',
#  'hong kong univers scienc technolog',
#  'hong kong univers scienc technolog',
#  'cole polytechniqu rale lausann',
#  'cole polytechniqu rale lausann',
#  'john hopkin univers',
#  'univers illinoi urbana champaign',
#  'rice univers',
#  'georgia institut technolog',
#  'univers california davi',
#  'california institut art',
#  'rice univers',
#  'rice univers',
#  'univers edinburgh',
#  'univers virginia',
#  'univers pennsylvania',
#  'univers alberta',
#  'univers california davi',
#  'univers pennsylvania',
#  'universidad nacion autónoma xico',
#  'universidad austral',
#  'universidad and',
#  'tecnológico monterrey',
#  'univers california davi',
#  'institut futur',
#  'googl cloud',
#  'univers toronto',
#  'michigan state univers',
#  'stanford univers',
#  'univers pennsylvania',
#  'univers pittsburgh',
#  'john hopkin univers',
#  'univers california davi',
#  'scienc',
#  'esad busi law school',
#  'pontificia universidad católica chile',
#  'bloomsburi learn exchang',
#  'michigan state univers',
#  'amazon web servic',
#  'univers california irvin',
#  'googl cloud',
#  'googl cloud',
#  'soa univers london',
#  'soa univers london',
#  'soa univers london',
#  'technic univers denmark dtu',
#  'rice univers',
#  'edhec busi school',
#  'univers pennsylvania',
#  'busi school',
#  'univers michigan',
#  'googl cloud',
#  'googl cloud',
#  'googl',
#  'googl',
#  'univers california irvin',
#  'univers colorado boulder',
#  'univers pennsylvania',
#  'lund univers',
#  'berkle colleg music',
#  'univers california san diego',
#  'john hopkin univers',
#  'universidad nacion autónoma xico',
#  'pontificia universidad católica chile',
#  'univers colorado boulder',
#  'univers florida',
#  'john hopkin univers',
#  'univers california davi',
#  'univers pennsylvania',
#  'univers minnesota',
#  'rutger state univers new jersey',
#  'northwestern univers',
#  'univers colorado system',
#  'essec busi school',
#  'univers virginia',
#  'state univers new york',
#  'michigan state univers',
#  'univers minnesota',
#  'ibm',
#  'ibm',
#  'ibm',
#  'ibm',
#  'ibm',
#  'ibm',
#  'googl',
#  'isc',
#  'busi school',
#  'autom anywher',
#  'georgia institut technolog',
#  'deeplearn',
#  'luther colleg univers regina',
#  'museum modern art',
#  'univers alberta',
#  'googl cloud',
#  'imperi colleg london',
#  'rutger state univers new jersey',
#  'macquari univers',
#  'royal holloway univers london',
#  'new york univers',
#  'univers minnesota',
#  'univers california irvin',
#  'erasmu univers rotterdam',
#  'univers sydney',
#  'univers illinoi urbana champaign',
#  'hec pari',
#  'case western reserv univers',
#  'univers michigan',
#  'univers illinoi urbana champaign',
#  'univers michigan',
#  'univers minnesota',
#  'univers pennsylvania',
#  'univers california san diego',
#  'escp busi school',
#  'univers london',
#  'state univers new york',
#  'kalshoven giesk forum',
#  'universiteit leiden',
#  'universiteit leiden',
#  'universit bocconi',
#  'yonsei univers',
#  'univers geneva',
#  'erasmu univers rotterdam',
#  'stanford univers',
#  'scienc',
#  'cisco',
#  'univers chicago',
#  'univers maryland colleg park',
#  'universidad nacion autónoma xico',
#  'pontificia universidad católica chile',
#  'univers geneva',
#  'berkle colleg music',
#  'ibm',
#  'univers california san diego',
#  'insead',
#  'yale univers',
#  'univers illinoi urbana champaign',
#  'univers michigan',
#  'univers sydney',
#  'duke univers',
#  'yale univers',
#  'ibm',
#  'goldsmith univers london',
#  'goldsmith univers london',
#  'univers pennsylvania',
#  'new york univers',
#  'new york univers',
#  'ibm',
#  'rice univers',
#  'ibm',
#  'univers michigan',
#  'univers pennsylvania',
#  'nation research univers higher school econom',
#  'georgia institut technolog',
#  'univers colorado boulder',
#  'georgia institut technolog',
#  'univers north carolina chapel hill',
#  'univers pennsylvania',
#  'nanyang technolog univers singapor',
#  'michigan state univers',
#  'duke univers',
#  'john hopkin univers',
#  'univers michigan',
#  'california institut art',
#  'univers pennsylvania',
#  'case western reserv univers',
#  'univers pennsylvania',
#  'stanford univers',
#  'univers pennsylvania',
#  'univers virginia',
#  'univers edinburgh',
#  'edhec busi school',
#  'duke univers',
#  'duke univers',
#  'vanderbilt univers',
#  'yale univers',
#  'rice univers',
#  'univers toronto',
#  'univers pennsylvania',
#  'imperi colleg london',
#  'univers illinoi urbana champaign',
#  'john hopkin univers',
#  'unsw sydney univers new south wale',
#  'deeplearn',
#  'univers michigan',
#  'new york institut financ',
#  'california institut art',
#  'georgia institut technolog',
#  'univers michigan',
#  'univers california davi',
#  'john hopkin univers',
#  'duke univers',
#  'universidad são paulo',
#  'universidad são paulo',
#  'univers geneva',
#  'edhec busi school',
#  'rice univers',
#  'saint petersburg state univers',
#  'duke univers',
#  'duke univers',
#  'univers cape town',
#  'jetbrain',
#  'essec busi school',
#  'essec busi school',
#  'rice univers',
#  'copenhagen busi school',
#  'georg washington univers',
#  'univers michigan',
#  'univers michigan',
#  'macquari univers',
#  'peke univers',
#  'tsinghua univers',
#  'univers california irvin',
#  'univers california irvin',
#  'univers california irvin',
#  'shanghai jiao tong univers',
#  'univers california davi',
#  'univers california davi',
#  'univers toronto',
#  'yonsei univers',
#  'unsw sydney univers new south wale',
#  'busi school',
#  'essec busi school',
#  'universidad and',
#  'georgia institut technolog',
#  'stanford univers',
#  'univers washington',
#  'stanford univers',
#  'univers washington',
#  'new york univers',
#  'univers london',
#  'googl cloud',
#  'googl cloud',
#  'ibm',
#  'googl cloud',
#  'universitat barcelona',
#  'school architectur design',
#  'universit bocconi',
#  'univers virginia',
#  'univers illinoi urbana champaign',
#  'hec pari',
#  'univers california irvin',
#  'univers pennsylvania',
#  'univers toronto',
#  'univers california davi',
#  'universidad são paulo',
#  'universidad austral',
#  'universidad chile',
#  'busi school',
#  'busi school',
#  'universidad and',
#  'tecnológico monterrey',
#  'univers illinoi urbana champaign',
#  'duke univers',
#  'learnquest',
#  'john hopkin univers',
#  'univers california davi',
#  'nation research univers higher school econom',
#  'imperi colleg london',
#  'imperi colleg london',
#  'imperi colleg london',
#  'imperi colleg london',
#  'univers colorado boulder',
#  'duke univers',
#  'wesleyan univers',
#  'univers amsterdam',
#  'univers illinoi urbana champaign',
#  'univers pennsylvania',
#  'mcmaster univers',
#  'universiteit leiden',
#  'univers michigan',
#  'univers pennsylvania',
#  'museum modern art',
#  'cloudera',
#  'northwestern univers',
#  'googl cloud',
#  'yale univers',
#  'univers pennsylvania',
#  'univers alberta',
#  'cole polytechniqu rale lausann',
#  'berkle colleg music',
#  'berkle colleg music',
#  'berkle colleg music',
#  'duke univers',
#  'deeplearn',
#  'univers michigan',
#  'essec busi school',
#  'vmware',
#  'googl cloud',
#  'deeplearn',
#  'saint petersburg state univers',
#  'univers maryland colleg park',
#  'univers colorado system',
#  'universidad nacion autónoma xico',
#  'ludwig maximilian universität münchen lmu',
#  'univers california san diego',
#  'duke univers',
#  'univers illinoi urbana champaign',
#  'univers alberta',
#  'duke univers',
#  'linux foundat',
#  'googl',
#  'univers pennsylvania',
#  'univers colorado boulder',
#  'northwestern univers',
#  'universiteit leiden',
#  'univers colorado system',
#  'palo alto network',
#  'rice univers',
#  'univers geneva',
#  'john hopkin univers',
#  'universitat autònoma barcelona',
#  'univers pennsylvania',
#  'univers california irvin',
#  'universidad nacion autónoma xico',
#  'michigan state univers',
#  'univers toronto',
#  'scienc',
#  'univers sydney',
#  'univers north carolina chapel hill',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'univers pennsylvania',
#  'univers colorado boulder',
#  'mathwork',
#  'state univers new york',
#  'googl cloud',
#  'univers minnesota',
#  'learn develop fund',
#  'bcg',
#  'universitat autònoma barcelona',
#  'universit bocconi',
#  'stanford univers',
#  'univers london',
#  'eindhoven univers technolog',
#  'duke univers',
#  'duke univers',
#  'univers michigan',
#  'univers california irvin',
#  'univers california irvin',
#  'univers california irvin',
#  'univers california irvin',
#  'univers california irvin',
#  'john hopkin univers',
#  'univers virginia',
#  'univers michigan',
#  'univers michigan',
#  'univers michigan',
#  'univers michigan',
#  'hong kong univers scienc technolog',
#  'ibm',
#  'univers michigan',
#  'univers amsterdam',
#  'univers colorado system',
#  'john hopkin univers',
#  'institut futur',
#  'univers minnesota',
#  'univers minnesota',
#  'univers alberta',
#  'duke univers',
#  'essec busi school',
#  'univers colorado system',
#  'univers edinburgh',
#  'univers minnesota',
#  'goldsmith univers london',
#  'universiteit leiden',
#  'universidad estadu campina',
#  'univers pennsylvania',
#  'yale univers',
#  'saint petersburg state univers',
#  'saint petersburg state univers',
#  'essec busi school',
#  'univers california davi',
#  'west virginia univers',
#  'hubspot academi',
#  'univers alberta',
#  'northwestern univers',
#  'univers colorado system',
#  'univers colorado boulder',
#  'univers california davi',
#  'univers california davi',
#  'universiteit leiden',
#  'googl cloud',
#  'univers toronto',
#  'deeplearn',
#  'universidad and',
#  'california institut art',
#  'googl cloud',
#  'univers system georgia',
#  'univers system georgia',
#  'univers michigan',
#  'cole polytechniqu rale lausann',
#  'copenhagen busi school',
#  'northwestern univers',
#  'univers pennsylvania',
#  'columbia univers',
#  'wesleyan univers',
#  'stanford univers',
#  'univers alberta',
#  'univers minnesota',
#  'univers alberta',
#  'univers alberta',
#  'state univers new york',
#  'berkle colleg music',
#  'crece con googl',
#  'univers colorado boulder',
#  'univers california davi',
#  'georgia institut technolog',
#  'northwestern univers',
#  'duke univers',
#  'stanford univers',
#  'stanford univers',
#  'imperi colleg london',
#  'univers michigan',
#  'duke univers',
#  'stanford univers',
#  'essec busi school',
#  'univers california irvin',
#  'univers illinoi urbana champaign',
#  'copenhagen busi school',
#  'copenhagen busi school',
#  'fundação instituto administração',
#  'macquari univers',
#  'ies busi school',
#  'deeplearn',
#  'univers pennsylvania',
#  'univers michigan',
#  'john hopkin univers',
#  'rutger state univers new jersey',
#  'new york institut financ',
#  'rutger state univers new jersey',
#  'rutger state univers new jersey',
#  'rutger state univers new jersey',
#  'georgia institut technolog',
#  'ucl institut educ',
#  'univers maryland colleg park',
#  'univers copenhagen',
#  'learnquest',
#  'googl',
#  'icahn school medicin mount sinai',
#  'john hopkin univers',
#  'arizona state univers',
#  'arizona state univers',
#  'arizona state univers',
#  'arizona state univers',
#  'relay graduat school educ',
#  'univers colorado boulder',
#  'googl',
#  'deeplearn',
#  'deeplearn',
#  'universiteit leiden',
#  'emori univers',
#  'berkle colleg music',
#  'northwestern univers',
#  'univers toronto',
#  'googl',
#  'univers pennsylvania',
#  'berkle colleg music',
#  'universiteit leiden',
#  'univers maryland colleg park',
#  'berkle colleg music',
#  'john hopkin univers',
#  'univers pennsylvania',
#  'yale univers',
#  'univers florida',
#  'birkbeck univers london',
#  'univers virginia',
#  'univers virginia',
#  'univers pennsylvania',
#  'univers california irvin',
#  'univers california irvin',
#  'univers california irvin',
#  'hong kong univers scienc technolog',
#  'american museum natur histori',
#  'univers michigan',
#  'univers florida',
#  'yale univers',
#  'berkle colleg music',
#  'univers toronto',
#  'univers california davi',
#  'univers copenhagen',
#  'univers colorado boulder',
#  'berkle colleg music',
#  'univers edinburgh',
#  'cole pont paristech',
#  'duke univers',
#  'ibm',
#  'indian school busi',
#  'unsw sydney univers new south wale',
#  'univers california irvin',
#  'univers geneva',
#  'univers illinoi urbana champaign',
#  'univers california irvin',
#  'california institut art',
#  'california institut art',
#  'john hopkin univers',
#  'univers cape town',
#  'stanford univers',
#  'yale univers',
#  'american institut busi econom',
#  'tel aviv univers',
#  'soa univers london',
#  'univers michigan',
#  'univers chicago',
#  'uniti',
#  'uniti',
#  'univers hong kong',
#  'univers amsterdam',
#  'univers michigan',
#  'univers minnesota',
#  'univers michigan',
#  'univers michigan',
#  'googl',
#  'univers illinoi urbana champaign',
#  'atlassian',
#  'univers pennsylvania',
#  'goldsmith univers london',
#  'univers california irvin',
#  'univers pennsylvania',
#  'univers michigan',
#  'univers michigan',
#  'emori univers',
#  'museum modern art',
#  'ucl institut educ',
#  'univers pennsylvania',
#  'ibm',
#  'northwestern univers',
#  'univers california davi',
#  'univers pennsylvania',
#  'michigan state univers',
#  'georgia institut technolog',
#  'michigan state univers',
#  'stanford univers',
#  'univers illinoi urbana champaign',
#  'univers toronto',
#  'ies busi school',
#  'cole polytechniqu',
#  'univers california irvin',
#  'saint petersburg state univers',
#  'learn develop fund',
#  'nation research univers higher school econom',
#  'learn develop fund',
#  'learn develop fund',
#  'nation research univers higher school econom',
#  'nation research univers higher school econom',
#  'learn develop fund',
#  'moscow institut physic technolog',
#  'mail group',
#  'saint petersburg state univers',
#  'learn develop fund',
#  'saint petersburg state univers',
#  'nation research univers higher school econom']

# %%
# !pip install langdetect
# Out:
# Requirement already satisfied: langdetect in /usr/local/lib/python3.7/dist-packages (1.0.9)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from langdetect) (1.15.0)

# %%
from langdetect import detect
def lang_process(data):
  lang_detected=detect(data)
  print(lang_detected,data)


for i in doc_title:
  lang_process(i)
# Out:
# de isc
# no univers pennsylvania
# fi john hopkin univers
# tr yale univers
# en indian school busi
# en univers buffalo
# nl deeplearn
# nl deeplearn
# tl ibm
# nl deeplearn
# nl deeplearn
# nl deeplearn
# en amazon web servic
# en amazon web servic
# en amazon web servic
# en amazon web servic
# en amazon web servic
# en univers toronto
# en univers california irvin
# it univers illinoi urbana champaign
# de isc
# no univers pennsylvania
# de univers michigan
# no univers pennsylvania
# es universidad nacion autónoma xico
# tr yale univers
# es univers colorado boulder
# tl ibm
# en nation research univers higher school econom
# cy googl cloud
# no erasmu univers rotterdam
# no duke univers
# tr yale univers
# lt univers virginia
# lt univers virginia
# en atlassian
# ro scrumtrek
# it univers california san diego
# no stanford univers
# es univers colorado system
# tr yale univers
# no univers pennsylvania
# nl copenhagen busi school
# en univers california irvin
# it macquari univers
# de univers michigan
# tr yale univers
# de univers michigan
# no univers pennsylvania
# no vanderbilt univers
# de univers edinburgh
# no stanford univers
# es universidad nacion autónoma xico
# de technic univers denmark dtu
# tl ibm
# tl ibm
# en univers michigan
# de univers michigan
# de univers michigan
# es universidad austral
# es universidad nacion autónoma xico
# ca univers california san diego
# cy googl cloud
# cy googl cloud
# cy googl cloud
# it arizona state univers
# da museum modern art
# da museum modern art
# en nation art strategi
# it universit bocconi
# lt univers virginia
# de univers edinburgh
# it pontificia universidad católica chile
# it univers california davi
# lv autodesk
# lv autodesk
# et autodesk
# lv autodesk
# en nation taiwan univers
# da univers amsterdam
# ca univers california santa cruz
# it univers california santa cruz
# en googl spectrum share
# en michigan state univers
# es univers colorado system
# en case western reserv univers
# en univers cape town
# no duke univers
# de univers michigan
# ca universitat autònoma barcelona
# it emori univers
# it univers california san diego
# fi john hopkin univers
# es univers colorado boulder
# en univers buffalo
# af insead
# en insead
# pt consensi academi
# en hec pari
# en london busi school
# en busi school
# en univers california irvin
# de univers alberta
# da hebrew univers jerusalem
# cy googl cloud
# cy googl cloud
# cy googl cloud
# cy googl cloud
# en hec pari
# no univers pennsylvania
# it arizona state univers
# en univers washington
# en univers washington
# no univers pennsylvania
# en hec pari
# it rice univers
# no univers pennsylvania
# lt univers virginia
# en indian school busi
# cy googl cloud
# es univers colorado boulder
# no univers pennsylvania
# it univers california santa cruz
# pt univers colorado system
# fi john hopkin univers
# lt osmosi
# en michigan state univers
# es pontificia universidad católica chile
# de univers michigan
# en univers california irvin
# fr univers lausann
# fi john hopkin univers
# de univers edinburgh
# no stanford univers
# no peke univers
# it cisco
# da univers amsterdam
# en ies busi school
# tr yale univers
# no univers pittsburgh
# it univers illinoi urbana champaign
# fr learnquest
# cy googl cloud
# it univers california davi
# de univers edinburgh
# it rice univers
# en univers toronto
# es univers colorado boulder
# ca universitat autònoma barcelona
# de ludwig maximilian universität münchen lmu
# no univers pennsylvania
# it berkle colleg music
# de universiteit leiden
# en univers maryland colleg park
# en berkle colleg music
# fi john hopkin univers
# no univers pennsylvania
# tr yale univers
# sv univers florida
# en birkbeck univers london
# lt univers virginia
# lt univers virginia
# no univers pennsylvania
# en univers california irvin
# en univers california irvin
# en univers california irvin
# en hong kong univers scienc technolog
# en american museum natur histori
# de univers michigan
# sv univers florida
# tr yale univers
# en berkle colleg music
# en univers toronto
# ca univers california davi
# da univers copenhagen
# es univers colorado boulder
# en berkle colleg music
# de univers edinburgh
# fr cole pont paristech
# no duke univers
# tl ibm
# en indian school busi
# en unsw sydney univers new south wale
# en univers california irvin
# nl univers geneva
# it univers illinoi urbana champaign
# en univers california irvin
# ro california institut art
# en california institut art
# fi john hopkin univers
# en univers cape town
# no stanford univers
# tr yale univers
# it american institut busi econom
# no tel aviv univers
# fr soa univers london
# de univers michigan
# it univers chicago
# it uniti
# it uniti
# tl univers hong kong
# da univers amsterdam
# de univers michigan
# no univers minnesota
# de univers michigan
# de univers michigan
# so googl
# it univers illinoi urbana champaign
# en atlassian
# no univers pennsylvania
# en goldsmith univers london
# en univers california irvin
# no univers pennsylvania
# de univers michigan
# de univers michigan
# it emori univers
# da museum modern art
# ro ucl institut educ
# no univers pennsylvania
# tl ibm
# de northwestern univers
# it univers california davi
# no univers pennsylvania
# en michigan state univers
# en georgia institut technolog
# en michigan state univers
# no stanford univers
# it univers illinoi urbana champaign
# en univers toronto
# en ies busi school
# fr cole polytechniqu
# en univers california irvin
# no saint petersburg state univers
# en learn develop fund
# en nation research univers higher school econom
# en learn develop fund
# en learn develop fund
# en nation research univers higher school econom
# en nation research univers higher school econom
# en learn develop fund
# en moscow institut physic technolog
# fr mail group
# no saint petersburg state univers
# en learn develop fund
# no saint petersburg state univers
# en nation research univers higher school econom

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer3 = CountVectorizer()
bog_vector2= vectorizer3.fit_transform(doc_title)
vectorizer3.get_feature_names_out()
# Out:
# array(['academi', 'administração', 'alberta', 'alto', 'amazon',
#        'american', 'amsterdam', 'and', 'anywher', 'architectur',
#        'arizona', 'art', 'atlassian', 'austral', 'autodesk', 'autom',
#        'autònoma', 'autónoma', 'aviv', 'barcelona', 'bcg', 'berkle',
#        'birkbeck', 'bloomsburi', 'bocconi', 'boulder', 'buffalo', 'busi',
#        'california', 'campina', 'cape', 'carolina', 'case', 'católica',
#        'champaign', 'chang', 'chapel', 'chicago', 'chile', 'cisco',
#        'cloud', 'cloudera', 'cole', 'colleg', 'colorado', 'columbia',
#        'con', 'consensi', 'copenhagen', 'crece', 'cruz', 'davi',
#        'deeplearn', 'denmark', 'design', 'develop', 'diego', 'dtu',
#        'duke', 'econom', 'edhec', 'edinburgh', 'educ', 'eindhoven',
#        'emori', 'erasmu', 'esad', 'escp', 'essec', 'estadu', 'exchang',
#        'financ', 'florida', 'forum', 'foundat', 'fund', 'fundação',
#        'futur', 'geneva', 'georg', 'georgia', 'giesk', 'goldsmith',
#        'googl', 'graduat', 'great', 'group', 'hebrew', 'hec', 'higher',
#        'hill', 'histori', 'holloway', 'hong', 'hopkin', 'hubspot', 'ibm',
#        'icahn', 'ies', 'illinoi', 'imperi', 'indian', 'insead',
#        'institut', 'instituto', 'irvin', 'isc', 'jersey', 'jerusalem',
#        'jetbrain', 'jiao', 'john', 'kalshoven', 'kong', 'lausann', 'law',
#        'learn', 'learnquest', 'leiden', 'linux', 'lmu', 'london',
#        'ludwig', 'lund', 'luther', 'macquari', 'mail', 'manag',
#        'maryland', 'mathwork', 'maximilian', 'mcmaster', 'medicin',
#        'melbourn', 'mexico', 'michigan', 'minnesota', 'modern',
#        'monterrey', 'moscow', 'mount', 'museum', 'music', 'münchen',
#        'nacion', 'nanyang', 'nation', 'natur', 'network', 'new', 'north',
#        'northwestern', 'novosibirsk', 'osmosi', 'palo', 'pari',
#        'paristech', 'park', 'paulo', 'peke', 'pennsylvania', 'peter',
#        'petersburg', 'physic', 'pittsburgh', 'polytechn', 'polytechniqu',
#        'pont', 'pontificia', 'pwc', 'rale', 'regina', 'relay', 'research',
#        'reserv', 'rice', 'rotterdam', 'royal', 'rutger', 'saint', 'san',
#        'santa', 'school', 'scienc', 'scrumtrek', 'servic', 'shanghai',
#        'share', 'sinai', 'singapor', 'soa', 'south', 'spectrum',
#        'stanford', 'state', 'strategi', 'sydney', 'system', 'são',
#        'taiwan', 'technic', 'technolog', 'tecnológico', 'tel', 'ticket',
#        'tokyo', 'tong', 'toronto', 'town', 'tsinghua', 'ucl', 'uniti',
#        'univers', 'universidad', 'universit', 'universitat',
#        'universiteit', 'universität', 'unsw', 'urbana', 'vanderbilt',
#        'virginia', 'vmware', 'wale', 'washington', 'web', 'wesleyan',
#        'west', 'western', 'xico', 'yale', 'yonsei', 'york'], dtype=object)

# %%
Title_bog=bog_vector2.toarray()
Title_bog.shape
# Out:
# (888, 233)

# %%
#delete the array
#title
"""
print(Title_bog.shape)
Title_bog=np.delete(Title_bog,removed_organisation_indices,axis=0)
print(Title_bog.shape)
#organisation
print(Organisation_bog.shape)
Organisation_bog=np.delete(Organisation_bog,removed_organisation_indices,axis=0)
print(Organisation_bog.shape)
"""
#Certification
print(encoded_Certification.shape)
encoded_Certification=np.delete(encoded_Certification,removed_organisation_indices,axis=0)
print(encoded_Certification.shape)


#level
print(encoded_Level.shape)
encoded_Level=np.delete(encoded_Level,removed_organisation_indices,axis=0)
print(encoded_Level.shape)
#rating
print(scaled_rating.shape)
scaled_rating=np.delete(scaled_rating,removed_organisation_indices,axis=0)
print(scaled_rating.shape)
#opted
print(scaled_opted.shape)
scaled_opted=np.delete(scaled_opted,removed_organisation_indices,axis=0)
print(scaled_opted.shape)
# Out:
# (891,)
# (888,)
# (891,)
# (888,)
# (891, 1)
# (888, 1)
# (891, 1)
# (888, 1)

# %%
encoded_Certification=encodeing_label([ i[0][0] for i in numpy_Certificate ])
 
encoded_Level=encodeing_label([ i[0][0] for i in numpy_Level])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test = train_test_split(scaled_opted, test_size=0.33, random_state=42)

# %%
from sklearn.cluster import DBSCAN
clustering = DBSCAN(eps=7, min_samples=10).fit(X_train)
